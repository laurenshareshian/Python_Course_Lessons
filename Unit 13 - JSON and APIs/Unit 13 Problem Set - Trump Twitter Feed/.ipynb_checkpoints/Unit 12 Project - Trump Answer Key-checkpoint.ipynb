# %% [markdown]
# In this project, you will use your knowledge of datetime and matplotlib to plot the number of Donald's tweets versus the a.) date, b.) day of the week and c.) time of the day. Also, you will analyze his most used words.
#
# 1.First, to get his tweets, we'll actually need to make a loop and hit the twitter API multiple times (since he's got a lotttt of tweets and Twitter has a limit to the amount of tweets that you can request at once.) This next code will get all of these tweets and save them to a file called new_tweets.json:

# %%
import twurl2
import json
import hidden

outfile = open('new_tweets.json', 'w')
wrap_list=[] #since I need to make a twitter API call repeatedly I will wrap the JSON info into a list

TWITTER_URL = 'https://api.twitter.com/1.1/statuses/user_timeline.json'
acct = 'realdonaldtrump'
twittercount=200 #pull 200 tweets at a time (the max)
secrets = hidden.oauth()
full_url=''.join([TWITTER_URL,'?','count=',str(twittercount),'&', 'screen_name=', acct])
user_timeline = twurl2.oauth_req( full_url, secrets['token_key'], secrets['token_secret'], "GET" )
js=json.loads(user_timeline)
wrap_list.append(js)

#twitter gives an ID with each tweet...keep hitting the twitter API until you run out of new IDs
old_max_id=0
max_id=js[len(js) - 1]['id']

while old_max_id!=max_id:
    old_max_id=max_id
    full_url=''.join([TWITTER_URL,'?','count=',str(twittercount),'&', 'screen_name=', acct, '&', 'max_id=', str(max_id)])
    user_timeline = twurl2.oauth_req( full_url, secrets['token_key'], secrets['token_secret'], "GET" )
    js = json.loads(user_timeline)

    max_id=js[len(js) - 1]['id']
    wrap_list.append(js)

json.dump(wrap_list, outfile)
outfile.close()

print('newest_tweet', wrap_list[0][0]['text'],wrap_list[0][0]['created_at'])
print('')
print('oldest_tweet', wrap_list[-1][0]['text'],wrap_list[-1][0]['created_at'])
# Out:
# newest_tweet Today, my Administration is launching the most sweeping action in history to lower the price of prescription drugs… https://t.co/YHscW623cr Fri May 11 19:30:16 +0000 2018
# oldest_tweet Ungrateful TRAITOR Chelsea Manning, who should never have been released from prison, is now calling President Obama a weak leader. Terrible! Thu Jan 26 11:04:24 +0000 2017

# %% [markdown]
# 2.Actually, Donald has older tweets than this. The Twitter API just doesn't let us access them. Luckily, Lauren has been saving his tweets for the last several years so we can merge the newer tweets that you just scraped with the older ones that she did in order to have a more complete data set. In the following code, we'll merge your list with hers.

# %%
import json

js=[]

#load older tweets
with open('old_tweets.json') as json_data1:
    js1 = json.load(json_data1)

#load newer tweets
with open('new_tweets.json') as json_data2:
    js2 = json.load(json_data2)

#merge both tweets
for j in range(len(js1)):
    js.append(js1[j])

for j in range(len(js2)):
    for i in range(len(js2[j])):
        js.append(js2[j][i])

#delete duplicates based on creation time
datelist=[]
count=0
dups_removed=[]

for j in range(len(js)):
    date=js[j]['created_at']
    if date not in datelist: #remove duplicates
        datelist.append(date)
        count = count + 1
        dups_removed.append(js[j])

#update donalddata.json to include all non-duplicate tweets
outfile = open('donalddata.json', 'w')
json.dump(dups_removed, outfile)
outfile.close()

print('number of unique tweets', count)
# Out:
# number of unique tweets 6167

# %% [markdown]
# 3.Load the donalddata.json data that you have just created back in in json format.

# %%
# insert 3
with open('donalddata.json') as json_data:
    js = json.load(json_data)

# %% [markdown]
# 4.Create a pandas dataframe that contains columns for tweet text, created_at, and number_of_retweets.

# %%
import pandas as pd
created_at=[]
text=[]
retweets=[]
for i in range(len(js)):
    text.append(js[i]['text'])
    created_at.append(js[i]['created_at'])
    retweets.append(js[i]['retweet_count'])
df = pd.DataFrame({'text': text, 'created_at': created_at, 'retweet_count': retweets})
df.head()
# Out:
#                        created_at  retweet_count  \
# 0  Thu Mar 23 01:04:32 +0000 2017           2896
# 1  Thu Mar 23 01:03:18 +0000 2017           1625
# 2  Wed Mar 22 13:09:35 +0000 2017          10233
# 3  Tue Mar 21 18:12:05 +0000 2017          13207
# 4  Tue Mar 21 17:33:23 +0000 2017          13448
#
#                                                 text
# 0  RT @mitchellvii: Trump always ends up being ri...
# 1  RT @mitchellvii: EXACTLY AS I SAID - House Int...
# 2              Big day for healthcare. Working hard!
# 3  Today on #NationalAgDay, we honor our great Am...
# 4  Honored to sign S.442 today. With this legisla...

# %% [markdown]
# 2.Let's convert the Twitter data (in UTC time) to Eastern Time Zone time. Here we create a new columns called eastern_time_zone:

# %%
import datetime
import pytz
from dateutil.parser import parse

tz = pytz.timezone('US/Eastern')

time_zone = []
for j in range(len(js)):
    time_zone.append(parse(js[j]['created_at']).astimezone(tz))
    
df['eastern_time_zone'] = time_zone

df.head()
# Out:
#                        created_at  retweet_count  \
# 0  Thu Mar 23 01:04:32 +0000 2017           2896
# 1  Thu Mar 23 01:03:18 +0000 2017           1625
# 2  Wed Mar 22 13:09:35 +0000 2017          10233
# 3  Tue Mar 21 18:12:05 +0000 2017          13207
# 4  Tue Mar 21 17:33:23 +0000 2017          13448
#
#                                                 text         eastern_time_zone
# 0  RT @mitchellvii: Trump always ends up being ri... 2017-03-22 21:04:32-04:00
# 1  RT @mitchellvii: EXACTLY AS I SAID - House Int... 2017-03-22 21:03:18-04:00
# 2              Big day for healthcare. Working hard! 2017-03-22 09:09:35-04:00
# 3  Today on #NationalAgDay, we honor our great Am... 2017-03-21 14:12:05-04:00
# 4  Honored to sign S.442 today. With this legisla... 2017-03-21 13:33:23-04:00

# %% [markdown]
# 3.Create a new column that includes just the hour of each tweets (use pandas built in datetime capabilities to do this in one line). Then plot the date versus the number of tweets on that date.
#
# 1. Label your axes.
#
# 2. Use bins = np.range(-.5,24.5,1) to center each bin at the hour and rwidth=0.9 to provide some separation.
#
# 3. Google how to add x-axis tick labels at each hour mark "0,1,2,3...23"
#
# Make sure the bins and the labels are centered nicely.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
plt.hist(df['eastern_time_zone'].dt.hour, rwidth=0.9, bins = np.arange(-.5,24.5,1))
plt.xlabel('hour')
plt.xticks(np.arange(0,25,1));

# %% [markdown]
# Which hour does he tweet at most often?

# %%
#8 am

# %% [markdown]
# How many tweets has he sent between midnight and 4:00 am during this time period?

# %%
print(len(df[(df['eastern_time_zone'].dt.hour)<4]))
# Out:
# 151

# %% [markdown]
# Make a histogram of day of week. Use the built in pandas capabilities. Recall that Monday corresponds to 0.
#
# Change the x-axis labels so that you see "Mon, Tues, etc." instead of "0,1,2...." You will probably need to google this.
#
# Make sure the bins and the labels are centered nicely.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
plt.hist(df['eastern_time_zone'].dt.weekday, rwidth=0.9, bins = np.arange(-.5,7.5,1))
plt.xticks(np.arange(0,7,1),['Mon','Tue','Wed','Thu','Fri','Sat','Sun']);

# %% [markdown]
# Next, we'll want to make a scatterplot of date versus number of tweets. This will take a couple of steps. First, create a dictionary called count_days such that the key is the date (just the month-day-year - not the hour or other stuff) and the value is the number of tweets on that date.

# %%
count_days={}
for day in df['eastern_time_zone'].dt.date:
    if day not in count_days:
        count_days[day]=1
    else:
        count_days[day]+=1

# %% [markdown]
# Next, plot this dictionary using a histogram. Hint: google "python plot dictionary histogram" in order to do this.
#
# Put the line "plt.rcParams['figure.figsize'] = [10, 5]" BEFORE you plot the histogram in order to see the dates along the x-axis clearly.

# %%
plt.rcParams['figure.figsize'] = [10, 5]
plt.bar(list(count_days.keys()), count_days.values())
# Out:
# <Container object of 766 artists>

# %% [markdown]
# On which date did he tweet the most? Hint: you can create a sorted list of tuples if you wish.

# %%
mytuple = []
for day,num in count_days.items():
    mytuple.append((num,day))
mytuple.sort(reverse = True)
print(mytuple[0])
# Out:
# (83, datetime.date(2016, 10, 19))

# %% [markdown]
# What were the texts of those tweets on that date? Hint: you can do this in one line.

# %%
df[df['eastern_time_zone'].dt.date == datetime.date(2016, 10, 19)]['text']
# Out:
# 943     That was really exciting. Made all of my point...
# 944     Join my team over on my Facebook page- live no...
# 945     The era of division is coming to an end. We wi...
# 946     We cannot take four more years of Barack Obama...
# 947     I started this campaign to Make America Great ...
# 948     HILLARY'S HEALTH CARE POLICIES\n#DrainTheSwamp...
# 949     RT @TeamTrump: .@realDonaldTrump is going to c...
# 950     We have to repeal &amp; replace #Obamacare! Lo...
# 951     ISIS has infiltrated countries all over Europe...
# 952     The economy cannot take four more years of the...
# 953     Together we can save American JOBS, American L...
# 954     USA has the greatest business people in the wo...
# 955     I WILL DEFEAT ISIS. THEY HAVE BEEN AROUND TOO ...
# 956     RT @TeamTrump: What They Are Saying About @rea...
# 957     After Crooked @HillaryClinton allowed ISIS to ...
# 958     RT @TeamTrump: "Her instincts are suboptimal."...
# 959     I opposed going into Iraq. Hillary voted for i...
# 960     #BigLeagueTruth #DrainTheSwamp https://t.co/eo...
# 961     Bernie Sanders on HRC: Bad Judgement. John Pod...
# 962     HILLARY FAILED ALL OVER THE WORLD. #BigLeagueT...
# 963     Hillary says "take back Mosul?" We would have ...
# 964     RT @TeamTrump: LIVE FACT-CHECK: Trump's RIGHT....
# 965     You should give the money back @HillaryClinton...
# 966     Crooked’s top aides were MIRED in massive conf...
# 967     Crooked @HillaryClinton's foundation is a CRIM...
# 968     Moderator: “Respectfully, you won’t answer the...
# 969     .@HillaryClinton loves to lie. America has had...
# 970     She'll say anything and change NOTHING! #MAGA ...
# 971     I will do more in the first 30 days in office ...
# 972     Crooked's camp incited violence at my rallies....
#                               ...
# 996     Plain &amp; Simple: We should only admit into ...
# 997     One of my first acts as President will be to d...
# 998     Hillary Clinton will use American tax dollars ...
# 999     Drugs are pouring into this country. If we hav...
# 1000    RT @TeamTrump: .@realDonaldTrump is PRO-LIFE, ...
# 1001    #SecondAmendment #2A\n#Debates https://t.co/Qb...
# 1002    It is so imperative that we have the right jus...
# 1003    .@HillaryClinton lists litany of ways she plan...
# 1004    RT @TeamTrump: .@realDonaldTrump will PROTECT ...
# 1005    The 2nd Amendment is under siege. We need SCOT...
# 1006    Hillary Clinton wants to create the most liber...
# 1007    Ready to lead. Ready to Make America Great Aga...
# 1008    This is an incredible MOVEMENT- WE are going t...
# 1009    Tune in at https://t.co/Q08Kp4w3oT and get the...
# 1010    I will be handing over my Twitter account to m...
# 1011    UNBELIEVABLE!\nClinton campaign contractor cau...
# 1012    'Over 250,000 to Lose Health Insurance in Batt...
# 1013    Join my team tonight at 8:30pmE!\nhttps://t.co...
# 1014    I will issue a lifetime ban against senior exe...
# 1015    I am going to expand the definition of LOBBYIS...
# 1016    Obamacare premiums increasing 33% in Pennsylva...
# 1017    'Hillary Clinton Deleted Emails With Her Email...
# 1018    Join me in Delaware, Ohio tomorrow at 12:30pm!...
# 1019    'Top Hillary Adviser Mocked, Plotted Attacks o...
# 1020    'Dem Operative Who Oversaw Trump Rally Agitato...
# 1021    'State works hard, and illegally, for Clinton'...
# 1022    'Scandals surround Clinton's gatekeeper at Sta...
# 1023    The State Department's 'shadow government' #Dr...
# 1024    More Anti-Catholic Emails From Team Clinton: h...
# 1025    It is time to #DrainTheSwamp!\nhttps://t.co/U2...
# Name: text, dtype: object

# %% [markdown]
# 6.Now we'll explore Trump's most frequently used words. To do this, create a loop that iterates through each tweet text and saves them all to one long string called "all_tweets".

# %%
#insert 6
all_tweets = ''
for tweet in df['text']:
    all_tweets = all_tweets + tweet
print(all_tweets[0:500])
# Out:
# RT @mitchellvii: Trump always ends up being right.  It's almost a little freaky.RT @mitchellvii: EXACTLY AS I SAID - House Intel Chair: We Cannot Rule Out Sr. Obama Officials Were Involved in Trump Surveillance https://…Big day for healthcare. Working hard!Today on #NationalAgDay, we honor our great American farmers &amp; ranchers. Their hard work &amp; dedication are ingrained… https://t.co/IpGRhly2zjHonored to sign S.442 today. With this legislation, we support @NASA's scientists, engineers, a

# %% [markdown]
# 7.Make the entire string lower case (since we want Hillary and hillary to be equivalent).

# %%
all_tweets = all_tweets.lower()

# %% [markdown]
# Also, we'll want to strip all of the punctuation. Do do that, we can use the following code.
#
# (Note: it is easier to strip the punctuation using regular expressions than the code below. But this class is a topic until itself. You can google more info about regular expressions if you'd like.)

# %%
import unicodedata
import sys

#get rid of unicode to allow removal of punctuation
tbl = dict.fromkeys(i for i in range(sys.maxunicode) if unicodedata.category(chr(i)).startswith('P'))
def remove_punctuation(text):
    return text.translate(tbl)

all_tweets=remove_punctuation(all_tweets)
print(all_tweets[0:100])
# Out:
# rt mitchellvii trump always ends up being right  its almost a little freakyrt mitchellvii exactly as

# %% [markdown]
# Create a dictionary called counts that whose key is each word and whose value is the number of times that that word occurs.

# %%
words = all_tweets.split()
counts = {}
for word in words:
    if word not in counts:
            counts[word] = 1
    else:
            counts[word] += 1
print(counts)
# Out:
# {'rt': 6, 'mitchellvii': 2, 'trump': 361, 'always': 59, 'ends': 5, 'up': 195, 'being': 117, 'right': 73, 'its': 123, 'almost': 23, 'a': 1636, 'little': 38, 'freakyrt': 1, 'exactly': 7, 'as': 296, 'i': 797, 'said': 131, 'house': 111, 'intel': 8, 'chair': 3, 'we': 672, 'cannot': 34, 'rule': 12, 'out': 266, 'sr': 1, 'obama': 126, 'officials': 12, 'were': 138, 'involved': 9, 'in': 1772, 'surveillance': 8, 'httpsbig': 1, 'day': 147, 'for': 1217, 'healthcare': 70, 'working': 101, 'hardtoday': 1, 'on': 1071, 'nationalagday': 1, 'honor': 126, 'our': 719, 'great': 850, 'american': 174, 'farmers': 10, 'amp': 685, 'ranchers': 1, 'their': 213, 'hard': 89, 'work': 67, 'dedication': 3, 'are': 760, 'ingrained': 1, 'httpstcoipgrhly2zjhonored': 1, 'to': 2856, 'sign': 15, 's442': 1, 'today': 230, 'with': 784, 'this': 383, 'legislation': 12, 'support': 97, 'nasas': 3, 'scientists': 1, 'engineers': 1, 'and': 2253, 'astronauts': 1, 'the': 4263, 'httpstcoz5vwluvjqxjoined': 1, 'housegop': 2, 'conference': 31, 'morning': 59, 'at': 647, 'us': 323, 'capitol': 2, 'httpstco03e4ybiwr0': 1, 'passthebill': 2, 'maga🇺🇸': 13, 'httpstco3swdfwgqtpthank': 1, 'you': 976, 'louisville': 2, 'kentucky': 9, 'together': 89, 'will': 1046, 'make': 215, 'america': 307, 'safe': 59, 'again': 162, 'httpstcoqggwewuvekthank': 1, 'my': 398, 'way': 90, 'httpstco3qsbsib6ktcongratulations': 1, 'eric': 14, 'lara': 3, 'very': 351, 'proud': 56, 'happy': 36, 'two': 65, 'of': 1984, 'httpstcos0t3ctqc40what': 1, 'about': 255, 'all': 437, 'contact': 3, 'clinton': 281, 'campaign': 91, 'russians': 12, 'also': 48, 'is': 1486, 'it': 505, 'true': 37, 'that': 744, 'dnc': 29, 'would': 191, 'not': 396, 'let': 53, 'fbi': 73, 'lookjust': 1, 'heard': 18, 'fake': 193, 'news': 244, 'cnn': 109, 'doing': 87, 'polls': 45, 'despite': 27, 'fact': 45, 'election': 119, 'off': 36, 'disaster': 39, 'much': 164, 'higher': 22, 'ratings': 53, 'foxthe': 1, 'real': 37, 'story': 86, 'congress': 50, 'others': 34, 'should': 160, 'be': 848, 'looking': 69, 'into': 90, 'leaking': 5, 'classified': 21, 'information': 21, 'must': 136, 'find': 20, 'leaker': 4, 'nowthe': 3, 'democrats': 132, 'made': 109, 'pushed': 6, 'russian': 35, 'an': 205, 'excuse': 12, 'running': 38, 'terrible': 45, 'big': 220, 'advantage': 7, 'electoral': 9, 'college': 8, 'lostjames': 1, 'clapper': 6, 'stated': 34, 'there': 141, 'no': 245, 'evidence': 15, 'potus': 63, 'colluded': 5, 'russia': 88, 'everyone': 67, 'knows': 23, 'iticymi': 1, 'weekly': 3, 'address': 14, '➡️httpstcockvx2zga1x': 1, 'httpstcodtgzlvlsgvvast': 1, 'sums': 1, 'money': 60, 'nato': 12, 'united': 120, 'states': 117, 'paid': 24, 'more': 226, 'powerful': 10, 'expensive': 7, 'defense': 13, 'provides': 1, 'germanydespite': 1, 'what': 172, 'have': 565, 'from': 321, 'had': 133, 'meeting': 106, 'german': 1, 'chancellor': 6, 'angela': 5, 'merkel': 5, 'nevertheless': 1, 'germany': 12, 'owesgreat': 1, 'republicanstudy': 1, 'committee': 22, 'whitehouse': 74, 'httpstco8y2uohoyaythe': 1, 'president': 268, 'changed': 12, 'so': 330, 'has': 383, 'small': 24, 'businesses': 7, 'confidence': 24, 'httpstcodatgjpmyejnorth': 1, 'korea': 83, 'behaving': 1, 'badly': 48, 'they': 353, 'been': 190, 'playing': 19, 'years': 139, 'china': 62, 'done': 77, 'helprt': 1, 'foxandfriends': 107, 'fox': 24, 'alert': 6, 'jihadis': 1, 'using': 17, 'religious': 6, 'visa': 5, 'enter': 6, 'experts': 6, 'warn': 3, 'via': 27, 'foxfriendsfirst': 2, 'httpstcopwxer9omqcrt': 1, 'video': 27, 'rep': 10, 'scalise': 4, 'gop': 39, 'agrees': 5, 'over': 113, '85': 3, 'percent': 4, 'health': 15, 'care': 32, 'bill': 82, 'httpstco05dtfjaubxrt': 1, 'americafirstpol': 2, 'major': 41, 'impact': 6, '50': 24, 'days': 39, 'moving': 9, 'swiftly': 2, 'get': 214, 'back': 162, 'track': 3, 'maga': 121, 'httpstcrt': 3, 'foxnews': 96, 'jobs': 189, 'created': 14, 'february': 4, 'httpstcosoamdxxta8happy': 1, 'lá': 1, 'fheile': 1, 'phadraig': 1, 'irish': 1, 'friendsrt': 1, 'diamondandsilk': 4, 'when': 136, 'says': 40, 'youre': 15, 'fired': 17, 'means': 12, 'pa ...

# %% [markdown]
# 8.Create a sorted list of tuples called tuple_list in reverse order of his most frequently used words. Only print the words that occur at least ten times.

# %%
tuple_list = []
for key, val in counts.items():
    tuple_list.append( (val, str(key) ))
    tuple_list.sort(reverse=True)

for i in range(len(tuple_list)):
    if tuple_list[i][0]>=10:
        print(tuple_list[i])
# Out:
# (4263, 'the')
# (2856, 'to')
# (2253, 'and')
# (1984, 'of')
# (1772, 'in')
# (1636, 'a')
# (1486, 'is')
# (1217, 'for')
# (1071, 'on')
# (1046, 'will')
# (976, 'you')
# (850, 'great')
# (848, 'be')
# (797, 'i')
# (784, 'with')
# (760, 'are')
# (744, 'that')
# (719, 'our')
# (685, 'amp')
# (672, 'we')
# (647, 'at')
# (565, 'have')
# (505, 'it')
# (498, 'was')
# (437, 'all')
# (421, 'by')
# (398, 'my')
# (396, 'not')
# (383, 'this')
# (383, 'has')
# (381, 'hillary')
# (370, 'me')
# (368, 'people')
# (361, 'trump')
# (353, 'they')
# (351, 'very')
# (330, 'so')
# (323, 'us')
# (321, 'from')
# (313, 'who')
# (309, 'realdonaldtrump')
# (307, 'america')
# (296, 'as')
# (293, 'just')
# (287, 'he')
# (281, 'clinton')
# (268, 'president')
# (266, 'out')
# (260, 'now')
# (255, 'about')
# (250, 'new')
# (245, 'no')
# (244, 'news')
# (240, 'thank')
# (230, 'today')
# (226, 'more')
# (220, 'big')
# (216, 'country')
# (215, 'make')
# (215, 'but')
# (214, 'get')
# (213, 'their')
# (213, 'many')
# (205, 'an')
# (199, 'she')
# (199, 'media')
# (197, 'am')
# (195, 'up')
# (194, 'time')
# (193, 'fake')
# (191, 'would')
# (190, 'been')
# (189, 'jobs')
# (183, 'going')
# (180, 'do')
# (179, 'your')
# (179, 'crooked')
# (174, 'american')
# (173, 'or')
# (173, 'her')
# (172, 'what')
# (172, 'tax')
# (167, 'never')
# (165, 'than')
# (164, 'much')
# (162, 'back')
# (162, 'again')
# (161, 'vote')
# (160, 'should')
# (160, 'his')
# (153, 'want')
# (152, 'trump2016')
# (151, 'bad')
# (148, 'can')
# (147, 'day')
# (143, 'one')
# (141, 'there')
# (139, 'years')
# (138, 'were')
# (136, 'when')
# (136, 'must')
# (133, 'if')
# (133, 'had')
# (132, 'like')
# (132, 'last')
# (132, 'good')
# (132, 'democrats')
# (131, 'said')
# (126, 'obama')
# (126, 'honor')
# (125, 'first')
# (123, 'its')
# (123, 'dont')
# (122, 'makeamericagreatagain')
# (121, 'maga')
# (120, 'united')
# (119, 'election')
# (118, 'state')
# (117, 'states')
# (117, 'only')
# (117, 'being')
# (113, 'tonight')
# (113, 'over')
# (112, 'even')
# (111, 'job')
# (111, 'house')
# (109, 'made')
# (109, 'cnn')
# (108, 'north')
# (107, 'foxandfriends')
# (106, 'meeting')
# (105, 'see')
# (105, 'republican')
# (104, 'tomorrow')
# (103, 'which')
# (102, 'national')
# (101, 'working')
# (100, 'how')
# (99, 'after')
# (98, 'win')
# (98, 'watch')
# (97, 'them')
# (97, 'support')
# (97, 'go')
# (97, 'did')
# (96, 'foxnews')
# (96, 'against')
# (95, 'florida')
# (92, 'ever')
# (92, 'border')
# (91, 'night')
# (91, 'military')
# (91, 'campaign')
# (90, 'way')
# (90, 'into')
# (90, 'deal')
# (89, 'women')
# (89, 'together')
# (89, 'hard')
# (88, 'year')
# (88, 'russia')
# (88, 'nytimes')
# (87, 'obamacare')
# (87, 'doing')
# (86, 'totally')
# (86, 'story')
# (83, 'wonderful')
# (83, 'really')
# (83, 'look')
# (83, 'korea')
# (82, 'bill')
# (81, 'speech')
# (81, 'need')
# (81, 'because')
# (80, 'down')
# (80, 'dems')
# (79, 'world')
# (79, 'join')
# (78, 'trade')
# (78, 'ohio')
# (77, 'why')
# (77, 'failing')
# (77, 'draintheswamp')
# (77, 'done')
# (77, 'americafirst')
# (75, 'forward')
# (74, 'whitehouse')
# (74, 'total')
# (74, 'take')
# (73, 'soon')
# (73, 'right')
# (73, 'massive')
# (73, 'fbi')
# (72, 'white')
# (72, 'cuts')
# (71, 'wall')
# (71, 'security')
# (71, 'rally')
# (71, 'other')
# (71, 'help')
# (70, 'poll')
# (70, 'long')
# (70, 'interviewed')
# (70, 'healthcare')
# (70, 'debate')
# (70, 'believe')
# (69, 'looking')
# (69, 'live')
# (69, 'donald')
# (69, 'cant')
# (68, 'washington')
# (68, 'love')
# (67, 'work')
# (67, 'say')
# (67, 'everyone')
# (66, 'w')
# (66, 'republicans')
# (66, 'pennsylvania')
# (66, 'nothing')
# (66, 'better')
# (65, 'two')
# (65, 'most')
# (64, 'record')
# (64, 'far')
# (63, 'put')
# (63, 'potus')
# (63, 'know')
# (63, 'coming')
# (63, 'before')
# (63, 'administration')
# (62, 'tickets')
# (62, 'things')
# (62, 'senate')
# (62, 'china')
# (61, 'those')
# (61, 'since')
# (61, 'law')
# (61, 'him')
# (61, 'here')
# (61, 'amazing')
# (60, 'well')
# (60, 'strong')
# (60, 'money')
# (60, 'making')
# (60, 'americans')
# (59, 'under')
# (59, 'safe')
# (59, 'morning')
# (59, 'dishonest')
# (59, 'always')
# (58, 'welcome')
# (58, 'order')
# (58, 'got')
# (57, 'york')
# (57, 'another')
# (56, 'proud')
# (56, 'keep')
# (55, 'yesterday')
# (55, 'stop')
# (55, 'economy')
# (55, 'doesnt')
# (54, 'such')
# (54, 'some')
# (54, 'show')
# (54, 'immigration')
# (53, 'ratings')
# (53, 'let')
# (53, 'isis')
# (53, 'imwithyou')
# (53, 'history')
# (53, 'families')
# (53, 'business')
# (52, 'incredible')
# (51, 'virginia')
# (51, 'teamtrump')
# (51, 'supporters')
# (51, 'pm')
# (51, 'minister')
# (51, 'market')
# (51, 'illegal')
# (51, 'high')
# (51, 'getting')
# (51, 'bernie')
# (50, 'movement')
# (50, 'congress')
# (49, 'where')
# (49, 'talk')
# (49, 'any')
# (48, 'system')
# (48, 'mexico')
# (48, 'crime')
# (48, 'badly')
# (48, 'also')
# (47, 'wrong')
# (47, 'votes')
# (47, 'taxes')
# (47, 'prayers')
# (47, 'governor')
# (46, 'then')
# (46, 'report')
# (46, 'repeal')
# (46, 'prime')
# (46, 'come')
# (46, 'attack')
# (45, 'terrible')
# (45, 'sanders')
# (45, 'polls')
# (45, 'next')
# (45, 'million')
# (45, 'john')
# (45, 'indiana')
# (45, 'fact')
# (45, 'every')
# (45, 'emails')
# (44, 'won')
# (44, 'wisconsin')
# (44, 'lost')
# (44, 'leaders')
# (44, 'comey')
# (44, 'best')
# (43, 'while')
# (43, 'run')
# (43, 'place')
# (43, 'party')
# (43, 'numbers')
# (43, 'millions')
# (43, 'melania')
# (43, 'government')
# (43, 'give')
# (42, 'think')
# (42, 'phony')
# (42, 'office')
# (42, 'ivankatrump')
# (42, 'general')
# (42, 'daca')
# (42, 'crowd')
# (42, 'carolina')
# (42, 'called')
# (41, 'thing')
# (41, 'talking')
# (41, 't')
# (41, 'mikepence')
# (41, 'major')
# (41, 'gave')
# (41, 'cut')
# (40, 'vp')
# (40, 'says')
# (40, 'nice')
# (40, 'lets')
# (40, 'full')
# (40, 'dc')
# (40, 'change')
# (40, 'bigleaguetruth')
# (39, 'wants')
# (39, 'stand')
# (39, 'same')
# (39, 'rigged')
# (39, 'plan')
# (39, 'nation')
# (39, 'interview')
# (39, 'including')
# (39, 'gop')
# (39, 'fight')
# (39, 'failed')
# (39, 'during')
# (39, 'dollars')
# (39, 'disaster')
# (39, 'days')
# (39, 'could')
# (39, 'collusion')
# (38, 'weak')
# (38, 'times')
# (38, 'thoughts')
# (38, 'these')
# (38, 'senator')
# (38, 'running')
# (38, 'men')
# (38, 'man')
# (38, 'little')
# (38, 'erictrump')
# (38, 'end')
# (38, 'does')
# (38, 'clintons')
# (38, 'arizona')
# (38, 'act')
# (37, 'true')
# (37, 'special')
# (37, 'secretary')
# (37, 'real')
# (37, 'person')
# (37, 'important')
# (37, 'family')
# (37, 'evening')
# (37, 'didnt')
# (37, 'companies')
# (37, 'colorado')
# (36, 'week')
# (36, 'watching')
# (36, 'stock')
# (36, 'seanhannity')
# (36, 'replace')
# (36, 'presidential')
# (36, 'off')
# (36, 'justice')
# (36, 'having')
# (36, 'happy')
# (36, 'flotus')
# (36, 'economic')
# (35, 'texas')
# (35, 'south')
# (35, 'saying')
# (35, 'russian')
# (35, 'press')
# (34, 'stated')
# (34, 'safety')
# (34, 'reform')
# (34, 'protect')
# (34, 'pence')
# (34, 'others')
# (34, 'hit')
# (34, 'cannot')
# (34, 'call')
# (34, 'bring')
# (33, 'team')
# (33, 'taking')
# (33, 'remember')
# (33, 'ready')
# (33, 'political')
# (33, 'im')
# (33, 'false')
# (33, 'close')
# (32, 'trumppence16')
# (32, 'top')
# (32, 'senators')
# (32, 'iran')
# (32, 'fantastic')
# (32, 'countries')
# (32, 'continue')
# (32, 'care')
# (32, 'biggest')
# (32, 'between')
# (32, 'beautiful')
# (31, 'use')
# (31, 'truly')
# (31, 'tremendous')
# (31, 'too')
# (31, 'thanks')
# (31, 'enforcement')
# (31, 'dead')
# (31, 'conference')
# (31, 'alabama')
# (30, 'worst')
# (30, 'winning')
# (30, 'west')
# (30, 'veterans')
# (30, 'through')
# (30, 'thats')
# (30, 'stories')
# (30, 'police')
# (30, 'pay')
# (30, 'nations')
# (30, 'michigan')
# (30, 'meet')
# (30, 'killed')
# (30, 'iowa')
# (30, 'hope')
# (30, 'future')
# (30, 'foreign')
# (30, 'already')
# (29, 'worse')
# (29, 'witch')
# (29, 'trumps')
# (29, 'spending')
# (29, 'smart')
# (29, 'rico')
# (29, 'primary')
# (29, 'policy')
# (29, 'open')
# (29, 'o')
# (29, 'leadership')
# (29, 'email')
# (29, 'dnc')
# (29, 'democrat')
# (29, 'cruz')
# (29, 'court')
# (29, 'book')
# (29, '7pm')
# (29, '2017')
# (28, 'yet')
# (28, 'votetrump')
# (28, 'victory')
# (28, 'trying')
# (28, 'took')
# (28, 'service')
# (28, 'meetings')
# (28, 'level')
# (28, 'hillaryclinton')
# (28, 'fix')
# (28, 'both')
# (28, 'billion')
# (28, 'away')
# (28, 'announced')
# (28, 'air')
# (27, 'warren')
# (27, 'video')
# (27, 'via')
# (27, 'until')
# (27, 'tough')
# (27, 'still')
# (27, 'race')
# (27, 'officers')
# (27, 'months')
# (27, 'members')
# (27, 'may')
# (27, 'increase')
# (27, 'historic')
# (27, 'despite')
# (27, 'california')
# (27, 'allowed')
# (27, 'afternoon')
# (26, 'zero')
# (26, 'workers')
# (26, 'victims')
# (26, 'unemployment')
# (26, 'taken')
# (26, 'statement')
# (26, 'spoke')
# (26, 'signed')
# (26, 'seen')
# (26, 'puerto')
# (26, 'nbc')
# (26, 'middle')
# (26, 'friend')
# (26, 'force')
# (26, 'finally')
# (26, 'fighting')
# (26, 'entire')
# (26, 'deals')
# (26, 'convention')
# (26, 'biased')
# (26, 'ago')
# (25, 'visit')
# (25, 'used')
# (25, 'shows')
# (25, 'respect')
# (25, 'radical')
# (25, 'low')
# (25, 'life')
# (25, 'leaving')
# (25, 'corrupt')
# (24, 'words')
# (24, 'without')
# (24, 'un')
# (24, 'told')
# (24, 'small')
# (24, 'policies')
# (24, 'paid')
# (24, 'nuclear')
# (24, 'november')
# (24, 'mike')
# (24, 'lot')
# (24, 'longer')
# (24, 'lives')
# (24, 'lies')
# (24, 'investigation')
# (24, 'highest')
# (24, 'heading')
# (24, 'god')
# (24, 'friends')
# (24, 'fox')
# (24, 'endorsement')
# (24, 'donaldjtrumpjr')
# (24, 'decision')
# (24, 'control')
# (24, 'confidence')
# (24, 'anyone')
# (24, '50')
# (24, '2016')
# (24, '100')
# (24, '1')
# (23, 'wont')
# (23, 'terrorist')
# (23, 'street')
# (23, 'secret')
# (23, 'released')
# (23, 'reason')
# (23, 'post')
# (23, 'please')
# (23, 'pass')
# (23, 'own')
# (23, 'left')
# (23, 'knows')
# (23, 'j')
# (23, 'honored')
# (23, 'home')
# (23, 'highly')
# (23, 'given')
# (23, 'elizabeth')
# (23, 'brave')
# (23, 'borders')
# (23, 'behalf')
# (23, 'beginning')
# (23, 'become')
# (23, 'almost')
# (23, 'allow')
# (23, '4')
# (22, 'went')
# (22, 'voters')
# (22, 'usa')
# (22, 'terror')
# (22, 'start')
# (22, 'sources')
# (22, 'scavino45')
# (22, 'results')
# (22, 'reporting')
# (22, 'presidency')
# (22, 'players')
# (22, 'mr')
# (22, 'luther')
# (22, 'lie')
# (22, 'less')
# (22, 'least')
# (22, 'kaine')
# (22, 'james')
# (22, 'hillarys')
# (22, 'higher')
# (22, 'happening')
# (22, 'france')
# (22, 'enjoy')
# (22, 'committee')
# (22, 'chance')
# (22, 'case')
# (22, 'beat')
# (22, 'asked')
# (22, 'arrived')
# (22, 'around')
# (22, 'approval')
# (22, 'actually')
# (22, 'abc')
# (21, 'woman')
# (21, 'wh')
# (21, 'u')
# (21, 'thought')
# (21, 'ted')
# (21, 'spent')
# (21, 'saturday')
# (21, 'reported')
# (21, 'questions')
# (21, 'perhaps')
# (21, 'oreillyfactor')
# (21, 'once')
# (21, 'nfl')
# (21, 'israel')
# (21, 'intelligence')
# (21, 'information')
# (21, 'hurricane')
# (21, 'hear')
# (21, 'guy')
# (21, 'flag')
# (21, 'everything')
# (21, 'energy')
# (21, 'debates2016')
# (21, 'danscavino')
# (21, 'crazy')
# (21, 'coverage')
# (21, 'condolences')
# (21, 'classified')
# (21, 'chuck')
# (21, 'center')
# (21, 'birthday')
# (21, 'agree')
# (21, '7')
# (21, '3')
# (20, 'xi')
# (20, 'war')
# (20, 'unfair')
# (20, 'trumptrain')
# (20, 'terrorism')
# (20, 'supreme')
# (20, 'stay')
# (20, 'san')
# (20, 'responders')
# (20, 'read')
# (20, 'public')
# (20, 'possible')
# (20, 'part')
# (20, 'old')
# (20, 'nevada')
# (20, 'needs')
# (20, 'message')
# (20, 'knew')
# (20, 'horrible')
# (20, 'happened')
# (20, 'game')
# (20, 'find')
# (20, 'final')
# (20, 'executive')
# (20, 'discuss')
# (20, 'david')
# (20, 'complete')
# (20, 'class')
# (20, 'candidate')
# (20, 'ban')
# (20, 'action')
# (20, 'across')
# (20, 'able')
# (20, '8')
# (20, '3pm')
# (20, '10')
# (19, 'voted')
# (19, 'three')
# (19, 'syria')
# (19, 'speak')
# (19, 'save')
# (19, 'remarks')
# (19, 'rate')
# (19, 'rallies')
# (19, 'pushing')
# (19, 'premiums')
# (19, 'politics')
# (19, 'playing')
# (19, 'past')
# (19, 'nobody')
# (19, 'negative')
# (19, 'met')
# (19, 'megynkelly')
# (19, 'lowest')
# (19, 'losing')
# (19, 'leader')
# (19, 'judgement')
# (19, 'japan')
# (19, 'islamic')
# (19, 'icymi')
# (19, 'hunt')
# (19, 'heroes')
# (19, 'hampshire')
# (19, 'greatest')
# (19, 'friday')
# (19, 'four')
# (19, 'forget')
# (19, 'focus')
# (19, 'fema')
# (19, 'federal')
# (19, 'director')
# (19, 'department')
# (19, 'delegates')
# (19, 'council')
# (19, 'children')
# (19, 'came')
# (19, 'cabinet')
# (19, 'bush')
# (19, 'anthem')
# (19, 'americas')
# (19, 'ad')
# (18, 'thousands')
# (18, 'th')
# (18, 'success')
# (18, 'southern')
# (18, 'son')
# (18, 'set')
# (18, 'schumer')
# (18, 'r')
# (18, 'problem')
# (18, 'power')
# (18, 'point')
# (18, 'lead')
# (18, 'heard')
# (18, 'harvey')
# (18, 'gone')
# (18, 'fully')
# (18, 'event')
# (18, 'endorsed')
# (18, 'dem')
# (18, 'debates')
# (18, 'continues')
# (18, 'congratulations')
# (18, 'concerning')
# (18, 'build')
# (18, 'asking')
# (18, 'along')
# (18, 'ahead')
# (18, 'abe')
# (17, 'wanted')
# (17, 'voting')
# (17, 'using')
# (17, 'treated')
# (17, 'tell')
# (17, 'speaking')
# (17, 'serve')
# (17, 'school')
# (17, 'sad')
# (17, 's')
# (17, 'paul')
# (17, 'louisiana')
# (17, 'free')
# (17, 'found')
# (17, 'fired')
# (17, 'fakenews')
# (17, 'drug')
# (17, 'crookedhillary')
# (17, 'cities')
# (17, 'calls')
# (17, 'broken')
# (17, 'billions')
# (17, 'behind')
# (17, 'anything')
# (17, '700')
# (17, '30')
# (17, '2')
# (16, 'watched')
# (16, 'vietnam')
# (16, 'vegas')
# (16, 'va')
# (16, 'strange')
# (16, 'steel')
# (16, 'started')
# (16, 'spirit')
# (16, 'sanctuary')
# (16, 'room')
# (16, 'relationship')
# (16, 'putin')
# (16, 'needed')
# (16, 'm')
# (16, 'leave')
# (16, 'leading')
# (16, 'las')
# (16, 'large')
# (16, 'ive')
# (16, 'ivanka')
# (16, 'interesting')
# (16, 'insurance')
# (16, 'hurt')
# (16, 'host')
# (16, 'hits')
# (16, 'hes')
# (16, 'h')
# (16, 'fraud')
# (16, 'former')
# (16, 'dumb')
# (16, 'drudgereport')
# (16, 'democratic')
# (16, 'dangerous')
# (16, 'county')
# (16, 'cleveland')
# (16, 'celebrate')
# (16, 'budget')
# (16, 'bringing')
# (16, 'bills')
# (16, '51')
# (16, '2018')
# (16, '13')
# (15, 'youre')
# (15, 'wife')
# (15, 'washingtonpost')
# (15, 'voter')
# (15, 'usa🇺🇸')
# (15, 'tuesday')
# (15, 'truth')
# (15, 'tower')
# (15, 'successful')
# (15, 'starting')
# (15, 'something')
# (15, 'sign')
# (15, 'server')
# (15, 'seeing')
# (15, 'ryan')
# (15, 'respected')
# (15, 'regulations')
# (15, 'refuses')
# (15, 'raise')
# (15, 'popular')
# (15, 'peace')
# (15, 'optimism')
# (15, 'mess')
# (15, 'mayor')
# (15, 'manufacturing')
# (15, 'lower')
# (15, 'looks')
# (15, 'laws')
# (15, 'judge')
# (15, 'infrastructure')
# (15, 'health')
# (15, 'happen')
# (15, 'gotten')
# (15, 'georgia')
# (15, 'freedom')
# (15, 'fire')
# (15, 'fast')
# (15, 'fair')
# (15, 'exciting')
# (15, 'evidence')
# (15, 'citizens')
# (15, 'camp')
# (15, 'calling')
# (15, 'ask')
# (15, 'alltime')
# (15, 'agenda')
# (15, 'ads')
# (15, '=')
# (14, '➡️')
# (14, 'wins')
# (14, 'violence')
# (14, 'tv')
# (14, 'tune')
# (14, 'trip')
# (14, 'travel')
# (14, 'todays')
# (14, 'tennessee')
# (14, 'stronger')
# (14, 'step')
# (14, 'short')
# (14, 'rest')
# (14, 'proven')
# (14, 'problems')
# (14, 'prior')
# (14, 'points')
# (14, 'plus')
# (14, 'plans')
# (14, 'phoenix')
# (14, 'patrol')
# (14, 'page')
# (14, 'oh')
# (14, 'makes')
# (14, 'loudobbs')
# (14, 'lose')
# (14, 'lied')
# (14, 'king')
# (14, 'kind')
# (14, 'kasich')
# (14, 'iraq')
# (14, 'forced')
# (14, 'facts')
# (14, 'facebook')
# (14, 'everybody')
# (14, 'eric')
# (14, 'elected')
# (14, 'dinner')
# (14, 'dallas')
# (14, 'crowds')
# (14, 'created')
# (14, 'city')
# (14, 'choice')
# (14, 'caught')
# (14, 'building')
# (14, 'bedminster')
# (14, 'announce')
# (14, 'angry')
# (14, 'ag')
# (14, 'address')
# (14, '900')
# (14, '60')
# (14, '17')
# (14, '16')
# (14, '12')
# (13, 'wiprimary')
# (13, 'weekend')
# (13, 'wasnt')
# (13, 'twitter')
# (13, 'sure')
# (13, 'shot')
# (13, 'shooting')
# (13, 'saved')
# (13, 'rncincle')
# (13, 'representatives')
# (13, 'protection')
# (13, 'promised')
# (13, 'progress')
# (13, 'potential')
# (13, 'passed')
# (13, 'obstruction')
# (13, 'number')
# (13, 'nbcnews')
# (13, 'move')
# (13, 'morningjoe')
# (13, 'michael')
# (13, 'maga🇺🇸')
# (13, 'known')
# (13, 'kim')
# (13, 'killing')
# (13, 'kelly')
# (13, 'joint')
# (13, 'january')
# (13, 'isnt')
# (13, 'interest')
# (13, 'immediately')
# (13, 'hall')
# (13, 'growth')
# (13, 'graham')
# (13, 'goofy')
# (13, 'giving')
# (13, 'foundation')
# (13, 'few')
# (13, 'expected')
# (13, 'enthusiasm')
# (13, 'east')
# (13, 'donaldtrump')
# (13, 'defense')
# (13, 'defeat')
# (13, 'create')
# (13, 'course')
# (13, 'congressional')
# (13, 'community')
# (13, 'committed')
# (13, 'comes')
# (13, 'check')
# (13, 'base')
# (13, 'b')
# (13, 'among')
# (13, '6')
# (12, 'wonder')
# (12, 'within')
# (12, 'wait')
# (12, 'vs')
# (12, 'turned')
# (12, 'try')
# (12, 'trillion')
# (12, 'town')
# (12, 'tougher')
# (12, 'thursday')
# (12, 'threat')
# (12, 'terrorists')
# (12, 'talks')
# (12, 'talented')
# (12, 'strongly')
# (12, 'social')
# (12, 'socalled')
# (12, 'single')
# (12, 'simple')
# (12, 'saw')
# (12, 'russians')
# (12, 'rule')
# (12, 'reviews')
# (12, 'process')
# (12, 'poor')
# (12, 'podesta')
# (12, 'plant')
# (12, 'planned')
# (12, 'piece')
# (12, 'pick')
# (12, 'paris')
# (12, 'pa')
# (12, 'officials')
# (12, 'official')
# (12, 'nomination')
# (12, 'nato')
# (12, 'n')
# (12, 'myself')
# (12, 'memorial')
# (12, 'means')
# (12, 'mccabe')
# (12, 'loves')
# (12, 'line')
# (12, 'legislation')
# (12, 'led')
# (12, 'landed')
# (12, 'la')
# (12, 'jackson')
# (12, 'international')
# (12, 'instead')
# (12, 'illegally')
# (12, 'husband')
# (12, 'httpstco3kwol2ibaw')
# (12, 'hopefully')
# (12, 'helping')
# (12, 'hacking')
# (12, 'group')
# (12, 'grateful')
# (12, 'germany')
# (12, 'foxbusiness')
# (12, 'father')
# (12, 'excuse')
# (12, 'except')
# (12, 'efforts')
# (12, 'deliver')
# (12, 'criminal')
# (12, 'correct')
# (12, 'claims')
# (12, 'cia')
# (12, 'chief')
# (12, 'chicago')
# (12, 'changed')
# (12, 'champion')
# (12, 'bless')
# (12, 'beach')
# (12, 'based')
# (12, 'approved')
# (12, 'andrew')
# (12, 'absolutely')
# (12, '6pm')
# (12, '1000')
# (11, 'young')
# (11, 'written')
# (11, 'worked')
# (11, 'wi')
# (11, 'weeks')
# (11, 'wednesday')
# (11, 'vpdebate')
# (11, 'unable')
# (11, 'term')
# (11, 'tampa')
# (11, 'strength')
# (11, 'standing')
# (11, 'sessions')
# (11, 'serious')
# (11, 'scandal')
# (11, 'rights')
# (11, 'ridiculous')
# (11, 'represent')
# (11, 'reince')
# (11, 'regulation')
# (11, 'rebuild')
# (11, 'rapidly')
# (11, 'quickly')
# (11, 'promise')
# (11, 'program')
# (11, 'presidents')
# (11, 'pouring')
# (11, 'play')
# (11, 'pittsburgh')
# (11, 'pensacola')
# (11, 'paying')
# (11, 'path')
# (11, 'oval')
# (11, 'outside')
# (11, 'obamas')
# (11, 'nyprimary')
# (11, 'network')
# (11, 'netanyahu')
# (11, 'nafta')
# (11, 'msm')
# (11, 'mrs')
# (11, 'moon')
# (11, 'monday')
# (11, 'missile')
# (11, 'minutes')
# (11, 'mention')
# (11, 'mccain')
# (11, 'matter')
# (11, 'majority')
# (11, 'maine')
# (11, 'loss')
# (11, 'local')
# (11, 'legal')
# (11, 'korean')
# (11, 'keeping')
# (11, 'jong')
# (11, 'joining')
# (11, 'joe')
# (11, 'jeff')
# (11, 'island')
# (11, 'info')
# (11, 'inaccurate')
# (11, 'hurricaneharvey')
# (11, 'hours')
# (11, 'hold')
# (11, 'hoax')
# (11, 'head')
# (11, 'greta')
# (11, 'greatly')
# (11, 'gang')
# (11, 'ford')
# (11, 'feel')
# (11, 'failure')
# (11, 'easy')
# (11, 'dropped')
# (11, 'dr')
# (11, 'dossier')
# (11, 'don')
# (11, 'deleted')
# (11, 'death')
# (11, 'couldnt')
# (11, 'cost')
# (11, 'corker')
# (11, 'clear')
# (11, 'charge')
# (11, 'c')
# (11, 'attacks')
# (11, 'april')
# (11, 'agreed')
# (11, 'agents')
# (11, '2nd')
# (11, '15')
# (10, 'wsj')
# (10, 'whether')
# (10, 'whats')
# (10, 'understand')
# (10, 'turning')
# (10, 'turn')
# (10, 'transcript')
# (10, 'tpp')
# (10, 'themselves')
# (10, 'syrian')
# (10, 'super')
# (10, 'staff')
# (10, 'spend')
# (10, 'situation')
# (10, 'side')
# (10, 'shes')
# (10, 'sell')
# (10, 'rules')
# (10, 'rick')
# (10, 'reporter')
# (10, 'rep')
# (10, 'relief')
# (10, 'rapids')
# (10, 'ran')
# (10, 'push')
# (10, 'proclamation')
# (10, 'primaries')
# (10, 'powerful')
# (10, 'positive')
# (10, 'pleased')
# (10, 'plane')
# (10, 'packed')
# (10, 'orlando')
# (10, 'opportunity')
# (10, 'onesided')
# (10, 'ny')
# (10, 'notice')
# (10, 'nominee')
# (10, 'native')
# (10, 'name')
# (10, 'ms13')
# (10, 'mcconnell')
# (10, 'leaked')
# (10, 'kellyannepolls')
# (10, 'june')
# (10, 'judgejeanine')
# (10, 'industry')
# (10, 'hate')
# (10, 'grand')
# (10, 'gets')
# (10, 'fools')
# (10, 'fl')
# (10, 'financial')
# (10, 'farmers')
# (10, 'especially')
# (10, 'enough')
# (10, 'emmanuelmacron')
# (10, 'drop')
# (10, 'divided')
# (10, 'disrespect')
# (10, 'died')
# (10, 'destroyed')
# (10, 'delegation')
# (10, 'defend')
# (10, 'decisions')
# (10, 'debt')
# (10, 'debatenight')
# (10, 'cover')
# (10, 'consumer')
# (10, 'connecticut')
# (10, 'cincinnati')
# (10, 'charges')
# (10, 'challenge')
# (10, 'candidates')
# (10, 'brought')
# (10, 'bobby')
# (10, 'bigger')
# (10, 'benefits')
# (10, 'attorney')
# (10, 'arent')
# (10, 'arabia')
# (10, 'apologize')
# (10, 'anymore')
# (10, 'answer')
# (10, 'amazon')
# (10, 'aluminum')
# (10, 'acting')
# (10, 'accomplished')
# (10, 'access')
# (10, '8th')
# (10, '500')
# (10, '5')
# (10, '33000')

# %% [markdown]
# One last thing...word cloud visualizations are kind of a hot thing right now. Let's make one, but get rid of the boring words like "the" that aren't that interesting. Recreate the count dictionary above but add keys that are not in the boring list below:
#
# boring_words=['that', 'have', 'there', 'just', 'their', 'were', 'what' , 'with', 'will', 'than', 'about', 'this']

# %%
boring_words=['at', 'be','was', 'by', 'our','do','so','amp','by','it','its','at','by' 'from', 'as', 'but','am','of', 'a', 'you', 'on', 'the', 'is', 'to', 'and', 'in', 'has', 'are', 'not', 'an', 'in', 'or', 'for', 'who', 'that', 'have', 'there', 'just', 'their', 'were', 'what' , 'with', 'will', 'than', 'about', 'this','if','from','would','been','had']
words = all_tweets.split()
counts = {}
for word in words:
    if word.strip() not in boring_words:
        if word not in counts:
            counts[word] = 1
        else:
            counts[word] += 1
x = sorted(counts, key=counts.get, reverse=True)
print(x[:100])
# Out:
# ['great', 'i', 'we', 'all', 'my', 'hillary', 'me', 'people', 'trump', 'they', 'very', 'us', 'realdonaldtrump', 'america', 'he', 'clinton', 'president', 'out', 'now', 'new', 'no', 'news', 'thank', 'today', 'more', 'big', 'country', 'make', 'get', 'many', 'media', 'she', 'up', 'time', 'fake', 'jobs', 'going', 'your', 'crooked', 'american', 'her', 'tax', 'never', 'much', 'again', 'back', 'vote', 'should', 'his', 'want', 'trump2016', 'bad', 'can', 'day', 'one', 'years', 'must', 'when', 'democrats', 'good', 'last', 'like', 'said', 'obama', 'honor', 'first', 'dont', 'makeamericagreatagain', 'maga', 'united', 'election', 'state', 'being', 'states', 'only', 'over', 'tonight', 'even', 'house', 'job', 'cnn', 'made', 'north', 'foxandfriends', 'meeting', 'republican', 'see', 'tomorrow', 'which', 'national', 'working', 'how', 'after', 'watch', 'win', 'support', 'go', 'did', 'them', 'foxnews']

# %% [markdown]
# We'll save the words and their frequencies to a javascript file that we can view on a webpage. Here's the code.

# %%
# ##########################################
#plot counts using d3, to view the visualization open the twitterword.htm file in a web browser
# ##########################################
x = sorted(counts, key=counts.get, reverse=True)
highest = None
lowest = None
for k in x[:100]:
    if highest is None or highest < counts[k] :
        highest = counts[k]
    if lowest is None or lowest > counts[k] :
        lowest = counts[k]

# Spread the font sizes across 20-100 based on the count
bigsize = 80
smallsize = 20

fhand = open('donaldwords.js','w')
fhand.write("donaldwords = [")
first = True
for k in x[:100]:
    if not first : fhand.write( ",\n")
    first = False
    size = counts[k]
    size = (size - lowest) / float(highest - lowest)
    size = int((size * bigsize) + smallsize)
    fhand.write("{text: '"+k+"', size: "+str(size)+"}")
fhand.write( "\n];\n")

print ("Output written to donaldwords.js")
# Out:
# Output written to donaldwords.js

# %% [markdown]
# Now open the twitterword.html file in a web browser to view the word cloud.
