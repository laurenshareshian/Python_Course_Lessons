# %% [markdown]
# 1. Save the Saturday, June 17th, 2017 data to a csv file. You can find it here: http://web.mta.info/developers/turnstile.html and read it in using read_csv. View the head of the dataframe.

# %%
#insert 1
import pandas as pd
from collections import defaultdict

df = pd.read_csv('turnstile_June_17_2017.csv')
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/10/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/10/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/10/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/10/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/10/2017  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6215258
# 1  REGULAR  6215284
# 2  REGULAR  6215318
# 3  REGULAR  6215475
# 4  REGULAR  6215841
#
#    EXITS
# 0                                            2104297
# 1                                            2104303
# 2                                            2104337
# 3                                            2104417
# 4                                            2104465

# %% [markdown]
# 2.View the dataframe columns. Is there extra whitespace at the end of any of the column names? Strip all of the whitespace.

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %% [markdown]
# 3.In one line, determine how many rows are in your dataframe and if there are are any null entries.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197209 entries, 0 to 197208
# Data columns (total 11 columns):
# C/A         197209 non-null object
# UNIT        197209 non-null object
# SCP         197209 non-null object
# STATION     197209 non-null object
# LINENAME    197209 non-null object
# DIVISION    197209 non-null object
# DATE        197209 non-null object
# TIME        197209 non-null object
# DESC        197209 non-null object
# ENTRIES     197209 non-null int64
# EXITS       197209 non-null int64
# dtypes: int64(2), object(9)
# memory usage: 16.6+ MB

# %% [markdown]
# 4.Print out the unique STATION names and list how many there are. (Hint: use set).

# %%
#insert 4
print(set(df.STATION))
print(len(set(df.STATION)))
# Out:
# {'BROOKLYN BRIDGE', 'BEACH 36 ST', '5 AV/59 ST', 'BEDFORD AV', 'PAVONIA/NEWPORT', '238 ST', '96 ST', 'UNION ST', '4 AV-9 ST', 'GRANT AV', '9TH STREET', 'NEW LOTS', 'BRIARWOOD', 'PENNSYLVANIA AV', 'NEWARK HM HE', "B'WAY-LAFAYETTE", 'FULTON ST', 'CHAMBERS ST', '66 ST-LINCOLN', '18 AV', 'RIT-ROOSEVELT', 'HALSEY ST', 'PATH WTC 2', 'BEACH 60 ST', '61 ST WOODSIDE', 'GATES AV', 'PELHAM BAY PARK', 'HOYT-SCHER', '191 ST', 'KNICKERBOCKER', 'HUNTS POINT AV', '40 ST LOWERY ST', '30 AV', 'NEWARK BM BW', '51 ST', '81 ST-MUSEUM', '103 ST-CORONA', 'HOWARD BCH JFK', '5 AVE', '86 ST-2 AVE', '59 ST', 'E 180 ST', 'ROOSEVELT ISLND', '169 ST', 'JUNIUS ST', 'CRESCENT ST', 'AVENUE I', '33 ST', '138/GRAND CONC', '168 ST', 'BROADWAY JCT', '149/GRAND CONC', 'ATLANTIC AV', 'STERLING ST', 'BROADWAY', 'BERGEN ST', 'HARLEM 148 ST', 'BOROUGH HALL', 'TWENTY THIRD ST', '72 ST', 'NEW LOTS AV', '110 ST', 'CLEVELAND ST', '72 ST-2 AVE', '46 ST', 'BEDFORD-NOSTRAN', 'BEACH 67 ST', 'ST LAWRENCE AV', '175 ST', '20 AV', 'FLUSHING-MAIN', 'JAY ST-METROTEC', 'FRANKLIN ST', 'NEPTUNE AV', 'NEVINS ST', 'NOSTRAND AV', 'GRAND-NEWTOWN', 'SIMPSON ST', 'EASTN PKWY-MUSM', 'AVENUE H', 'PARK PLACE', '104 ST', '36 AV', 'MORGAN AV', 'EASTCHSTER/DYRE', 'CORTLANDT ST', 'FORDHAM RD', '174 ST', '116 ST', 'JOURNAL SQUARE', 'CLASSON AV', '21 ST-QNSBRIDGE', 'QUEENS PLAZA', 'CHRISTOPHER ST', '207 ST', 'FREEMAN ST', 'BOTANIC GARDEN', 'GRAHAM AV', 'SHEPHERD AV', 'BEACH 44 ST', 'CONEY IS-STILLW', '57 ST-7 AV', 'SHEEPSHEAD BAY', 'CENTRAL AV', 'AVENUE P', 'WORLD TRADE CTR', 'ZEREGA AV', 'DYCKMAN ST', 'CLINTON-WASH AV', 'AVENUE U', 'GUN HILL RD', '34 ST-PENN STA', 'ATL AV-BARCLAY', 'TOMPKINSVILLE', 'VAN SICLEN AVE', 'JUNCTION BLVD', 'KINGSBRIDGE RD', 'METS-WILLETS PT', '80 ST', 'PRINCE ST', 'THIRTY ST', '42 ST-BRYANT PK', '3 AV', 'BEACH 105 ST', 'BLEECKER ST', 'JKSN HT-ROOSVLT', 'PATH NEW WTC', 'V.CORTLANDT PK', 'MYRTLE-WYCKOFF', '233 ST', '55 ST', 'GRD CNTRL-42 ST', '8 AV', '28 ST', '57 ST', 'ROCKAWAY AV', 'CROWN HTS-UTICA', 'THIRTY THIRD ST', 'SPRING ST', 'GRAND ST', '25 AV', 'NEWKIRK PLAZA', '2 AV', '50 ST', 'PROSPECT AV', 'HOYT ST', 'SARATOGA AV', 'PARKSIDE AV', 'ASTORIA BLVD', '86 ST', 'UTICA AV', '71 ST', 'SUTPHIN-ARCHER', 'WALL ST', 'EUCLID AV', 'COURT SQ', 'YORK ST', '176 ST', 'WESTCHESTER SQ', '33 ST-RAWSON ST', 'SUTPHIN BLVD', '75 AV', '5 AV/53 ST', 'PARSONS BLVD', 'CANARSIE-ROCKAW', '7 AV', 'HIGH ST', 'STEINWAY ST', 'CORTELYOU RD', '215 ST', 'INTERVALE AV', '167 ST', '225 ST', 'LAFAYETTE AV', 'MYRTLE-WILLOUGH', '137 ST CITY COL', 'ALABAMA AV', '190 ST', '125 ST', 'WAKEFIELD/241', '75 ST-ELDERTS', '231 ST', 'AVENUE J', 'BAY 50 ST', 'ROCKAWAY PARK B', 'KINGSTON AV', 'GROVE STREET', 'FLATBUSH AV-B.C', '3 AV 138 ST', 'FLUSHING AV', 'LEXINGTON AV/53', '182-183 STS', 'LACKAWANNA', 'LIBERTY AV', '34 ST-HUDSON YD', 'HUNTERS PT AV', 'QUEENSBORO PLZ', 'KINGS HWY', '155 ST', '65 ST', '18 ST', 'BRIGHTON BEACH', 'MORISN AV/SNDVW', 'BAY PKWY', '34 ST-HERALD SQ', 'NORWOOD 205 ST', 'WOODLAWN', 'FAR ROCKAWAY', 'NEWKIRK AV', 'GREENPOINT AV', 'FRANKLIN AV', '161/YANKEE STAD', 'BROAD CHANNEL', 'BURNSIDE AV', '46 ST BLISS ST', 'BEVERLY RD', '8 ST-NYU', 'CLARK ST', 'LEXINGTON AV/63', '1 AV', 'VAN SICLEN AV', '4AV-9 ST', '9 AV', 'BRONX PARK EAST', 'MORRIS PARK', '14 ST-UNION SQ', 'JAMAICA CENTER', 'ELDER AV', 'BROOK AV', 'FOREST AVE', 'E 149 ST', '85 ST-FOREST PK', 'DELANCEY/ESSEX', 'BOWLING GREEN', '14 ST', 'SUTTER AV', 'CASTLE HILL AV', 'BEVERLEY ROAD', '49 ST', 'EXCHANGE PLACE', 'MYRTLE AV', 'NEWARK HW BMEBE', '45 ST', '103 ST', 'AQUEDUCT N.COND', '25 ST', 'MARCY AV', 'NASSAU AV', '52 ST', 'CHAUNCEY ST', 'BAY RIDGE-95 ST', '59 ST COLUMBUS', 'ALLERTON AV', 'CANAL ST', 'MONTROSE AV', 'WHITLOCK AV', 'BUSHWICK AV', 'RECTOR ST', 'RIT-MANHATTAN', 'CITY HALL', 'TREMONT AV', 'NEWARK C', 'WEST FARMS SQ', '181 ST', 'KINGSTON-THROOP', 'W 8 ST-AQUARIUM', 'WILSON AV', '183 ST', '219 ST', 'SENECA AVE', 'AVENUE X', '14TH STREET', 'CATHEDRAL PKWY', 'FT HAMILTON PKY', 'ORCHARD BEACH', 'CHURCH AV', 'NORWOOD AV', '42 ST-PORT  ...
# 376

# %% [markdown]
# 5.Okay, so we understand what station represents. But what the heck are C/A, UNIT, and SCP? Keep in mind that in the larger stations, you might have multiple areas within one station that look like this:
#
# <img src="image.jpg" style="width: 300px;"/>
#
# Further complicating things, there are a few station names like 14TH ST that refer to more than one station location along that street.
#
# This data set is not very well documented. Welcome to the joys of real world data science!!!
#
# Read the following two links carefully to see other people's confusion and what information they have been able to gather:
#
# https://groups.google.com/forum/#!topic/mtadeveloperresources/AMVx2WUY9iI
#
# https://groups.google.com/forum/#!searchin/mtadeveloperresources/%22remote$20unit%22%7Csort:relevance/mtadeveloperresources/z8l3ZU9cY6Y/OFlHGkFAimQJ
#
# What did Patrick O'Hara and Katie Toth have to say?

# %%
#insert 6

# %% [markdown]
# 6.To simplify our calculations right now, let's only look at ridership on Monday, June 12th, 2017. In one line, create a dataset called monday that just includes the dates listed as 06/12/2017.
#
# Then, use the command "monday = monday.reset_index(drop=True)" to reset the index.

# %%
monday = df[df.DATE == '06/12/2017']
monday = monday.reset_index(drop=True)
monday.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/12/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/12/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/12/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/12/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/12/2017  16:00:00
#
#       DESC  ENTRIES    EXITS
# 0  REGULAR  6217322  2104727
# 1  REGULAR  6217332  2104729
# 2  REGULAR  6217372  2104813
# 3  REGULAR  6217540  2105024
# 4  REGULAR  6217825  2105081

# %% [markdown]
# 7.Create a dictionary called monday_dict mapping the tuple (C/A, UNIT,SCP, STATION) to a list of tuples containing (TIME,EXITS).
#
# For example, the key ('A002', 'R051', '02-00'00','59 ST') in your dictionary should give the value:
#
# [('00:00:00', 2104727),
#  ('04:00:00', 2104729),
#  ('08:00:00', 2104813),
#  ('12:00:00', 2105024),
#  ('16:00:00', 2105081),
#  ('20:00:00', 2105134)]
#
# Hint: if you need help, google "python dictionary within dictionary" and read the first few StackOverflow hits.

# %%
monday_dict={}
for i in range(len(monday.index)):
    mytuple = (monday['C/A'][i], monday.UNIT[i], monday.SCP[i], monday.STATION[i], )
    if mytuple not in monday_dict.keys():
        monday_dict[mytuple]=[(monday.TIME[i],monday.EXITS[i])]
    else:
        monday_dict[mytuple].append((monday.TIME[i],monday.EXITS[i]))
monday_dict[('A002', 'R051', '02-00-00','59 ST')]
# Out:
# [('00:00:00', 2104727),
#  ('04:00:00', 2104729),
#  ('08:00:00', 2104813),
#  ('12:00:00', 2105024),
#  ('16:00:00', 2105081),
#  ('20:00:00', 2105134)]

# %% [markdown]
# 8.Note: as you get more comfortable with pandas, you will rely more on built-in pandas capabilities and less on creating dictionaries from scratch. For example, run the following lines of code to verify that this dataframe gives you the same info that you got in Exercise 7.

# %%
x=monday.groupby(['C/A', 'UNIT', 'SCP', 'STATION']).groups #the keys are the station pairs and the values are the row indices
flds = ['TIME','EXITS'] #we want to make values out of the remaining columns
monday_exits = {key: monday.loc[val,flds] for key, val in x.items()}
monday_exits[('A002', 'R051', '02-00-00','59 ST')]
# Out:
#        TIME    EXITS
# 0  00:00:00  2104727
# 1  04:00:00  2104729
# 2  08:00:00  2104813
# 3  12:00:00  2105024
# 4  16:00:00  2105081
# 5  20:00:00  2105134

# %% [markdown]
# 9.What the heck do these exit numbers represent? We can assume that they represent some sort of counter on the turnstile. We can subtract the exits at t=20 minus t=0 to figure out how many riders exited this turnstile between 8 pm for two consecutive nights.
#
# Can we calculate 20 - 0 for all of the stations? No! Unfortunately, the time increments aren't standardized. Many of the times are listed in 4 hour intervals of midnight, 4 am, 8 am, etc but not all. Make a frequency chart of the times for the monday dataframe from Exercise 6.

# %%
monday.TIME.value_counts()[0:50]
# Out:
# 00:00:00    2409
# 20:00:00    2408
# 12:00:00    2408
# 08:00:00    2407
# 16:00:00    2405
# 04:00:00    2405
# 17:00:00    1741
# 01:00:00    1740
# 13:00:00    1740
# 05:00:00    1740
# 09:00:00    1739
# 21:00:00    1738
# 06:00:00     110
# 14:00:00     110
# 22:00:00     110
# 02:00:00     110
# 18:00:00     110
# 10:00:00     110
# 23:00:00      39
# 19:00:00      39
# 03:00:00      39
# 11:00:00      39
# 15:00:00      39
# 07:00:00      39
# 08:22:00      37
# 00:22:00      37
# 20:22:00      37
# 16:22:00      37
# 04:22:00      37
# 12:22:00      37
# 18:30:00      20
# 22:30:00      20
# 02:30:00      20
# 06:30:00      20
# 14:30:00      20
# 10:30:00      20
# 08:13:24      15
# 08:13:06      15
# 08:13:33      14
# 08:17:17      13
# 08:30:00      12
# 16:30:00      12
# 00:30:00      12
# 20:30:00      12
# 04:30:00      12
# 12:30:00      12
# 08:17:40      12
# 09:07:07      11
# 09:00:20      11
# 09:03:04      11
# Name: TIME, dtype: int64

# %% [markdown]
# 10.Use your monday_dict from Exercise 7 to create a dictionary called monday_dict_diff that maps (C/A, UNIT, SCP, STATION) to the differences in exits between two consective times in order to see how many people exited through a turnstile within a given time interval.
#
# For example, the key ('A002', 'R051', '02-00-00','59 ST') should map to:
#
# [('04:00:00', 2),
#  ('08:00:00', 84),
#  ('12:00:00', 211),
#  ('16:00:00', 57),
#  ('20:00:00', 53)]

# %%
monday_diff_dict = {}
for key,values in monday_dict.items():
    for i in range(1,len(values)):
        if key not in monday_diff_dict:
            monday_diff_dict[key] = [(values[i][0], values[i][1]-values[i-1][1])]
        else:
            monday_diff_dict[key].append((values[i][0], values[i][1]-values[i-1][1]))
monday_diff_dict[('A002', 'R051', '02-00-00','59 ST')]
# Out:
# [('04:00:00', 2),
#  ('08:00:00', 84),
#  ('12:00:00', 211),
#  ('16:00:00', 57),
#  ('20:00:00', 53)]

# %% [markdown]
# 11.Once again, note that pandas can do the above calculation for you. If you used the monday_exits dataframe from Exercise 8, run the following code to verify that you obtain what you just got in Exercise 10.

# %%
monday_diff = {}

for turnstile, slice_df in monday_exits.items():
    diff = slice_df['EXITS'].diff().values #calculates the exit difference between each entry
    monday_diff[turnstile] = pd.Series(diff, index=slice_df['TIME'].values) #maps turnstile to (time, exit difference) pairs
    for i,(key, val) in enumerate(monday_diff[turnstile].items()):
        try: #need a try because you'll get an error for NAN difference values since there is one less difference than the number of times
            monday_exits[turnstile].at[i,'EXITS'] = val
        except:
            continue
    monday_exits[turnstile] = monday_exits[turnstile].drop(0)    #drop the first time because you only calculate differences after the second time.                   
    
monday_exits[('A002', 'R051', '02-00-00', '59 ST')]
# Out:
#        TIME  EXITS
# 1  04:00:00      2
# 2  08:00:00     84
# 3  12:00:00    211
# 4  16:00:00     57
# 5  20:00:00     53

# %% [markdown]
# 12.Find how many people in total passed through a given turnstile between the hours given for 06/12/2017. For example, if a turnstile is on increments of 0,4,8,...,20, then you want to find out how many total people passed through between midnight and 8 pm. Create a dictionary called total_turnstile that maps (C/A,UNIT,SCP,STATION) to total Monday ridership. Use your dictionary from Exercise 10.
#
# Hint: the key ('A002', 'R051', '02-00-00', '59 ST') should map to 407 total riders.

# %%
total_turnstile = {}
for turnstile, times in monday_diff_dict.items():
    total_turnstile[turnstile]=sum(time[1] for time in times)
total_turnstile[('A002', 'R051', '02-00-00', '59 ST')]
# Out:
# 407

# %% [markdown]
# 13.Use your work in Exercise 12 to create a dictionary called total_riders that maps the (C/A, UNIT, STATION) location to all riders that passed through ALL of the turnstiles in that area on Monday.
#
# Hint 1: use get
#
# Hint 2: ('A002', 'R051', '59 ST') should have 6704 total riders.

# %%
total_riders = {}
for turnstile, exits in total_turnstile.items():
    mytuple = (turnstile[0], turnstile[1], turnstile[3])
    total_riders[mytuple] = total_riders.get(mytuple,0)+exits
total_riders[('A002', 'R051', '59 ST')]
# Out:
# 6704

# %% [markdown]
# 14.Create a list of tuples called tuple_list using your total_riders dictionary so that you can sort the list in decending order to see busiest stations. Hint: the busiest area should be in a PATH World Trade Center station.

# %%
tuple_list = []
for key,val in total_riders.items():
    tuple_list.append((val,key))
tuple_list.sort(reverse=True)
tuple_list
# Out:
# [(56297, ('PTH22', 'R540', 'PATH NEW WTC')),
#  (50291, ('R238', 'R046', 'GRD CNTRL-42 ST')),
#  (39654, ('R240', 'R047', 'GRD CNTRL-42 ST')),
#  (31126, ('R249', 'R179', '86 ST')),
#  (27180, ('N500', 'R020', '47-50 STS ROCK')),
#  (26181, ('R138', 'R293', '34 ST-PENN STA')),
#  (25527, ('A025', 'R023', '34 ST-HERALD SQ')),
#  (24776, ('R533', 'R055', 'FLUSHING-MAIN')),
#  (24129, ('R221', 'R170', '14 ST-UNION SQ')),
#  (24085, ('N507', 'R023', '34 ST-HERALD SQ')),
#  (24053, ('N506', 'R022', '34 ST-HERALD SQ')),
#  (24049, ('N049', 'R084', '59 ST COLUMBUS')),
#  (23536, ('H009', 'R235', 'BEDFORD AV')),
#  (23504, ('A034', 'R170', '14 ST-UNION SQ')),
#  (23196, ('N306', 'R017', 'LEXINGTON AV/53')),
#  (23123, ('N083', 'R138', 'W 4 ST-WASH SQ')),
#  (22670, ('N324', 'R018', 'JKSN HT-ROOSVLT')),
#  (22189, ('N063A', 'R011', '42 ST-PORT AUTH')),
#  (22075, ('N501', 'R020', '47-50 STS ROCK')),
#  (21168, ('R258', 'R132', '125 ST')),
#  (20911, ('R169', 'R168', '96 ST')),
#  (20589, ('A033', 'R170', '14 ST-UNION SQ')),
#  (20076, ('R151', 'R033', 'TIMES SQ-42 ST')),
#  (19889, ('PTH06', 'R546', 'PAVONIA/NEWPORT')),
#  (19870, ('PTH17', 'R541', 'THIRTY THIRD ST')),
#  (19814, ('R236', 'R045', 'GRD CNTRL-42 ST')),
#  (19367, ('A021', 'R032', 'TIMES SQ-42 ST')),
#  (19271, ('PTH20', 'R549', 'NEWARK HM HE')),
#  (19260, ('N606', 'R025', 'JAMAICA CENTER')),
#  (19161, ('PTH04', 'R551', 'GROVE STREET')),
#  (19090, ('N504', 'R021', '42 ST-BRYANT PK')),
#  (18894, ('R247', 'R178', '77 ST')),
#  (18671, ('N067', 'R012', '34 ST-PENN STA')),
#  (18496, ('R116', 'R030', 'CHAMBERS ST')),
#  (18491, ('N051', 'R084', '59 ST COLUMBUS')),
#  (18132, ('R610', 'R057', 'ATL AV-BARCLAY')),
#  (17924, ('N505', 'R022', '34 ST-HERALD SQ')),
#  (17543, ('R206', 'R014', 'FULTON ST')),
#  (17058, ('R135', 'R031', '34 ST-PENN STA')),
#  (16808, ('N605', 'R024', 'SUTPHIN-ARCHER')),
#  (16332, ('PTH05', 'R543', 'EXCHANGE PLACE')),
#  (16073, ('A046', 'R463', 'CANAL ST')),
#  (16069, ('R101', 'R001', 'SOUTH FERRY')),
#  (15975, ('R246', 'R177', '68ST-HUNTER CO')),
#  (15842, ('R523', 'R147', '61 ST WOODSIDE')),
#  (15761, ('R161B', 'R452', '72 ST')),
#  (15604, ('R526', 'R096', '82 ST-JACKSON H')),
#  (15369, ('PTH07', 'R550', 'CITY / BUS')),
#  (15354, ('N303', 'R015', '5 AV/53 ST')),
#  (15312, ('R145', 'R032', 'TIMES SQ-42 ST')),
#  (15311, ('N026', 'R102', '125 ST')),
#  (15209, ('R417', 'R222', 'PARKCHESTER')),
#  (15189, ('N336', 'R158', 'KEW GARDENS')),
#  (14887, ('N519', 'R461', "B'WAY-LAFAYETTE")),
#  (14793, ('R528', 'R097', 'JUNCTION BLVD')),
#  (14219, ('N700', 'R570', '72 ST-2 AVE')),
#  (14214, ('R143', 'R032', 'TIMES SQ-42 ST')),
#  (13967, ('A043', 'R462', 'CANAL ST')),
#  (13952, ('R202', 'R042', 'BOWLING GREEN')),
#  (13934, ('N520', 'R240', 'GRAND ST')),
#  (13920, ('N073', 'R013', '34 ST-PENN STA')),
#  (13916, ('N503', 'R021', '42 ST-BRYANT PK')),
#  (13586, ('R626', 'R062', 'CROWN HTS-UTICA')),
#  (13442, ('N305', 'R017', 'LEXINGTON AV/53')),
#  (13093, ('N304', 'R015', '5 AV/53 ST')),
#  (13014, ('N062A', 'R010', '42 ST-PORT AUTH')),
#  (12945, ('R182', 'R035', '168 ST')),
#  (12901, ('N020', 'R101', '145 ST')),
#  (12688, ('N508', 'R453', '23 ST')),
#  (12645, ('R245A', 'R051', '59 ST')),
#  (12450, ('R155', 'R116', '50 ST')),
#  (12232, ('H008', 'R248', '1 AV')),
#  (12130, ('H001', 'R175', '8 AV')),
#  (11951, ('PTH13', 'R541', 'THIRTY ST')),
#  (11948, ('R243', 'R049', '51 ST')),
#  (11948, ('N098', 'R028', 'FULTON ST')),
#  (11942, ('R534', 'R055', 'FLUSHING-MAIN')),
#  (11883, ('N600', 'R302', '57 ST')),
#  (11850, ('D002', 'R390', '8 AV')),
#  (11811, ('PTH12', 'R542', 'TWENTY THIRD ST')),
#  (11630, ('PTH16', 'R550', 'LACKAWANNA')),
#  (11580, ('R515', 'R095', 'ASTORIA DITMARS')),
#  (11362, ('R220', 'R160', 'ASTOR PL')),
#  (11311, ('R529', 'R208', '103 ST-CORONA')),
#  (11258, ('N519A', 'R461', "B'WAY-LAFAYETTE")),
#  (11207, ('N501A', 'R020', '47-50 STS ROCK')),
#  (11200, ('N329', 'R201', 'WOODHAVEN BLVD')),
#  (11144, ('R501', 'R054', '5 AVE')),
#  (11136, ('R168A', 'R168', '96 ST')),
#  (11064, ('N335', 'R158', 'KEW GARDENS')),
#  (10999, ('R244', 'R050', '59 ST')),
#  (10997, ('R210', 'R044', 'BROOKLYN BRIDGE')),
#  (10820, ('N060', 'R010', '42 ST-PORT AUTH')),
#  (10769, ('C009', 'R057', 'ATL AV-BARCLAY')),
#  (10766, ('R252', 'R180', '103 ST')),
#  (10704, ('B016', 'R098', 'CHURCH AV')),
#  (10670, ('N078', 'R175', '14 ST')),
#  (10639, ('N080', 'R138', 'W 4 ST-WASH SQ')),
#  (10558, ('R161A', 'R452', '72 ST')),
#  (10528, ('R165', 'R167', '86 ST')),
#  (10393, ('A060', 'R001', 'WHITEHALL S-FRY')),
#  (10380, ('R550', 'R072', '34 ST-HUDSON YD')),
#  (10367, ('A022', 'R022', '34 ST-HERALD SQ')),
#  (10328, ('R154', 'R116', '50 ST')),
#  (10297, ('N301', 'R113', '7 AV')),
#  (10265, ('A049', 'R088', 'CORTLANDT ST')),
#  (10222, ('N509', 'R203', '23 ST')),
#  (10197, ('N095A', 'R014', 'FULTON ST')),
#  (10137, ('A035', 'R170', '14 ST-UNION SQ')),
#  (10005, ('R159', 'R164', '66 ST-LINCOLN')),
#  (9861, ('R183', 'R260', '181 ST')),
#  (9839, ('N092', 'R029', 'CHAMBERS ST')),
#  (9718, ('N103', 'R127', 'JAY ST-METROTEC')),
#  (9686, ('R158', 'R084', '59 ST COLUMBUS')),
#  (9481, ('N700A', 'R570', '72 ST-2 AVE')),
#  (9429, ('B027', 'R136', 'SHEEPSHEAD BAY')),
#  (9397, ('R204', 'R043', 'WALL ST')),
#  (9365, ('N102', 'R127', 'JAY ST-METROTEC')),
#  (9362, ('N089', 'R139', 'CANAL ST')),
#  (9337, ('N094', 'R029', 'WORLD TRADE CTR')),
#  (9325, ('R111', 'R027', 'WALL ST')),
#  (9281, ('R532H', 'R328', 'METS-WILLETS PT')),
#  (9268, ('R226', 'R131', '23 ST')),
#  (9080, ('R602', 'R108', 'BOROUGH HALL')),
#  (9080, ('R228', 'R143', '28 ST')),
#  (9073, ('N601', 'R319', 'LEXINGTON AV/63')),
#  (9019, ('R142', 'R293', '34 ST-PENN STA')),
#  (9007, ('N072', 'R012', '34 ST-PENN STA')),
#  (8926, ('N607', 'R025', 'JAMAICA CENTER')),
#  (8863, ('R513', 'R093', '30 AV')),
#  (8836, ('G001', 'R151', 'CONEY IS-STILLW')),
#  (8802, ('R244A', 'R050', '59 ST')),
#  (8799, ('B019', 'R149', 'NEWKIRK PLAZA')),
#  (8779, ('N701A', 'R571', '86 ST-2 AVE')),
#  (8730, ('N305A', 'R016', 'LEXINGTON AV/53')),
#  (8714, ('R216', 'R322', 'SPRING ST')),
#  (8697, ('N062', 'R011', '42 ST-PORT AUTH')),
#  (8673, ('R601A', 'R108', 'BOROUGH HALL')),
#  (8652, ('N300', 'R113', '7 AV')),
#  (8561, ('N095', 'R014', 'FULTON ST')),
#  (8486, ('R201', 'R041', 'BOWLING GREEN')),
#  (8485, ('PTH01', 'R549', 'NEWARK HW BMEBE')),
#  (8347, ('N044', 'R187', '81 ST-MUSEUM')),
#  (8346, ('B004', 'R171', '7 AV')),
#  (8345, ('PTH02', 'R544', 'HARRISON')),
#  (8317, ('R229', 'R143', '28 ST')),
#  (8159, ('N523', 'R300', '2 AV')),
#  (8135, ('R232', 'R176', '33 ST')),
#  (8080, ('A042', 'R086', 'PRINCE ST')),
#  (8050, ('N601A', 'R319', 'LEXINGTON AV/63')),
#  (7927, ('N323', 'R018', 'JKSN HT-ROOSVLT')),
#  (7908, ('N108', 'R217', 'HOYT-SCHER')),
#  (7901, ('N327', 'R254', 'GRAND-NEWTOWN')),
#  (7882, ('R237', 'R046', 'GRD CNTRL-42 ST')),
#  (7826, ('N091', 'R029', 'CHAMBERS ST')),
#  (7811, ('R283', 'R221', '167 ST')),
#  (7742, ('PTH21', 'R540', 'PATH WTC 2')),
#  (7678, ('R518', 'R261', '40 ST LOWERY ST')),
#  (7649, ('JFK03', 'R536', 'JFK JAMAICA CT1')),
#  (7647, ('R185', 'R274', '191 ST')),
#  (7607, ('R412', 'R146', 'HUNTS POINT AV')),
#  (7574, ('R132', 'R190', '23 ST')),
#  (7559, ('R512', 'R092', 'BROADWAY')),
#  (7495, ('R147', 'R033', 'TIMES SQ-42 ST')),
#  (7443, ('R175', 'R169', '137 ST CITY COL')),
#  (7437, ('R516', 'R291', '33 ST-RAWSON ST')),
#  (7433, ('C008', 'R099', 'DEKALB AV')),
#  (7422, ('R331', 'R364', 'GUN HILL RD')),
#  (7412, ('R503', 'R276', 'VERNON-JACKSON')),
#  (7277, ('B024A', 'R211', 'KINGS HWY')),
#  (7231, ('A029', 'R082', '28 ST')),
#  (7223, ('N512', 'R163', '14 ST')),
#  (7208, ('N333B', 'R141', 'FOREST HILLS 71')),
#  (7204, ('N046', 'R281', '72 ST')),
#  (7168, ('R519', 'R223', '46 ST BLISS ST')),
#  (7153, ('PTH11', 'R545', '14TH STREET')),
#  (7135, ('R110', 'R027', 'WALL ST')),
#  (7116, ('N701', 'R571', '86 ST-2 AVE')),
#  (7098, ('R113', 'R028', 'FULTON ST')),
#  (7070, ('A006', 'R079', '5 AV/59 ST')),
#  (7065, ('R148', 'R033', 'TIMES SQ-42 ST')),
#  (7033, ('A013', 'R081', '49 ST')),
#  (7030, ('N124', 'R103', 'BROADWAY JCT')),
#  (7005, ('R242', 'R049', '51 ST')),
#  (6934, ('R237B', 'R047', 'GRD CNTRL-42 ST')),
#  (6932, ('N071', 'R013', '34 ST-PENN STA')),
#  (6841, ('H007', 'R248', '1 AV')),
#  (6839, ('A039', 'R085', '8 ST-NYU')),
#  (6836, ('C018', 'R197', '36 ST')),
#  (6704, ('A002', 'R051', '59 ST')),
#  (6700, ('N120', 'R153', 'UTICA AV')),
#  (6646, ('R514', 'R094', 'ASTORIA BLVD')),
#  (6613, ('C012', 'R258', '4AV-9 ST')),
#  (6528, ('G009', 'R151', 'CONEY IS-STILLW')),
#  (6520, ('N077', 'R111', '23 ST')),
#  (6506, ('N400A', 'R359', 'COURT SQ')),
#  (6473, ('R248', 'R178', '77 ST')),
#  (6461, ('R301', 'R323', 'CENTRAL PK N110')),
#  (6432, ('R173', 'R159', '116 ST-COLUMBIA')),
#  (6421, ('R527', 'R122', '90 ST-ELMHURST')),
#  (6421, ('R507', 'R134', 'HUNTERS PT AV')),
#  (6411, ('J002', 'R460', 'MARCY AV')),
#  (6377, ('D010', 'R394', 'BAY PKWY')),
#  (6337, ('N056', 'R188', '50 ST')),
#  (6333, ('R141', 'R031', '34 ST-PENN STA')),
#  (6331, ('E014', 'R374', 'BAY PKWY')),
#  (6297, ('A010', 'R080', '57 ST-7 AV')),
#  (6296, ('N525', 'R142', 'DELANCEY/ESSEX')),
#  (6279, ('R174', 'R034', '125 ST')),
#  (6255, ('N502', 'R021', '42 ST-BRYANT PK')),
#  (6244, ('N309A', 'R140', 'QUEENS PLAZA')),
#  (6230, ('N076', 'R111', '23 ST')),
#  (6191, ('J009', 'R378', 'MYRTLE AV')),
#  (6179, ('R200A', 'R041', 'BOWLING GREEN')),
#  (6175, ('A031', 'R083', '23 ST')),
#  (6163, ('R612', 'R057', 'ATL AV-BARCLAY')),
#  (6163, ('N070', 'R012', '34 ST-PENN STA')),
#  (6143, ('N090', 'R139', 'CANAL ST')),
#  (6116, ('R261', 'R205', '149/GRAND CONC')),
#  (6108, ('N702', 'R572', '96 ST-2 AVE')),
#  (5975, ('A030', 'R083', '23 ST')),
#  (5968, ('B031', 'R172', 'BRIGHTON BEACH')),
#  (5919, ('N117', 'R198', 'NOSTRAND AV')),
#  (5887, ('R284', 'R243', '170 ST')),
#  (5885, ('B024', 'R211', 'KINGS HWY')),
#  (5875, ('N702A', 'R572', '96 ST-2 AVE')),
#  (5861, ('R530', 'R310', '111 ST')),
#  (5857, ('N141', 'R356', 'OZONE PK LEFFRT')),
#  (5852, ('N539A', 'R288', '7 AV')),
#  (5837, ('A058', 'R001', 'WHITEHALL S-FRY')),
#  (5798, ('R124', 'R290', 'HOUSTON ST')),
#  (5756, ('A037', 'R170', '14 ST-UNION SQ')),
#  (5753, ('N063', 'R011', '42 ST-PORT AUTH')),
#  (5651, ('N315', 'R238', 'STEINWAY ST')),
#  (5615, ('R418', 'R106', 'CASTLE HILL AV')),
#  (5594, ('N603', 'R303', '21 ST-QNSBRIDGE')),
#  (5594, ('A061', 'R142', 'DELANCEY/ESSEX')),
#  (5585, ('R325', 'R388', 'E 180 ST')),
#  (5526, ('R126', 'R189', 'CHRISTOPHER ST')),
#  (5514, ('R127', 'R105', '14 ST')),
#  (5503, ('R231A', 'R176', '33 ST')),
#  (5456, ('R250', 'R179', '86 ST')),
#  (5450, ('A015', 'R081', '49 ST')),
#  (5437, ('R170', 'R191', '103 ST')),
#  (5415, ('C025', 'R215', '86 ST')),
#  (5414, ('PTH09', 'R548', 'CHRISTOPHER ST')),
#  (5398, ('R231', 'R176', '33 ST')),
#  (5371, ('N405', 'R239', 'GREENPOINT AV')),
#  (5352, ('R521', 'R327', '52 ST')),
#  (5342, ('R414', 'R162', 'ELDER AV')),
#  (5292, ('K025', 'R404', 'FRESH POND RD')),
#  (5269, ('A081', 'R028', 'FULTON ST')),
#  (5207, ('R622', 'R123', 'FRANKLIN AV')),
#  (5207, ('R420', 'R107', 'WESTCHESTER SQ')),
#  (5207, ('A027', 'R082', '28 ST')),
#  (5201, ('N602', 'R259', 'ROOSEVELT ISLND')),
#  (5163, ('N213', 'R154', 'TREMONT AV')),
#  (5146, ('R508', 'R346', 'COURT SQ')),
#  (5115, ('H027', 'R137', 'MYRTLE-WYCKOFF')),
#  (5101, ('N019', 'R101', '145 ST')),
#  (5076, ('R112', 'R027', 'WALL ST')),
#  (5048, ('R608', 'R056', 'NEVINS ST')),
#  (5027, ('N010', 'R126', '175 ST')),
#  (4991, ('R253', 'R181', '110 ST')),
#  (4985, ('N217', 'R112', 'FORDHAM RD')),
#  (4963, ('R625', 'R062', 'CROWN HTS-UTICA')),
#  (4953, ('R134', 'R272', '28 ST')),
#  (4948, ('N536', 'R270', 'SMITH-9 ST')),
#  (4908, ('R210A', 'R044', 'BROOKLYN BRIDGE')),
#  (4900, ('N339A', 'R114', 'PARSONS BLVD')),
#  (4860, ('R311', 'R053', '3 AV-149 ST')),
#  (4851, ('R251', 'R144', '96 ST')),
#  (4847, ('R217A', 'R194', 'BLEECKER ST')),
#  (4835, ('H026', 'R137', 'MYRTLE-WYCKOFF')),
#  (4829, ('E001', 'R368', '9 AV')),
#  (4801, ('N604', 'R342', 'JAMAICA VAN WK')),
#  (4794, ('R401', 'R445', '3 AV 138 ST')),
#  (4783, ('R629', 'R065', 'ROCKAWAY AV')),
#  (4777, ('R524', 'R347', '69 ST')),
#  (4765, ('N521', 'R300', '2 AV')),
#  (4759, ('R208', 'R014', 'FULTON ST')),
#  (4758, ('R114', 'R028', 'FULTON ST')),
#  (4748, ('R628', 'R064', 'SARATOGA AV')),
#  (4696, ('R336', 'R145', 'WAKEFIELD/241')),
#  (4695, ('R634', 'R069', 'NEW LOTS AV')),
#  (4671, ('N537', 'R258', '4 AV-9 ST')),
#  (4659, ('N546', 'R204', 'CHURCH AV')),
#  (4628, ('PTH10', 'R547', '9TH STREET')),
#  (4615, ('R290', 'R161', 'KINGSBRIDGE RD')),
#  (4601, ('N330', 'R202', '63 DR-REGO PARK')),
#  (4584, ('N343', 'R019', 'JAMAICA 179 ST')),
#  (4569, ('R160A', 'R164', '66 ST-LINCOLN')),
#  (4564, ('A014', 'R081', '49 ST')),
#  (4559, ('R160', 'R164', '66 ST-LINCOLN')),
#  (4517, ('R112A', 'R027', 'WALL ST')),
#  (4514, ('H014', 'R249', 'GRAHAM AV')),
#  (4490, ('R219', 'R160', 'ASTOR PL')),
#  (4468, ('R256', 'R182', '116 ST')),
#  (4468, ('N526', 'R142', 'DELANCEY/ESSEX')),
#  (4423, ('N196', 'R285', 'FAR ROCKAWAY')),
#  (4410, ('H016', 'R250', 'GRAND ST')),
#  (4409, ('J024', 'R437', 'CRESCENT ST')),
#  (4406, ('R415', 'R120', 'MORISN AV/SNDVW')),
#  (4394, ('R511', 'R091', '36 AV')),
#  (4345, ('R423', 'R429', 'PELHAM BAY PARK')),
#  (4315, ('N069', 'R013', '34 ST-PENN STA')),
#  (4306, ('N530', 'R301', 'YORK ST')),
#  (4286, ('B013', 'R196', 'PROSPECT PARK')),
#  (4279, ('R287', 'R244', 'BURNSIDE AV')),
#  (4263, ('R164', 'R167', '86 ST')),
#  (4263, ('C019', 'R232', '45 ST')),
#  (4250, ('R179', 'R193', '157 ST')),
#  (4240, ('N114', 'R297', 'FRANKLIN AV')),
#  (4232, ('N043', 'R186', '86 ST')),
#  (4215, ('R645', 'R110', 'FLATBUSH AV-B.C')),
#  (4210, ('R730', 'R431', 'EASTCHSTER/DYRE')),
#  (4210, ('R177', 'R273', '145 ST')),
#  (4183, ('N409', 'R268', 'METROPOLITAN AV')),
#  (4169, ('R171', 'R192', 'CATHEDRAL PKWY')),
#  (4118, ('H039', 'R375', 'NEW LOTS')),
#  (4110, ('N531', 'R129', 'BERGEN ST')),
#  (4099, ('D003', 'R391', 'FT HAMILTON PKY')),
#  (4075, ('A041', 'R086', 'PRINCE ST')),
#  (4066, ('R137', 'R031', '34 ST-PENN STA')),
#  (4058, ('N129', 'R382', 'GRANT AV')),
#  (4043, ('R102', 'R304', 'RECTOR ST')),
#  (4024, ('N068', 'R012', '34 ST-PENN STA')),
#  (3997, ('N120A', 'R153', 'UTICA AV')),
#  (3967, ('R644', 'R135', 'NEWKIRK AV')),
#  (3967, ('B015', 'R098', 'CHURCH AV')),
#  (3964, ('R609', 'R056', 'NEVINS ST')),
#  (3949, ('N116', 'R198', 'NOSTRAND AV')),
#  (3920, ('R120', 'R320', 'CANAL ST')),
#  (3920, ('N007A', 'R174', '181 ST')),
#  (3919, ('R605', 'R456', 'HOYT ST')),
#  (3885, ('N040', 'R251', '96 ST')),
#  (3881, ('R525', 'R018', '74 ST-BROADWAY')),
#  (3879, ('R245', 'R051', '59 ST')),
#  (3867, ('N419', 'R287', 'CLASSON AV')),
#  (3827, ('R203', 'R043', 'WALL ST')),
#  (3800, ('N510', 'R163', '14 ST')),
#  (3768, ('R635', 'R277', 'PRESIDENT ST')),
#  (3751, ('R509', 'R121', 'QUEENSBORO PLZ')),
#  (3737, ('A047', 'R087', 'CITY HALL')),
#  (3735, ('N333A', 'R141', 'FOREST HILLS 71')),
#  (3696, ('N408A', 'R256', 'NASSAU AV')),
#  (3685, ('N057', 'R188', '50 ST')),
#  (3684, ('A050', 'R088', 'CORTLANDT ST')),
#  (3669, ('N511', 'R163', '14 ST')),
#  (3668, ('N422', 'R318', 'FULTON ST')),
#  (3660, ('B014', 'R148', 'PARKSIDE AV')),
#  (3655, ('R131', 'R190', '23 ST')),
#  (3605, ('N025', 'R102', '125 ST')),
#  (3570, ('R163', 'R166', '79 ST')),
#  (3556, ('R321', 'R386', '174 ST')),
#  (3536, ('B029', 'R172', 'BRIGHTON BEACH')),
#  (3534, ('N205', 'R195', '161/YANKEE STAD')),
#  (3528, ('D005', 'R398', 'NEW UTRECHT AV')),
#  (3514, ('N535', 'R220', 'CARROLL ST')),
#  (3506, ('K019', 'R413', 'KNICKERBOCKER')),
#  (3500, ('R128', 'R105', '14 ST')),
#  (3497, ('R403', 'R446', 'BROOK AV')),
#  (3491, ('N101', 'R252', 'HIGH ST')),
#  (3488, ('R647', 'R110', 'FLATBUSH AV-B.C')),
#  (3488, ('N009', 'R174', '181 ST')),
#  (3460, ('R162', 'R166', '79 ST')),
#  (3446, ('R133', 'R272', '28 ST')),
#  (3427, ('N513', 'R163', '14 ST')),
#  (3415, ('A069', 'R044', 'CHAMBERS ST')),
#  (3405, ('R323', 'R387', 'WEST FARMS SQ')),
#  (3405, ('R242A', 'R049', '51 ST')),
#  (3398, ('N222', 'R156', 'BEDFORD PK BLVD')),
#  (3368, ('R291', 'R183', 'BEDFORD PK BLVD')),
#  (3363, ('N319', 'R298', 'NORTHERN BLVD')),
#  (3342, ('J001', 'R460', 'MARCY AV')),
#  (3312, ('N549', 'R242', '18 AV')),
#  (3305, ('N340', 'R115', '169 ST')),
#  (3290, ('R227A', 'R131', '23 ST')),
#  (3284, ('B012', 'R196', 'PROSPECT PARK')),
#  (3272, ('H040', 'R376', 'EAST 105 ST')),
#  (3263, ('D012', 'R395', 'KINGS HWY')),
#  (3260, ('N417', 'R269', 'BEDFORD-NOSTRAN')),
#  (3259, ('R262', 'R195', '161/YANKEE STAD')),
#  (3244, ('R232A', 'R176', '33 ST')),
#  (3232, ('R186', 'R036', 'DYCKMAN ST')),
#  (3228, ('R621', 'R060', 'EASTN PKWY-MUSM')),
#  (3222, ('H005', 'R330', '3 AV')),
#  (3211, ('R319', 'R409', 'FREEMAN ST')),
#  (3211, ('R285', 'R308', 'MT EDEN AV')),
#  (3208, ('N342', 'R019', 'JAMAICA 179 ST')),
#  (3204, ('A011', 'R080', '57 ST-7 AV')),
#  (3184, ('R624', 'R124', 'KINGSTON AV')),
#  (3179, ('R257', 'R182', '116 ST')),
#  (3171, ('R130', 'R321', '18 ST')),
#  (3171, ('N207', 'R104', '167 ST')),
#  (3140, ('H041', 'R152', 'CANARSIE-ROCKAW')),
#  (3132, ('N203', 'R195', '161/YANKEE STAD')),
#  (3131, ('R422', 'R428', 'BUHRE AV')),
#  (3131, ('A007', 'R079', '5 AV/59 ST')),
#  (3070, ('N316A', 'R267', '46 ST')),
#  (3064, ('H032', 'R295', 'WILSON AV')),
#  (3048, ('C021', 'R212', '59 ST')),
#  (3047, ('N045', 'R187', '81 ST-MUSEUM')),
#  (3032, ('R623', 'R061', 'NOSTRAND AV')),
#  (3012, ('K017', 'R401', 'CENTRAL AV')),
#  (3009, ('N340A', 'R115', '169 ST')),
#  (3008, ('N220', 'R155', 'KINGSBRIDGE RD')),
#  (3001, ('H017', 'R265', 'MONTROSE AV')),
#  (2997, ('R309', 'R345', 'HARLEM 148 ST')),
#  (2991, ('R416', 'R245', 'ST LAWRENCE AV')),
#  (2989, ('A038', 'R085', '8 ST-NYU')),
#  (2987, ('C027', 'R216', 'BAY RIDGE-95 ST')),
#  (2977, ('R205A', 'R014', 'FULTON ST')),
#  (2974, ('R600', 'R224', 'CLARK ST')),
#  (2958, ('N412', 'R299', 'BROADWAY')),
#  (2955, ('N118', 'R199', 'KINGSTON-THROOP')),
#  (2950, ('N037', 'R314', '103 ST')),
#  (2938, ('N557', 'R130', 'KINGS HWY')),
#  (2928, ('N314', 'R238', 'STEINWAY ST')),
#  (2921, ('J023', 'R436', 'NORWOOD AV')),
#  (2919, ('N039', 'R251', '96 ST')),
#  (2915, ('R532', 'R328', 'METS-WILLETS PT')),
#  (2905, ('C011', 'R231', 'UNION ST')),
#  (2904, ('N122', 'R439', 'ROCKAWAY AV')),
#  (2891, ('R304', 'R206', '125 ST')),
#  (2889, ('G011', 'R312', 'W 8 ST-AQUARIUM')),
#  (2884, ('B021', 'R228', 'AVENUE J')),
#  (2880, ('R115', 'R029', 'PARK PLACE')),
#  (2875, ('H023', 'R236', 'DEKALB AV')),
#  (2856, ('R604', 'R108', 'BOROUGH HALL')),
#  (2839, ('E004', 'R234', '50 ST')),
#  (2800, ('N224', 'R157', 'NORWOOD 205 ST')),
#  (2799, ('A066', 'R118', 'CANAL ST')),
#  (2794, ('J022', 'R435', 'CLEVELAND ST')),
#  (2792, ('R316', 'R407', 'INTERVALE AV')),
#  (2792, ('N331', 'R219', '67 AV')),
#  (2766, ('N035', 'R334', 'CATHEDRAL PKWY')),
#  (2763, ('H019', 'R294', 'MORGAN AV')),
#  (2743, ('R303', 'R324', '116 ST')),
#  (2734, ('N128', 'R200', 'EUCLID AV')),
#  (2722, ('R286', 'R309', '176 ST')),
#  (2685, ('A083', 'R125', 'BROAD ST')),
#  (2681, ('J007', 'R377', 'FLUSHING AV')),
#  (2671, ('H037', 'R349', 'SUTTER AV')),
#  (2652, ('R197', 'R117', 'V.CORTLANDT PK')),
#  (2631, ('R188', 'R037', '207 ST')),
#  (2631, ('A016', 'R081', '49 ST')),
#  (2618, ('B022', 'R229', 'AVENUE M')),
#  (2596, ('N528', 'R257', 'EAST BROADWAY')),
#  (2592, ('R636', 'R209', 'STERLING ST')),
#  (2585, ('R293', 'R133', 'MOSHOLU PKWY')),
#  (2575, ('N529', 'R257', 'EAST BROADWAY')),
#  (2571, ('R328', 'R361', 'PELHAM PKWY')),
#  (2570, ('N013', 'R035', '168 ST')),
#  (2567, ('R310', 'R053', '3 AV-149 ST')),
#  (2561, ('R230', 'R143', '28 ST')),
#  (2557, ('R259', 'R307', '138/GRAND CONC')),
#  (2557, ('N317', 'R267', '46 ST')),
#  (2554, ('R288', 'R275', '183 ST')),
#  (2536, ('C017', 'R455', '25 ST')),
#  (2535, ('R254', 'R181', '110 ST')),
#  (2535, ('K024', 'R403', 'FOREST AVE')),
#  (2531, ('N225', 'R157', 'NORWOOD 205 ST')),
#  (2500, ('B025', 'R150', 'AVENUE U')),
#  (2498, ('H006', 'R330', '3 AV')),
#  (2494, ('R226A', 'R131', '23 ST')),
#  (2489, ('R204A', 'R043', 'WALL ST')),
#  (2484, ('A064', 'R311', 'BOWERY')),
#  (2473, ('J021', 'R434', 'VAN SICLEN AV')),
#  (2472, ('R238A', 'R046', 'GRD CNTRL-42 ST')),
#  (2462, ('N191', 'R335', 'BEACH 67 ST')),
#  (2459, ('R619', 'R059', 'GRAND ARMY PLAZ')),
#  (2443, ('R139', 'R031', '34 ST-PENN STA')),
#  (2437, ('B028', 'R136', 'SHEEPSHEAD BAY')),
#  (2433, ('E003', 'R369', 'FT HAMILTON PKY')),
#  (2432, ('N310', 'R140', 'QUEENS PLAZA')),
#  (2427, ('R409', 'R449', 'E 149 ST')),
#  (2416, ('N002A', 'R173', 'INWOOD-207 ST')),
#  (2394, ('N112A', 'R284', 'CLINTON-WASH AV')),
#  (2390, ('H030', 'R266', 'HALSEY ST')),
#  (2379, ('R504', 'R276', 'VERNON-JACKSON')),
#  (2376, ('JFK02', 'R535', 'HOWARD BCH JFK')),
#  (2369, ('R606', 'R225', 'HOYT ST')),
#  (2367, ('R633', 'R068', 'VAN SICLEN AV')),
#  (2352, ('K022', 'R402', 'SENECA AVE')),
#  (2350, ('R118', 'R343', 'FRANKLIN ST')),
#  (2336, ('R176', 'R169', '137 ST CITY COL')),
#  (2334, ('N307', 'R359', 'COURT SQ-23 ST')),
#  (2332, ('N121B', 'R438', 'RALPH AV')),
#  (2312, ('C024', 'R214', '77 ST')),
#  (2301, ('N333', 'R141', 'FOREST HILLS 71')),
#  (2301, ('J016', 'R381', 'HALSEY ST')),
#  (2292, ('B023', 'R211', 'KINGS HWY')),
#  (2262, ('R103', 'R304', 'RECTOR ST')),
#  (2254, ('N325A', 'R218', 'ELMHURST AV')),
#  (2238, ('R305', 'R206', '125 ST')),
#  (2225, ('R307', 'R207', '135 ST')),
#  (2212, ('B017', 'R262', 'BEVERLEY ROAD')),
#  (2208, ('R419', 'R326', 'ZEREGA AV')),
#  (2202, ('N322', 'R340', '65 ST')),
#  (2201, ('J020', 'R433', 'ALABAMA AV')),
#  (2160, ('N542', 'R241', '15 ST-PROSPECT')),
#  (2153, ('N030', 'R333', '116 ST')),
#  (2151, ('N337', 'R255', 'BRIARWOOD')),
#  (2143, ('R123', 'R290', 'HOUSTON ST')),
#  (2128, ('R517', 'R291', '33 ST-RAWSON ST')),
#  (2119, ('R125', 'R189', 'CHRISTOPHER ST')),
#  (2114, ('N221', 'R155', 'KINGSBRIDGE RD')),
#  (2110, ('R726', 'R329', 'MORRIS PARK')),
#  (2104, ('J013', 'R380', 'GATES AV')),
#  (2100, ('B020', 'R263', 'AVENUE H')),
#  (2062, ('R639', 'R109', 'CHURCH AV')),
#  (2062, ('N312', 'R339', '36 ST')),
#  (2058, ('H038', 'R350', 'LIVONIA AV')),
#  (2035, ('B010', 'R412', 'BOTANIC GARDEN')),
#  (1995, ('R727', 'R430', 'PELHAM PKWY')),
#  (1983, ('N338B', 'R128', 'SUTPHIN BLVD')),
#  (1970, ('H003', 'R163', '6 AV')),
#  (1968, ('N415', 'R286', 'MYRTLE-WILLOUGH')),
#  (1967, ('N209', 'R443', '170 ST')),
#  (1943, ('N023', 'R332', '135 ST')),
#  (1941, ('C003', 'R089', 'JAY ST-METROTEC')),
#  (1922, ('R421', 'R427', 'MIDDLETOWN RD')),
#  (1915, ('J028', 'R004', '75 ST-ELDERTS')),
#  (1910, ('R510', 'R090', '39 AV')),
#  (1907, ('R172', 'R192', 'CATHEDRAL PKWY')),
#  (1886, ('K026', 'R100', 'METROPOLITAN AV')),
#  (1884, ('J005', 'R353', 'LORIMER ST')),
#  (1874, ('N561', 'R271', 'AVENUE X')),
#  (1855, ('A077', 'R028', 'FULTON ST')),
#  (1822, ('R632', 'R067', 'PENNSYLVANIA AV')),
#  (1822, ('R329', 'R362', 'ALLERTON AV')),
#  (1821, ('R289', 'R119', 'FORDHAM RD')),
#  (1812, ('N100', 'R252', 'HIGH ST')),
#  (1809, ('J031', 'R006', 'WOODHAVEN BLVD')),
#  (1798, ('E011', 'R371', '79 ST')),
#  (1798, ('D015', 'R396', 'AVENUE U')),
#  (1774, ('R618', 'R058', 'BERGEN ST')),
#  (1767, ('N195', 'R358', 'BEACH 25 ST')),
#  (1757, ('R215', 'R322', 'SPRING ST')),
#  (1755, ('J035', 'R008', '111 ST')),
#  (1750, ('N401', 'R360', '21 ST')),
#  (1732, ('R413', 'R325', 'WHITLOCK AV')),
#  (1712, ('N017', 'R331', '155 ST')),
#  (1704, ('N555', 'R423', 'AVENUE N')),
#  (1703, ('R166', 'R167', '86 ST')),
#  (1699, ('R411', 'R450', 'LONGWOOD AV')),
#  (1699, ('N556', 'R424', 'AVENUE P')),
#  (1694, ('B009', 'R411', 'PARK PLACE')),
#  (1677, ('N318', 'R298', 'NORTHERN BLVD')),
#  (1657, ('R302', 'R324', '116 ST')),
#  (1653, ('B018', 'R184', 'CORTELYOU RD')),
#  (1647, ('N086', 'R282', 'SPRING ST')),
#  (1643, ('N192', 'R336', 'BEACH 60 ST')),
#  (1639, ('N110', 'R283', 'LAFAYETTE AV')),
#  (1636, ('R333', 'R366', '225 ST')),
#  (1631, ('R315', 'R406', 'PROSPECT AV')),
#  (1630, ('R178', 'R273', '145 ST')),
#  (1629, ('N548', 'R420', 'DITMAS AV')),
#  (1603, ('R129', 'R321', '18 ST')),
#  (1597, ('N202', 'R315', '155 ST')),
#  (1555, ('J012', 'R379', 'KOSCIUSZKO ST')),
#  (1546, ('A054', 'R227', 'RECTOR ST')),
#  (1544, ('E012', 'R372', '18 AV')),
#  (1543, ('H015', 'R250', 'GRAND ST')),
#  (1536, ('J030', 'R005', '85 ST-FOREST PK')),
#  (1505, ('N006A', 'R280', '190 ST')),
#  (1493, ('R119', 'R320', 'CANAL ST')),
#  (1489, ('R317', 'R408', 'SIMPSON ST')),
#  (1486, ('N181', 'R357', 'AQUEDUCT N.COND')),
#  (1486, ('E009', 'R370', '71 ST')),
#  (1481, ('N184', 'R416', 'BEACH 90 ST')),
#  (1475, ('R408', 'R449', 'E 149 ST')),
#  (1461, ('H022', 'R279', 'JEFFERSON ST')),
#  (1442, ('C001', 'R108', 'BOROUGH HALL')),
#  (1433, ('R180', 'R193', '157 ST')),
#  (1423, ('N126', 'R441', 'VAN SICLEN AVE')),
#  (1423, ('E013', 'R373', '20 AV')),
#  (1398, ('N414', 'R316', 'FLUSHING AV')),
#  (1389, ('N559', 'R425', 'AVENUE U')),
#  (1371, ('N532', 'R129', 'BERGEN ST')),
#  (1370, ('R334', 'R367', '233 ST')),
#  (1365, ('N127', 'R442', 'SHEPHERD AV')),
#  (1363, ('N024', 'R332', '135 ST')),
#  (1362, ('H028', 'R266', 'HALSEY ST')),
#  (1347, ('N001', 'R173', 'INWOOD-207 ST')),
#  (1336, ('N543', 'R289', 'FT HAMILTON PKY')),
#  (1335, ('R294', 'R052', 'WOODLAWN')),
#  (1320, ('N551', 'R421', 'AVENUE I')),
#  (1305, ('N187', 'R419', 'ROCKAWAY PARK B')),
#  (1304, ('R637', 'R451', 'WINTHROP ST')),
#  (1296, ('R306', 'R207', '135 ST')),
#  (1296, ('N215', 'R237', '182-183 STS')),
#  (1295, ('R405', 'R447', 'CYPRESS AV')),
#  (1280, ('R227', 'R131', '23 ST')),
#  (1278, ('R402', 'R446', 'BROOK AV')),
#  (1258, ('N111', 'R284', 'CLINTON-WASH AV')),
#  (1231, ('H012', 'R268', 'LORIMER ST')),
#  (1216, ('R194', 'R040', '231 ST')),
#  (1213, ('N131', 'R383', '80 ST')),
#  (1210, ('N414A', 'R316', 'FLUSHING AV')),
#  (1206, ('R646', 'R110', 'FLATBUSH AV-B.C')),
#  (1194, ('J003', 'R352', 'HEWES ST')),
#  (1190, ('N125', 'R440', 'LIBERTY AV')),
#  (1185, ('R332', 'R365', '219 ST')),
#  (1181, ('R520', 'R223', '46 ST BLISS ST')),
#  (1179, ('N208', 'R443', '170 ST')),
#  (1174, ('R335', 'R444', 'NEREID AV')),
#  (1170, ('N134', 'R385', 'ROCKAWAY BLVD')),
#  (1163, ('J017', 'R432', 'CHAUNCEY ST')),
#  (1132, ('R728', 'R226', 'GUN HILL RD')),
#  (1132, ('D016', 'R397', '86 ST')),
#  (1130, ('E015', 'R399', '25 AV')),
#  (1122, ('N185', 'R417', 'BEACH 98 ST')),
#  (1114, ('N034', 'R334', 'CATHEDRAL PKWY')),
#  (1108, ('R192', 'R039', 'MARBLE HILL-225')),
#  (1103, ('R404', 'R447', 'CYPRESS AV')),
#  (1099, ('N316', 'R267', '46 ST')),
#  (1087, ('JFK01', 'R535', 'HOWARD BCH JFK')),
#  (1084, ('N541', 'R241', '15 ST-PROSPECT')),
#  (1082, ('N332', 'R219', '67 AV')),
#  (1065, ('N113', 'R297', 'FRANKLIN AV')),
#  (1052, ('B026', 'R230', 'NECK RD')),
#  (1050, ('N075', 'R111', '23 ST')),
#  (1047, ('N133', 'R384', '88 ST')),
#  (1045, ('H033', 'R313', 'BUSHWICK AV')),
#  (1045, ('C010', 'R231', 'UNION ST')),
#  (1040, ('C022', 'R212', '59 ST')),
#  (1032, ('R326', 'R389', 'BRONX PARK EAST')),
#  (1032, ('N011', 'R126', '175 ST')),
#  (1019, ('R122', 'R290', 'HOUSTON ST')),
#  (1013, ('B032', 'R264', 'OCEAN PKWY')),
#  (1011, ('N119', 'R199', 'KINGSTON-THROOP')),
#  (1000, ('R330', 'R363', 'BURKE AV')),
#  (1000, ('N311', 'R339', '36 ST')),
#  (976, ('E005', 'R247', '55 ST')),
#  (974, ('C016', 'R278', '25 ST')),
#  (971, ('N194', 'R338', 'BEACH 36 ST')),
#  (950, ('R410', 'R450', 'LONGWOOD AV')),
#  (922, ('N135', 'R385', 'ROCKAWAY BLVD')),
#  (918, ('N212', 'R253', '174-175 STS')),
#  (912, ('N016A', 'R296', '163 ST-AMSTERDM')),
#  (886, ('N553', 'R422', 'BAY PKWY')),
#  (853, ('N130', 'R383', '80 ST')),
#  (844, ('R312', 'R405', 'JACKSON AV')),
#  (834, ('R117', 'R343', 'FRANKLIN ST')),
#  (828, ('N534', 'R220', 'CARROLL ST')),
#  (820, ('H013', 'R249', 'GRAHAM AV')),
#  (803, ('A071', 'R044', 'CHAMBERS ST')),
#  (790, ('PTH18', 'R549', 'NEWARK BM BW')),
#  (780, ('N210', 'R253', '174-175 STS')),
#  (771, ('N533', 'R129', 'BERGEN ST')),
#  (763, ('R327', 'R361', 'PELHAM PKWY')),
#  (746, ('R190', 'R038', '215 ST')),
#  (738, ('N012', 'R035', '168 ST')),
#  (734, ('J025', 'R003', 'CYPRESS HILLS')),
#  (725, ('R617', 'R058', 'BERGEN ST')),
#  (712, ('E016', 'R400', 'BAY 50 ST')),
#  (711, ('N193', 'R337', 'BEACH 44 ST')),
#  (703, ('R203A', 'R043', 'WALL ST')),
#  (701, ('H035', 'R348', 'ATLANTIC AV')),
#  (700, ('R641', 'R210', 'BEVERLY RD')),
#  (667, ('R121', 'R290', 'HOUSTON ST')),
#  (666, ('R407', 'R448', "E 143/ST MARY'S")),
#  (654, ('N545', 'R204', 'CHURCH AV')),
#  (643, ('R260', 'R205', '149/GRAND CONC')),
#  (638, ('N330C', 'R202', '63 DR-REGO PARK')),
#  (632, ('N087', 'R282', 'SPRING ST')),
#  (612, ('N562', 'R426', 'NEPTUNE AV')),
#  (597, ('N558', 'R130', 'KINGS HWY')),
#  (594, ('B034', 'R264', 'OCEAN PKWY')),
#  (534, ('N206', 'R104', '167 ST')),
#  (531, ('N137', 'R354', '104 ST')),
#  (521, ('N186', 'R418', 'BEACH 105 ST')),
#  (508, ('R729', 'R292', 'BAYCHESTER AV')),
#  (499, ('R318', 'R408', 'SIMPSON ST')),
#  (486, ('N139', 'R355', '111 ST')),
#  (483, ('A055', 'R227', 'RECTOR ST')),
#  (482, ('N420B', 'R317', 'CLINTON-WASH AV')),
#  (480, ('D008', 'R392', '18 AV')),
#  (465, ('N338', 'R128', 'SUTPHIN BLVD')),
#  (464, ('N182', 'R414', 'HOWARD BCH JFK')),
#  (430, ('R643', 'R135', 'NEWKIRK AV')),
#  (430, ('N329A', 'R201', 'WOODHAVEN BLVD')),
#  (424, ('R314', 'R406', 'PROSPECT AV')),
#  (417, ('C004', 'R089', 'JAY ST-METROTEC')),
#  (409, ('N544', 'R289', 'FT HAMILTON PKY')),
#  (408, ('R322', 'R386', '174 ST')),
#  (356, ('N418', 'R269', 'BEDFORD-NOSTRAN')),
#  (350, ('N547', 'R420', 'DITMAS AV')),
#  (330, ('N138', 'R355', '111 ST')),
#  (308, ('C026', 'R215', '86 ST')),
#  (302, ('R320', 'R409', 'FREEMAN ST')),
#  (300, ('R406', 'R448', "E 143/ST MARY'S")),
#  (294, ('D009', 'R393', '20 AV')),
#  (225, ('J032', 'R006', 'WOODHAVEN BLVD')),
#  (217, ('N416', 'R286', 'MYRTLE-WILLOUGH')),
#  (217, ('N218', 'R112', 'FORDHAM RD')),
#  (210, ('N339', 'R114', 'PARSONS BLVD')),
#  (207, ('A082', 'R028', 'FULTON ST')),
#  (202, ('N223', 'R156', 'BEDFORD PK BLVD')),
#  (167, ('N334B', 'R341', '75 AV')),
#  (164, ('N181A', 'R464', 'AQUEDUCT RACETR')),
#  (163, ('R308', 'R344', '145 ST')),
#  (161, ('N003', 'R185', 'DYCKMAN ST')),
#  (149, ('C028', 'R216', 'BAY RIDGE-95 ST')),
#  (145, ('PTH19', 'R549', 'NEWARK C')),
#  (139, ('R506', 'R276', 'VERNON-JACKSON')),
#  (130, ('J037', 'R009', '121 ST')),
#  (120, ('J034', 'R007', '104 ST')),
#  (100, ('G015', 'R312', 'W 8 ST-AQUARIUM')),
#  (96, ('N183', 'R415', 'BROAD CHANNEL')),
#  (96, ('N123B', 'R439', 'ROCKAWAY AV')),
#  (95, ('R196', 'R306', '238 ST')),
#  (74, ('N022', 'R332', '135 ST')),
#  (64, ('A084', 'R125', 'BROAD ST')),
#  (56, ('TRAM2', 'R469', 'RIT-ROOSEVELT')),
#  (55, ('TRAM1', 'R468', 'RIT-MANHATTAN')),
#  (18, ('OB01', 'R459', 'ORCHARD BEACH')),
#  (0, ('S102', 'R165', 'TOMPKINSVILLE')),
#  (0, ('S101A', 'R070', 'ST. GEORGE')),
#  (0, ('S101', 'R070', 'ST. GEORGE')),
#  (0, ('R262B', 'R195', '161/YANKEE STAD')),
#  (0, ('R262A', 'R195', '161/YANKEE STAD')),
#  (0, ('N554', 'R423', 'AVENUE N')),
#  (0, ('N550', 'R242', '18 AV')),
#  (0, ('A085', 'R125', 'BROAD ST')),
#  (-333, ('N029', 'R333', '116 ST')),
#  (-2060, ('R241A', 'R048', 'GRD CNTRL-42 ST')),
#  (-45421, ('PTH03', 'R552', 'JOURNAL SQUARE'))]

# %% [markdown]
# 15.Look at the three smallest riderships in your above tuple list. Do they make sense? What about your data caused negative numbers? Welcome to the world of buggy real world data! Remove these three items from your tuple list.

# %%
tuple_list.remove((-333, ('N029', 'R333', '116 ST')))
tuple_list.remove( (-2060, ('R241A', 'R048', 'GRD CNTRL-42 ST')))
tuple_list.remove((-45421, ('PTH03', 'R552', 'JOURNAL SQUARE')))
tuple_list
# Out:
# [(56297, ('PTH22', 'R540', 'PATH NEW WTC')),
#  (50291, ('R238', 'R046', 'GRD CNTRL-42 ST')),
#  (39654, ('R240', 'R047', 'GRD CNTRL-42 ST')),
#  (31126, ('R249', 'R179', '86 ST')),
#  (27180, ('N500', 'R020', '47-50 STS ROCK')),
#  (26181, ('R138', 'R293', '34 ST-PENN STA')),
#  (25527, ('A025', 'R023', '34 ST-HERALD SQ')),
#  (24776, ('R533', 'R055', 'FLUSHING-MAIN')),
#  (24129, ('R221', 'R170', '14 ST-UNION SQ')),
#  (24085, ('N507', 'R023', '34 ST-HERALD SQ')),
#  (24053, ('N506', 'R022', '34 ST-HERALD SQ')),
#  (24049, ('N049', 'R084', '59 ST COLUMBUS')),
#  (23536, ('H009', 'R235', 'BEDFORD AV')),
#  (23504, ('A034', 'R170', '14 ST-UNION SQ')),
#  (23196, ('N306', 'R017', 'LEXINGTON AV/53')),
#  (23123, ('N083', 'R138', 'W 4 ST-WASH SQ')),
#  (22670, ('N324', 'R018', 'JKSN HT-ROOSVLT')),
#  (22189, ('N063A', 'R011', '42 ST-PORT AUTH')),
#  (22075, ('N501', 'R020', '47-50 STS ROCK')),
#  (21168, ('R258', 'R132', '125 ST')),
#  (20911, ('R169', 'R168', '96 ST')),
#  (20589, ('A033', 'R170', '14 ST-UNION SQ')),
#  (20076, ('R151', 'R033', 'TIMES SQ-42 ST')),
#  (19889, ('PTH06', 'R546', 'PAVONIA/NEWPORT')),
#  (19870, ('PTH17', 'R541', 'THIRTY THIRD ST')),
#  (19814, ('R236', 'R045', 'GRD CNTRL-42 ST')),
#  (19367, ('A021', 'R032', 'TIMES SQ-42 ST')),
#  (19271, ('PTH20', 'R549', 'NEWARK HM HE')),
#  (19260, ('N606', 'R025', 'JAMAICA CENTER')),
#  (19161, ('PTH04', 'R551', 'GROVE STREET')),
#  (19090, ('N504', 'R021', '42 ST-BRYANT PK')),
#  (18894, ('R247', 'R178', '77 ST')),
#  (18671, ('N067', 'R012', '34 ST-PENN STA')),
#  (18496, ('R116', 'R030', 'CHAMBERS ST')),
#  (18491, ('N051', 'R084', '59 ST COLUMBUS')),
#  (18132, ('R610', 'R057', 'ATL AV-BARCLAY')),
#  (17924, ('N505', 'R022', '34 ST-HERALD SQ')),
#  (17543, ('R206', 'R014', 'FULTON ST')),
#  (17058, ('R135', 'R031', '34 ST-PENN STA')),
#  (16808, ('N605', 'R024', 'SUTPHIN-ARCHER')),
#  (16332, ('PTH05', 'R543', 'EXCHANGE PLACE')),
#  (16073, ('A046', 'R463', 'CANAL ST')),
#  (16069, ('R101', 'R001', 'SOUTH FERRY')),
#  (15975, ('R246', 'R177', '68ST-HUNTER CO')),
#  (15842, ('R523', 'R147', '61 ST WOODSIDE')),
#  (15761, ('R161B', 'R452', '72 ST')),
#  (15604, ('R526', 'R096', '82 ST-JACKSON H')),
#  (15369, ('PTH07', 'R550', 'CITY / BUS')),
#  (15354, ('N303', 'R015', '5 AV/53 ST')),
#  (15312, ('R145', 'R032', 'TIMES SQ-42 ST')),
#  (15311, ('N026', 'R102', '125 ST')),
#  (15209, ('R417', 'R222', 'PARKCHESTER')),
#  (15189, ('N336', 'R158', 'KEW GARDENS')),
#  (14887, ('N519', 'R461', "B'WAY-LAFAYETTE")),
#  (14793, ('R528', 'R097', 'JUNCTION BLVD')),
#  (14219, ('N700', 'R570', '72 ST-2 AVE')),
#  (14214, ('R143', 'R032', 'TIMES SQ-42 ST')),
#  (13967, ('A043', 'R462', 'CANAL ST')),
#  (13952, ('R202', 'R042', 'BOWLING GREEN')),
#  (13934, ('N520', 'R240', 'GRAND ST')),
#  (13920, ('N073', 'R013', '34 ST-PENN STA')),
#  (13916, ('N503', 'R021', '42 ST-BRYANT PK')),
#  (13586, ('R626', 'R062', 'CROWN HTS-UTICA')),
#  (13442, ('N305', 'R017', 'LEXINGTON AV/53')),
#  (13093, ('N304', 'R015', '5 AV/53 ST')),
#  (13014, ('N062A', 'R010', '42 ST-PORT AUTH')),
#  (12945, ('R182', 'R035', '168 ST')),
#  (12901, ('N020', 'R101', '145 ST')),
#  (12688, ('N508', 'R453', '23 ST')),
#  (12645, ('R245A', 'R051', '59 ST')),
#  (12450, ('R155', 'R116', '50 ST')),
#  (12232, ('H008', 'R248', '1 AV')),
#  (12130, ('H001', 'R175', '8 AV')),
#  (11951, ('PTH13', 'R541', 'THIRTY ST')),
#  (11948, ('R243', 'R049', '51 ST')),
#  (11948, ('N098', 'R028', 'FULTON ST')),
#  (11942, ('R534', 'R055', 'FLUSHING-MAIN')),
#  (11883, ('N600', 'R302', '57 ST')),
#  (11850, ('D002', 'R390', '8 AV')),
#  (11811, ('PTH12', 'R542', 'TWENTY THIRD ST')),
#  (11630, ('PTH16', 'R550', 'LACKAWANNA')),
#  (11580, ('R515', 'R095', 'ASTORIA DITMARS')),
#  (11362, ('R220', 'R160', 'ASTOR PL')),
#  (11311, ('R529', 'R208', '103 ST-CORONA')),
#  (11258, ('N519A', 'R461', "B'WAY-LAFAYETTE")),
#  (11207, ('N501A', 'R020', '47-50 STS ROCK')),
#  (11200, ('N329', 'R201', 'WOODHAVEN BLVD')),
#  (11144, ('R501', 'R054', '5 AVE')),
#  (11136, ('R168A', 'R168', '96 ST')),
#  (11064, ('N335', 'R158', 'KEW GARDENS')),
#  (10999, ('R244', 'R050', '59 ST')),
#  (10997, ('R210', 'R044', 'BROOKLYN BRIDGE')),
#  (10820, ('N060', 'R010', '42 ST-PORT AUTH')),
#  (10769, ('C009', 'R057', 'ATL AV-BARCLAY')),
#  (10766, ('R252', 'R180', '103 ST')),
#  (10704, ('B016', 'R098', 'CHURCH AV')),
#  (10670, ('N078', 'R175', '14 ST')),
#  (10639, ('N080', 'R138', 'W 4 ST-WASH SQ')),
#  (10558, ('R161A', 'R452', '72 ST')),
#  (10528, ('R165', 'R167', '86 ST')),
#  (10393, ('A060', 'R001', 'WHITEHALL S-FRY')),
#  (10380, ('R550', 'R072', '34 ST-HUDSON YD')),
#  (10367, ('A022', 'R022', '34 ST-HERALD SQ')),
#  (10328, ('R154', 'R116', '50 ST')),
#  (10297, ('N301', 'R113', '7 AV')),
#  (10265, ('A049', 'R088', 'CORTLANDT ST')),
#  (10222, ('N509', 'R203', '23 ST')),
#  (10197, ('N095A', 'R014', 'FULTON ST')),
#  (10137, ('A035', 'R170', '14 ST-UNION SQ')),
#  (10005, ('R159', 'R164', '66 ST-LINCOLN')),
#  (9861, ('R183', 'R260', '181 ST')),
#  (9839, ('N092', 'R029', 'CHAMBERS ST')),
#  (9718, ('N103', 'R127', 'JAY ST-METROTEC')),
#  (9686, ('R158', 'R084', '59 ST COLUMBUS')),
#  (9481, ('N700A', 'R570', '72 ST-2 AVE')),
#  (9429, ('B027', 'R136', 'SHEEPSHEAD BAY')),
#  (9397, ('R204', 'R043', 'WALL ST')),
#  (9365, ('N102', 'R127', 'JAY ST-METROTEC')),
#  (9362, ('N089', 'R139', 'CANAL ST')),
#  (9337, ('N094', 'R029', 'WORLD TRADE CTR')),
#  (9325, ('R111', 'R027', 'WALL ST')),
#  (9281, ('R532H', 'R328', 'METS-WILLETS PT')),
#  (9268, ('R226', 'R131', '23 ST')),
#  (9080, ('R602', 'R108', 'BOROUGH HALL')),
#  (9080, ('R228', 'R143', '28 ST')),
#  (9073, ('N601', 'R319', 'LEXINGTON AV/63')),
#  (9019, ('R142', 'R293', '34 ST-PENN STA')),
#  (9007, ('N072', 'R012', '34 ST-PENN STA')),
#  (8926, ('N607', 'R025', 'JAMAICA CENTER')),
#  (8863, ('R513', 'R093', '30 AV')),
#  (8836, ('G001', 'R151', 'CONEY IS-STILLW')),
#  (8802, ('R244A', 'R050', '59 ST')),
#  (8799, ('B019', 'R149', 'NEWKIRK PLAZA')),
#  (8779, ('N701A', 'R571', '86 ST-2 AVE')),
#  (8730, ('N305A', 'R016', 'LEXINGTON AV/53')),
#  (8714, ('R216', 'R322', 'SPRING ST')),
#  (8697, ('N062', 'R011', '42 ST-PORT AUTH')),
#  (8673, ('R601A', 'R108', 'BOROUGH HALL')),
#  (8652, ('N300', 'R113', '7 AV')),
#  (8561, ('N095', 'R014', 'FULTON ST')),
#  (8486, ('R201', 'R041', 'BOWLING GREEN')),
#  (8485, ('PTH01', 'R549', 'NEWARK HW BMEBE')),
#  (8347, ('N044', 'R187', '81 ST-MUSEUM')),
#  (8346, ('B004', 'R171', '7 AV')),
#  (8345, ('PTH02', 'R544', 'HARRISON')),
#  (8317, ('R229', 'R143', '28 ST')),
#  (8159, ('N523', 'R300', '2 AV')),
#  (8135, ('R232', 'R176', '33 ST')),
#  (8080, ('A042', 'R086', 'PRINCE ST')),
#  (8050, ('N601A', 'R319', 'LEXINGTON AV/63')),
#  (7927, ('N323', 'R018', 'JKSN HT-ROOSVLT')),
#  (7908, ('N108', 'R217', 'HOYT-SCHER')),
#  (7901, ('N327', 'R254', 'GRAND-NEWTOWN')),
#  (7882, ('R237', 'R046', 'GRD CNTRL-42 ST')),
#  (7826, ('N091', 'R029', 'CHAMBERS ST')),
#  (7811, ('R283', 'R221', '167 ST')),
#  (7742, ('PTH21', 'R540', 'PATH WTC 2')),
#  (7678, ('R518', 'R261', '40 ST LOWERY ST')),
#  (7649, ('JFK03', 'R536', 'JFK JAMAICA CT1')),
#  (7647, ('R185', 'R274', '191 ST')),
#  (7607, ('R412', 'R146', 'HUNTS POINT AV')),
#  (7574, ('R132', 'R190', '23 ST')),
#  (7559, ('R512', 'R092', 'BROADWAY')),
#  (7495, ('R147', 'R033', 'TIMES SQ-42 ST')),
#  (7443, ('R175', 'R169', '137 ST CITY COL')),
#  (7437, ('R516', 'R291', '33 ST-RAWSON ST')),
#  (7433, ('C008', 'R099', 'DEKALB AV')),
#  (7422, ('R331', 'R364', 'GUN HILL RD')),
#  (7412, ('R503', 'R276', 'VERNON-JACKSON')),
#  (7277, ('B024A', 'R211', 'KINGS HWY')),
#  (7231, ('A029', 'R082', '28 ST')),
#  (7223, ('N512', 'R163', '14 ST')),
#  (7208, ('N333B', 'R141', 'FOREST HILLS 71')),
#  (7204, ('N046', 'R281', '72 ST')),
#  (7168, ('R519', 'R223', '46 ST BLISS ST')),
#  (7153, ('PTH11', 'R545', '14TH STREET')),
#  (7135, ('R110', 'R027', 'WALL ST')),
#  (7116, ('N701', 'R571', '86 ST-2 AVE')),
#  (7098, ('R113', 'R028', 'FULTON ST')),
#  (7070, ('A006', 'R079', '5 AV/59 ST')),
#  (7065, ('R148', 'R033', 'TIMES SQ-42 ST')),
#  (7033, ('A013', 'R081', '49 ST')),
#  (7030, ('N124', 'R103', 'BROADWAY JCT')),
#  (7005, ('R242', 'R049', '51 ST')),
#  (6934, ('R237B', 'R047', 'GRD CNTRL-42 ST')),
#  (6932, ('N071', 'R013', '34 ST-PENN STA')),
#  (6841, ('H007', 'R248', '1 AV')),
#  (6839, ('A039', 'R085', '8 ST-NYU')),
#  (6836, ('C018', 'R197', '36 ST')),
#  (6704, ('A002', 'R051', '59 ST')),
#  (6700, ('N120', 'R153', 'UTICA AV')),
#  (6646, ('R514', 'R094', 'ASTORIA BLVD')),
#  (6613, ('C012', 'R258', '4AV-9 ST')),
#  (6528, ('G009', 'R151', 'CONEY IS-STILLW')),
#  (6520, ('N077', 'R111', '23 ST')),
#  (6506, ('N400A', 'R359', 'COURT SQ')),
#  (6473, ('R248', 'R178', '77 ST')),
#  (6461, ('R301', 'R323', 'CENTRAL PK N110')),
#  (6432, ('R173', 'R159', '116 ST-COLUMBIA')),
#  (6421, ('R527', 'R122', '90 ST-ELMHURST')),
#  (6421, ('R507', 'R134', 'HUNTERS PT AV')),
#  (6411, ('J002', 'R460', 'MARCY AV')),
#  (6377, ('D010', 'R394', 'BAY PKWY')),
#  (6337, ('N056', 'R188', '50 ST')),
#  (6333, ('R141', 'R031', '34 ST-PENN STA')),
#  (6331, ('E014', 'R374', 'BAY PKWY')),
#  (6297, ('A010', 'R080', '57 ST-7 AV')),
#  (6296, ('N525', 'R142', 'DELANCEY/ESSEX')),
#  (6279, ('R174', 'R034', '125 ST')),
#  (6255, ('N502', 'R021', '42 ST-BRYANT PK')),
#  (6244, ('N309A', 'R140', 'QUEENS PLAZA')),
#  (6230, ('N076', 'R111', '23 ST')),
#  (6191, ('J009', 'R378', 'MYRTLE AV')),
#  (6179, ('R200A', 'R041', 'BOWLING GREEN')),
#  (6175, ('A031', 'R083', '23 ST')),
#  (6163, ('R612', 'R057', 'ATL AV-BARCLAY')),
#  (6163, ('N070', 'R012', '34 ST-PENN STA')),
#  (6143, ('N090', 'R139', 'CANAL ST')),
#  (6116, ('R261', 'R205', '149/GRAND CONC')),
#  (6108, ('N702', 'R572', '96 ST-2 AVE')),
#  (5975, ('A030', 'R083', '23 ST')),
#  (5968, ('B031', 'R172', 'BRIGHTON BEACH')),
#  (5919, ('N117', 'R198', 'NOSTRAND AV')),
#  (5887, ('R284', 'R243', '170 ST')),
#  (5885, ('B024', 'R211', 'KINGS HWY')),
#  (5875, ('N702A', 'R572', '96 ST-2 AVE')),
#  (5861, ('R530', 'R310', '111 ST')),
#  (5857, ('N141', 'R356', 'OZONE PK LEFFRT')),
#  (5852, ('N539A', 'R288', '7 AV')),
#  (5837, ('A058', 'R001', 'WHITEHALL S-FRY')),
#  (5798, ('R124', 'R290', 'HOUSTON ST')),
#  (5756, ('A037', 'R170', '14 ST-UNION SQ')),
#  (5753, ('N063', 'R011', '42 ST-PORT AUTH')),
#  (5651, ('N315', 'R238', 'STEINWAY ST')),
#  (5615, ('R418', 'R106', 'CASTLE HILL AV')),
#  (5594, ('N603', 'R303', '21 ST-QNSBRIDGE')),
#  (5594, ('A061', 'R142', 'DELANCEY/ESSEX')),
#  (5585, ('R325', 'R388', 'E 180 ST')),
#  (5526, ('R126', 'R189', 'CHRISTOPHER ST')),
#  (5514, ('R127', 'R105', '14 ST')),
#  (5503, ('R231A', 'R176', '33 ST')),
#  (5456, ('R250', 'R179', '86 ST')),
#  (5450, ('A015', 'R081', '49 ST')),
#  (5437, ('R170', 'R191', '103 ST')),
#  (5415, ('C025', 'R215', '86 ST')),
#  (5414, ('PTH09', 'R548', 'CHRISTOPHER ST')),
#  (5398, ('R231', 'R176', '33 ST')),
#  (5371, ('N405', 'R239', 'GREENPOINT AV')),
#  (5352, ('R521', 'R327', '52 ST')),
#  (5342, ('R414', 'R162', 'ELDER AV')),
#  (5292, ('K025', 'R404', 'FRESH POND RD')),
#  (5269, ('A081', 'R028', 'FULTON ST')),
#  (5207, ('R622', 'R123', 'FRANKLIN AV')),
#  (5207, ('R420', 'R107', 'WESTCHESTER SQ')),
#  (5207, ('A027', 'R082', '28 ST')),
#  (5201, ('N602', 'R259', 'ROOSEVELT ISLND')),
#  (5163, ('N213', 'R154', 'TREMONT AV')),
#  (5146, ('R508', 'R346', 'COURT SQ')),
#  (5115, ('H027', 'R137', 'MYRTLE-WYCKOFF')),
#  (5101, ('N019', 'R101', '145 ST')),
#  (5076, ('R112', 'R027', 'WALL ST')),
#  (5048, ('R608', 'R056', 'NEVINS ST')),
#  (5027, ('N010', 'R126', '175 ST')),
#  (4991, ('R253', 'R181', '110 ST')),
#  (4985, ('N217', 'R112', 'FORDHAM RD')),
#  (4963, ('R625', 'R062', 'CROWN HTS-UTICA')),
#  (4953, ('R134', 'R272', '28 ST')),
#  (4948, ('N536', 'R270', 'SMITH-9 ST')),
#  (4908, ('R210A', 'R044', 'BROOKLYN BRIDGE')),
#  (4900, ('N339A', 'R114', 'PARSONS BLVD')),
#  (4860, ('R311', 'R053', '3 AV-149 ST')),
#  (4851, ('R251', 'R144', '96 ST')),
#  (4847, ('R217A', 'R194', 'BLEECKER ST')),
#  (4835, ('H026', 'R137', 'MYRTLE-WYCKOFF')),
#  (4829, ('E001', 'R368', '9 AV')),
#  (4801, ('N604', 'R342', 'JAMAICA VAN WK')),
#  (4794, ('R401', 'R445', '3 AV 138 ST')),
#  (4783, ('R629', 'R065', 'ROCKAWAY AV')),
#  (4777, ('R524', 'R347', '69 ST')),
#  (4765, ('N521', 'R300', '2 AV')),
#  (4759, ('R208', 'R014', 'FULTON ST')),
#  (4758, ('R114', 'R028', 'FULTON ST')),
#  (4748, ('R628', 'R064', 'SARATOGA AV')),
#  (4696, ('R336', 'R145', 'WAKEFIELD/241')),
#  (4695, ('R634', 'R069', 'NEW LOTS AV')),
#  (4671, ('N537', 'R258', '4 AV-9 ST')),
#  (4659, ('N546', 'R204', 'CHURCH AV')),
#  (4628, ('PTH10', 'R547', '9TH STREET')),
#  (4615, ('R290', 'R161', 'KINGSBRIDGE RD')),
#  (4601, ('N330', 'R202', '63 DR-REGO PARK')),
#  (4584, ('N343', 'R019', 'JAMAICA 179 ST')),
#  (4569, ('R160A', 'R164', '66 ST-LINCOLN')),
#  (4564, ('A014', 'R081', '49 ST')),
#  (4559, ('R160', 'R164', '66 ST-LINCOLN')),
#  (4517, ('R112A', 'R027', 'WALL ST')),
#  (4514, ('H014', 'R249', 'GRAHAM AV')),
#  (4490, ('R219', 'R160', 'ASTOR PL')),
#  (4468, ('R256', 'R182', '116 ST')),
#  (4468, ('N526', 'R142', 'DELANCEY/ESSEX')),
#  (4423, ('N196', 'R285', 'FAR ROCKAWAY')),
#  (4410, ('H016', 'R250', 'GRAND ST')),
#  (4409, ('J024', 'R437', 'CRESCENT ST')),
#  (4406, ('R415', 'R120', 'MORISN AV/SNDVW')),
#  (4394, ('R511', 'R091', '36 AV')),
#  (4345, ('R423', 'R429', 'PELHAM BAY PARK')),
#  (4315, ('N069', 'R013', '34 ST-PENN STA')),
#  (4306, ('N530', 'R301', 'YORK ST')),
#  (4286, ('B013', 'R196', 'PROSPECT PARK')),
#  (4279, ('R287', 'R244', 'BURNSIDE AV')),
#  (4263, ('R164', 'R167', '86 ST')),
#  (4263, ('C019', 'R232', '45 ST')),
#  (4250, ('R179', 'R193', '157 ST')),
#  (4240, ('N114', 'R297', 'FRANKLIN AV')),
#  (4232, ('N043', 'R186', '86 ST')),
#  (4215, ('R645', 'R110', 'FLATBUSH AV-B.C')),
#  (4210, ('R730', 'R431', 'EASTCHSTER/DYRE')),
#  (4210, ('R177', 'R273', '145 ST')),
#  (4183, ('N409', 'R268', 'METROPOLITAN AV')),
#  (4169, ('R171', 'R192', 'CATHEDRAL PKWY')),
#  (4118, ('H039', 'R375', 'NEW LOTS')),
#  (4110, ('N531', 'R129', 'BERGEN ST')),
#  (4099, ('D003', 'R391', 'FT HAMILTON PKY')),
#  (4075, ('A041', 'R086', 'PRINCE ST')),
#  (4066, ('R137', 'R031', '34 ST-PENN STA')),
#  (4058, ('N129', 'R382', 'GRANT AV')),
#  (4043, ('R102', 'R304', 'RECTOR ST')),
#  (4024, ('N068', 'R012', '34 ST-PENN STA')),
#  (3997, ('N120A', 'R153', 'UTICA AV')),
#  (3967, ('R644', 'R135', 'NEWKIRK AV')),
#  (3967, ('B015', 'R098', 'CHURCH AV')),
#  (3964, ('R609', 'R056', 'NEVINS ST')),
#  (3949, ('N116', 'R198', 'NOSTRAND AV')),
#  (3920, ('R120', 'R320', 'CANAL ST')),
#  (3920, ('N007A', 'R174', '181 ST')),
#  (3919, ('R605', 'R456', 'HOYT ST')),
#  (3885, ('N040', 'R251', '96 ST')),
#  (3881, ('R525', 'R018', '74 ST-BROADWAY')),
#  (3879, ('R245', 'R051', '59 ST')),
#  (3867, ('N419', 'R287', 'CLASSON AV')),
#  (3827, ('R203', 'R043', 'WALL ST')),
#  (3800, ('N510', 'R163', '14 ST')),
#  (3768, ('R635', 'R277', 'PRESIDENT ST')),
#  (3751, ('R509', 'R121', 'QUEENSBORO PLZ')),
#  (3737, ('A047', 'R087', 'CITY HALL')),
#  (3735, ('N333A', 'R141', 'FOREST HILLS 71')),
#  (3696, ('N408A', 'R256', 'NASSAU AV')),
#  (3685, ('N057', 'R188', '50 ST')),
#  (3684, ('A050', 'R088', 'CORTLANDT ST')),
#  (3669, ('N511', 'R163', '14 ST')),
#  (3668, ('N422', 'R318', 'FULTON ST')),
#  (3660, ('B014', 'R148', 'PARKSIDE AV')),
#  (3655, ('R131', 'R190', '23 ST')),
#  (3605, ('N025', 'R102', '125 ST')),
#  (3570, ('R163', 'R166', '79 ST')),
#  (3556, ('R321', 'R386', '174 ST')),
#  (3536, ('B029', 'R172', 'BRIGHTON BEACH')),
#  (3534, ('N205', 'R195', '161/YANKEE STAD')),
#  (3528, ('D005', 'R398', 'NEW UTRECHT AV')),
#  (3514, ('N535', 'R220', 'CARROLL ST')),
#  (3506, ('K019', 'R413', 'KNICKERBOCKER')),
#  (3500, ('R128', 'R105', '14 ST')),
#  (3497, ('R403', 'R446', 'BROOK AV')),
#  (3491, ('N101', 'R252', 'HIGH ST')),
#  (3488, ('R647', 'R110', 'FLATBUSH AV-B.C')),
#  (3488, ('N009', 'R174', '181 ST')),
#  (3460, ('R162', 'R166', '79 ST')),
#  (3446, ('R133', 'R272', '28 ST')),
#  (3427, ('N513', 'R163', '14 ST')),
#  (3415, ('A069', 'R044', 'CHAMBERS ST')),
#  (3405, ('R323', 'R387', 'WEST FARMS SQ')),
#  (3405, ('R242A', 'R049', '51 ST')),
#  (3398, ('N222', 'R156', 'BEDFORD PK BLVD')),
#  (3368, ('R291', 'R183', 'BEDFORD PK BLVD')),
#  (3363, ('N319', 'R298', 'NORTHERN BLVD')),
#  (3342, ('J001', 'R460', 'MARCY AV')),
#  (3312, ('N549', 'R242', '18 AV')),
#  (3305, ('N340', 'R115', '169 ST')),
#  (3290, ('R227A', 'R131', '23 ST')),
#  (3284, ('B012', 'R196', 'PROSPECT PARK')),
#  (3272, ('H040', 'R376', 'EAST 105 ST')),
#  (3263, ('D012', 'R395', 'KINGS HWY')),
#  (3260, ('N417', 'R269', 'BEDFORD-NOSTRAN')),
#  (3259, ('R262', 'R195', '161/YANKEE STAD')),
#  (3244, ('R232A', 'R176', '33 ST')),
#  (3232, ('R186', 'R036', 'DYCKMAN ST')),
#  (3228, ('R621', 'R060', 'EASTN PKWY-MUSM')),
#  (3222, ('H005', 'R330', '3 AV')),
#  (3211, ('R319', 'R409', 'FREEMAN ST')),
#  (3211, ('R285', 'R308', 'MT EDEN AV')),
#  (3208, ('N342', 'R019', 'JAMAICA 179 ST')),
#  (3204, ('A011', 'R080', '57 ST-7 AV')),
#  (3184, ('R624', 'R124', 'KINGSTON AV')),
#  (3179, ('R257', 'R182', '116 ST')),
#  (3171, ('R130', 'R321', '18 ST')),
#  (3171, ('N207', 'R104', '167 ST')),
#  (3140, ('H041', 'R152', 'CANARSIE-ROCKAW')),
#  (3132, ('N203', 'R195', '161/YANKEE STAD')),
#  (3131, ('R422', 'R428', 'BUHRE AV')),
#  (3131, ('A007', 'R079', '5 AV/59 ST')),
#  (3070, ('N316A', 'R267', '46 ST')),
#  (3064, ('H032', 'R295', 'WILSON AV')),
#  (3048, ('C021', 'R212', '59 ST')),
#  (3047, ('N045', 'R187', '81 ST-MUSEUM')),
#  (3032, ('R623', 'R061', 'NOSTRAND AV')),
#  (3012, ('K017', 'R401', 'CENTRAL AV')),
#  (3009, ('N340A', 'R115', '169 ST')),
#  (3008, ('N220', 'R155', 'KINGSBRIDGE RD')),
#  (3001, ('H017', 'R265', 'MONTROSE AV')),
#  (2997, ('R309', 'R345', 'HARLEM 148 ST')),
#  (2991, ('R416', 'R245', 'ST LAWRENCE AV')),
#  (2989, ('A038', 'R085', '8 ST-NYU')),
#  (2987, ('C027', 'R216', 'BAY RIDGE-95 ST')),
#  (2977, ('R205A', 'R014', 'FULTON ST')),
#  (2974, ('R600', 'R224', 'CLARK ST')),
#  (2958, ('N412', 'R299', 'BROADWAY')),
#  (2955, ('N118', 'R199', 'KINGSTON-THROOP')),
#  (2950, ('N037', 'R314', '103 ST')),
#  (2938, ('N557', 'R130', 'KINGS HWY')),
#  (2928, ('N314', 'R238', 'STEINWAY ST')),
#  (2921, ('J023', 'R436', 'NORWOOD AV')),
#  (2919, ('N039', 'R251', '96 ST')),
#  (2915, ('R532', 'R328', 'METS-WILLETS PT')),
#  (2905, ('C011', 'R231', 'UNION ST')),
#  (2904, ('N122', 'R439', 'ROCKAWAY AV')),
#  (2891, ('R304', 'R206', '125 ST')),
#  (2889, ('G011', 'R312', 'W 8 ST-AQUARIUM')),
#  (2884, ('B021', 'R228', 'AVENUE J')),
#  (2880, ('R115', 'R029', 'PARK PLACE')),
#  (2875, ('H023', 'R236', 'DEKALB AV')),
#  (2856, ('R604', 'R108', 'BOROUGH HALL')),
#  (2839, ('E004', 'R234', '50 ST')),
#  (2800, ('N224', 'R157', 'NORWOOD 205 ST')),
#  (2799, ('A066', 'R118', 'CANAL ST')),
#  (2794, ('J022', 'R435', 'CLEVELAND ST')),
#  (2792, ('R316', 'R407', 'INTERVALE AV')),
#  (2792, ('N331', 'R219', '67 AV')),
#  (2766, ('N035', 'R334', 'CATHEDRAL PKWY')),
#  (2763, ('H019', 'R294', 'MORGAN AV')),
#  (2743, ('R303', 'R324', '116 ST')),
#  (2734, ('N128', 'R200', 'EUCLID AV')),
#  (2722, ('R286', 'R309', '176 ST')),
#  (2685, ('A083', 'R125', 'BROAD ST')),
#  (2681, ('J007', 'R377', 'FLUSHING AV')),
#  (2671, ('H037', 'R349', 'SUTTER AV')),
#  (2652, ('R197', 'R117', 'V.CORTLANDT PK')),
#  (2631, ('R188', 'R037', '207 ST')),
#  (2631, ('A016', 'R081', '49 ST')),
#  (2618, ('B022', 'R229', 'AVENUE M')),
#  (2596, ('N528', 'R257', 'EAST BROADWAY')),
#  (2592, ('R636', 'R209', 'STERLING ST')),
#  (2585, ('R293', 'R133', 'MOSHOLU PKWY')),
#  (2575, ('N529', 'R257', 'EAST BROADWAY')),
#  (2571, ('R328', 'R361', 'PELHAM PKWY')),
#  (2570, ('N013', 'R035', '168 ST')),
#  (2567, ('R310', 'R053', '3 AV-149 ST')),
#  (2561, ('R230', 'R143', '28 ST')),
#  (2557, ('R259', 'R307', '138/GRAND CONC')),
#  (2557, ('N317', 'R267', '46 ST')),
#  (2554, ('R288', 'R275', '183 ST')),
#  (2536, ('C017', 'R455', '25 ST')),
#  (2535, ('R254', 'R181', '110 ST')),
#  (2535, ('K024', 'R403', 'FOREST AVE')),
#  (2531, ('N225', 'R157', 'NORWOOD 205 ST')),
#  (2500, ('B025', 'R150', 'AVENUE U')),
#  (2498, ('H006', 'R330', '3 AV')),
#  (2494, ('R226A', 'R131', '23 ST')),
#  (2489, ('R204A', 'R043', 'WALL ST')),
#  (2484, ('A064', 'R311', 'BOWERY')),
#  (2473, ('J021', 'R434', 'VAN SICLEN AV')),
#  (2472, ('R238A', 'R046', 'GRD CNTRL-42 ST')),
#  (2462, ('N191', 'R335', 'BEACH 67 ST')),
#  (2459, ('R619', 'R059', 'GRAND ARMY PLAZ')),
#  (2443, ('R139', 'R031', '34 ST-PENN STA')),
#  (2437, ('B028', 'R136', 'SHEEPSHEAD BAY')),
#  (2433, ('E003', 'R369', 'FT HAMILTON PKY')),
#  (2432, ('N310', 'R140', 'QUEENS PLAZA')),
#  (2427, ('R409', 'R449', 'E 149 ST')),
#  (2416, ('N002A', 'R173', 'INWOOD-207 ST')),
#  (2394, ('N112A', 'R284', 'CLINTON-WASH AV')),
#  (2390, ('H030', 'R266', 'HALSEY ST')),
#  (2379, ('R504', 'R276', 'VERNON-JACKSON')),
#  (2376, ('JFK02', 'R535', 'HOWARD BCH JFK')),
#  (2369, ('R606', 'R225', 'HOYT ST')),
#  (2367, ('R633', 'R068', 'VAN SICLEN AV')),
#  (2352, ('K022', 'R402', 'SENECA AVE')),
#  (2350, ('R118', 'R343', 'FRANKLIN ST')),
#  (2336, ('R176', 'R169', '137 ST CITY COL')),
#  (2334, ('N307', 'R359', 'COURT SQ-23 ST')),
#  (2332, ('N121B', 'R438', 'RALPH AV')),
#  (2312, ('C024', 'R214', '77 ST')),
#  (2301, ('N333', 'R141', 'FOREST HILLS 71')),
#  (2301, ('J016', 'R381', 'HALSEY ST')),
#  (2292, ('B023', 'R211', 'KINGS HWY')),
#  (2262, ('R103', 'R304', 'RECTOR ST')),
#  (2254, ('N325A', 'R218', 'ELMHURST AV')),
#  (2238, ('R305', 'R206', '125 ST')),
#  (2225, ('R307', 'R207', '135 ST')),
#  (2212, ('B017', 'R262', 'BEVERLEY ROAD')),
#  (2208, ('R419', 'R326', 'ZEREGA AV')),
#  (2202, ('N322', 'R340', '65 ST')),
#  (2201, ('J020', 'R433', 'ALABAMA AV')),
#  (2160, ('N542', 'R241', '15 ST-PROSPECT')),
#  (2153, ('N030', 'R333', '116 ST')),
#  (2151, ('N337', 'R255', 'BRIARWOOD')),
#  (2143, ('R123', 'R290', 'HOUSTON ST')),
#  (2128, ('R517', 'R291', '33 ST-RAWSON ST')),
#  (2119, ('R125', 'R189', 'CHRISTOPHER ST')),
#  (2114, ('N221', 'R155', 'KINGSBRIDGE RD')),
#  (2110, ('R726', 'R329', 'MORRIS PARK')),
#  (2104, ('J013', 'R380', 'GATES AV')),
#  (2100, ('B020', 'R263', 'AVENUE H')),
#  (2062, ('R639', 'R109', 'CHURCH AV')),
#  (2062, ('N312', 'R339', '36 ST')),
#  (2058, ('H038', 'R350', 'LIVONIA AV')),
#  (2035, ('B010', 'R412', 'BOTANIC GARDEN')),
#  (1995, ('R727', 'R430', 'PELHAM PKWY')),
#  (1983, ('N338B', 'R128', 'SUTPHIN BLVD')),
#  (1970, ('H003', 'R163', '6 AV')),
#  (1968, ('N415', 'R286', 'MYRTLE-WILLOUGH')),
#  (1967, ('N209', 'R443', '170 ST')),
#  (1943, ('N023', 'R332', '135 ST')),
#  (1941, ('C003', 'R089', 'JAY ST-METROTEC')),
#  (1922, ('R421', 'R427', 'MIDDLETOWN RD')),
#  (1915, ('J028', 'R004', '75 ST-ELDERTS')),
#  (1910, ('R510', 'R090', '39 AV')),
#  (1907, ('R172', 'R192', 'CATHEDRAL PKWY')),
#  (1886, ('K026', 'R100', 'METROPOLITAN AV')),
#  (1884, ('J005', 'R353', 'LORIMER ST')),
#  (1874, ('N561', 'R271', 'AVENUE X')),
#  (1855, ('A077', 'R028', 'FULTON ST')),
#  (1822, ('R632', 'R067', 'PENNSYLVANIA AV')),
#  (1822, ('R329', 'R362', 'ALLERTON AV')),
#  (1821, ('R289', 'R119', 'FORDHAM RD')),
#  (1812, ('N100', 'R252', 'HIGH ST')),
#  (1809, ('J031', 'R006', 'WOODHAVEN BLVD')),
#  (1798, ('E011', 'R371', '79 ST')),
#  (1798, ('D015', 'R396', 'AVENUE U')),
#  (1774, ('R618', 'R058', 'BERGEN ST')),
#  (1767, ('N195', 'R358', 'BEACH 25 ST')),
#  (1757, ('R215', 'R322', 'SPRING ST')),
#  (1755, ('J035', 'R008', '111 ST')),
#  (1750, ('N401', 'R360', '21 ST')),
#  (1732, ('R413', 'R325', 'WHITLOCK AV')),
#  (1712, ('N017', 'R331', '155 ST')),
#  (1704, ('N555', 'R423', 'AVENUE N')),
#  (1703, ('R166', 'R167', '86 ST')),
#  (1699, ('R411', 'R450', 'LONGWOOD AV')),
#  (1699, ('N556', 'R424', 'AVENUE P')),
#  (1694, ('B009', 'R411', 'PARK PLACE')),
#  (1677, ('N318', 'R298', 'NORTHERN BLVD')),
#  (1657, ('R302', 'R324', '116 ST')),
#  (1653, ('B018', 'R184', 'CORTELYOU RD')),
#  (1647, ('N086', 'R282', 'SPRING ST')),
#  (1643, ('N192', 'R336', 'BEACH 60 ST')),
#  (1639, ('N110', 'R283', 'LAFAYETTE AV')),
#  (1636, ('R333', 'R366', '225 ST')),
#  (1631, ('R315', 'R406', 'PROSPECT AV')),
#  (1630, ('R178', 'R273', '145 ST')),
#  (1629, ('N548', 'R420', 'DITMAS AV')),
#  (1603, ('R129', 'R321', '18 ST')),
#  (1597, ('N202', 'R315', '155 ST')),
#  (1555, ('J012', 'R379', 'KOSCIUSZKO ST')),
#  (1546, ('A054', 'R227', 'RECTOR ST')),
#  (1544, ('E012', 'R372', '18 AV')),
#  (1543, ('H015', 'R250', 'GRAND ST')),
#  (1536, ('J030', 'R005', '85 ST-FOREST PK')),
#  (1505, ('N006A', 'R280', '190 ST')),
#  (1493, ('R119', 'R320', 'CANAL ST')),
#  (1489, ('R317', 'R408', 'SIMPSON ST')),
#  (1486, ('N181', 'R357', 'AQUEDUCT N.COND')),
#  (1486, ('E009', 'R370', '71 ST')),
#  (1481, ('N184', 'R416', 'BEACH 90 ST')),
#  (1475, ('R408', 'R449', 'E 149 ST')),
#  (1461, ('H022', 'R279', 'JEFFERSON ST')),
#  (1442, ('C001', 'R108', 'BOROUGH HALL')),
#  (1433, ('R180', 'R193', '157 ST')),
#  (1423, ('N126', 'R441', 'VAN SICLEN AVE')),
#  (1423, ('E013', 'R373', '20 AV')),
#  (1398, ('N414', 'R316', 'FLUSHING AV')),
#  (1389, ('N559', 'R425', 'AVENUE U')),
#  (1371, ('N532', 'R129', 'BERGEN ST')),
#  (1370, ('R334', 'R367', '233 ST')),
#  (1365, ('N127', 'R442', 'SHEPHERD AV')),
#  (1363, ('N024', 'R332', '135 ST')),
#  (1362, ('H028', 'R266', 'HALSEY ST')),
#  (1347, ('N001', 'R173', 'INWOOD-207 ST')),
#  (1336, ('N543', 'R289', 'FT HAMILTON PKY')),
#  (1335, ('R294', 'R052', 'WOODLAWN')),
#  (1320, ('N551', 'R421', 'AVENUE I')),
#  (1305, ('N187', 'R419', 'ROCKAWAY PARK B')),
#  (1304, ('R637', 'R451', 'WINTHROP ST')),
#  (1296, ('R306', 'R207', '135 ST')),
#  (1296, ('N215', 'R237', '182-183 STS')),
#  (1295, ('R405', 'R447', 'CYPRESS AV')),
#  (1280, ('R227', 'R131', '23 ST')),
#  (1278, ('R402', 'R446', 'BROOK AV')),
#  (1258, ('N111', 'R284', 'CLINTON-WASH AV')),
#  (1231, ('H012', 'R268', 'LORIMER ST')),
#  (1216, ('R194', 'R040', '231 ST')),
#  (1213, ('N131', 'R383', '80 ST')),
#  (1210, ('N414A', 'R316', 'FLUSHING AV')),
#  (1206, ('R646', 'R110', 'FLATBUSH AV-B.C')),
#  (1194, ('J003', 'R352', 'HEWES ST')),
#  (1190, ('N125', 'R440', 'LIBERTY AV')),
#  (1185, ('R332', 'R365', '219 ST')),
#  (1181, ('R520', 'R223', '46 ST BLISS ST')),
#  (1179, ('N208', 'R443', '170 ST')),
#  (1174, ('R335', 'R444', 'NEREID AV')),
#  (1170, ('N134', 'R385', 'ROCKAWAY BLVD')),
#  (1163, ('J017', 'R432', 'CHAUNCEY ST')),
#  (1132, ('R728', 'R226', 'GUN HILL RD')),
#  (1132, ('D016', 'R397', '86 ST')),
#  (1130, ('E015', 'R399', '25 AV')),
#  (1122, ('N185', 'R417', 'BEACH 98 ST')),
#  (1114, ('N034', 'R334', 'CATHEDRAL PKWY')),
#  (1108, ('R192', 'R039', 'MARBLE HILL-225')),
#  (1103, ('R404', 'R447', 'CYPRESS AV')),
#  (1099, ('N316', 'R267', '46 ST')),
#  (1087, ('JFK01', 'R535', 'HOWARD BCH JFK')),
#  (1084, ('N541', 'R241', '15 ST-PROSPECT')),
#  (1082, ('N332', 'R219', '67 AV')),
#  (1065, ('N113', 'R297', 'FRANKLIN AV')),
#  (1052, ('B026', 'R230', 'NECK RD')),
#  (1050, ('N075', 'R111', '23 ST')),
#  (1047, ('N133', 'R384', '88 ST')),
#  (1045, ('H033', 'R313', 'BUSHWICK AV')),
#  (1045, ('C010', 'R231', 'UNION ST')),
#  (1040, ('C022', 'R212', '59 ST')),
#  (1032, ('R326', 'R389', 'BRONX PARK EAST')),
#  (1032, ('N011', 'R126', '175 ST')),
#  (1019, ('R122', 'R290', 'HOUSTON ST')),
#  (1013, ('B032', 'R264', 'OCEAN PKWY')),
#  (1011, ('N119', 'R199', 'KINGSTON-THROOP')),
#  (1000, ('R330', 'R363', 'BURKE AV')),
#  (1000, ('N311', 'R339', '36 ST')),
#  (976, ('E005', 'R247', '55 ST')),
#  (974, ('C016', 'R278', '25 ST')),
#  (971, ('N194', 'R338', 'BEACH 36 ST')),
#  (950, ('R410', 'R450', 'LONGWOOD AV')),
#  (922, ('N135', 'R385', 'ROCKAWAY BLVD')),
#  (918, ('N212', 'R253', '174-175 STS')),
#  (912, ('N016A', 'R296', '163 ST-AMSTERDM')),
#  (886, ('N553', 'R422', 'BAY PKWY')),
#  (853, ('N130', 'R383', '80 ST')),
#  (844, ('R312', 'R405', 'JACKSON AV')),
#  (834, ('R117', 'R343', 'FRANKLIN ST')),
#  (828, ('N534', 'R220', 'CARROLL ST')),
#  (820, ('H013', 'R249', 'GRAHAM AV')),
#  (803, ('A071', 'R044', 'CHAMBERS ST')),
#  (790, ('PTH18', 'R549', 'NEWARK BM BW')),
#  (780, ('N210', 'R253', '174-175 STS')),
#  (771, ('N533', 'R129', 'BERGEN ST')),
#  (763, ('R327', 'R361', 'PELHAM PKWY')),
#  (746, ('R190', 'R038', '215 ST')),
#  (738, ('N012', 'R035', '168 ST')),
#  (734, ('J025', 'R003', 'CYPRESS HILLS')),
#  (725, ('R617', 'R058', 'BERGEN ST')),
#  (712, ('E016', 'R400', 'BAY 50 ST')),
#  (711, ('N193', 'R337', 'BEACH 44 ST')),
#  (703, ('R203A', 'R043', 'WALL ST')),
#  (701, ('H035', 'R348', 'ATLANTIC AV')),
#  (700, ('R641', 'R210', 'BEVERLY RD')),
#  (667, ('R121', 'R290', 'HOUSTON ST')),
#  (666, ('R407', 'R448', "E 143/ST MARY'S")),
#  (654, ('N545', 'R204', 'CHURCH AV')),
#  (643, ('R260', 'R205', '149/GRAND CONC')),
#  (638, ('N330C', 'R202', '63 DR-REGO PARK')),
#  (632, ('N087', 'R282', 'SPRING ST')),
#  (612, ('N562', 'R426', 'NEPTUNE AV')),
#  (597, ('N558', 'R130', 'KINGS HWY')),
#  (594, ('B034', 'R264', 'OCEAN PKWY')),
#  (534, ('N206', 'R104', '167 ST')),
#  (531, ('N137', 'R354', '104 ST')),
#  (521, ('N186', 'R418', 'BEACH 105 ST')),
#  (508, ('R729', 'R292', 'BAYCHESTER AV')),
#  (499, ('R318', 'R408', 'SIMPSON ST')),
#  (486, ('N139', 'R355', '111 ST')),
#  (483, ('A055', 'R227', 'RECTOR ST')),
#  (482, ('N420B', 'R317', 'CLINTON-WASH AV')),
#  (480, ('D008', 'R392', '18 AV')),
#  (465, ('N338', 'R128', 'SUTPHIN BLVD')),
#  (464, ('N182', 'R414', 'HOWARD BCH JFK')),
#  (430, ('R643', 'R135', 'NEWKIRK AV')),
#  (430, ('N329A', 'R201', 'WOODHAVEN BLVD')),
#  (424, ('R314', 'R406', 'PROSPECT AV')),
#  (417, ('C004', 'R089', 'JAY ST-METROTEC')),
#  (409, ('N544', 'R289', 'FT HAMILTON PKY')),
#  (408, ('R322', 'R386', '174 ST')),
#  (356, ('N418', 'R269', 'BEDFORD-NOSTRAN')),
#  (350, ('N547', 'R420', 'DITMAS AV')),
#  (330, ('N138', 'R355', '111 ST')),
#  (308, ('C026', 'R215', '86 ST')),
#  (302, ('R320', 'R409', 'FREEMAN ST')),
#  (300, ('R406', 'R448', "E 143/ST MARY'S")),
#  (294, ('D009', 'R393', '20 AV')),
#  (225, ('J032', 'R006', 'WOODHAVEN BLVD')),
#  (217, ('N416', 'R286', 'MYRTLE-WILLOUGH')),
#  (217, ('N218', 'R112', 'FORDHAM RD')),
#  (210, ('N339', 'R114', 'PARSONS BLVD')),
#  (207, ('A082', 'R028', 'FULTON ST')),
#  (202, ('N223', 'R156', 'BEDFORD PK BLVD')),
#  (167, ('N334B', 'R341', '75 AV')),
#  (164, ('N181A', 'R464', 'AQUEDUCT RACETR')),
#  (163, ('R308', 'R344', '145 ST')),
#  (161, ('N003', 'R185', 'DYCKMAN ST')),
#  (149, ('C028', 'R216', 'BAY RIDGE-95 ST')),
#  (145, ('PTH19', 'R549', 'NEWARK C')),
#  (139, ('R506', 'R276', 'VERNON-JACKSON')),
#  (130, ('J037', 'R009', '121 ST')),
#  (120, ('J034', 'R007', '104 ST')),
#  (100, ('G015', 'R312', 'W 8 ST-AQUARIUM')),
#  (96, ('N183', 'R415', 'BROAD CHANNEL')),
#  (96, ('N123B', 'R439', 'ROCKAWAY AV')),
#  (95, ('R196', 'R306', '238 ST')),
#  (74, ('N022', 'R332', '135 ST')),
#  (64, ('A084', 'R125', 'BROAD ST')),
#  (56, ('TRAM2', 'R469', 'RIT-ROOSEVELT')),
#  (55, ('TRAM1', 'R468', 'RIT-MANHATTAN')),
#  (18, ('OB01', 'R459', 'ORCHARD BEACH')),
#  (0, ('S102', 'R165', 'TOMPKINSVILLE')),
#  (0, ('S101A', 'R070', 'ST. GEORGE')),
#  (0, ('S101', 'R070', 'ST. GEORGE')),
#  (0, ('R262B', 'R195', '161/YANKEE STAD')),
#  (0, ('R262A', 'R195', '161/YANKEE STAD')),
#  (0, ('N554', 'R423', 'AVENUE N')),
#  (0, ('N550', 'R242', '18 AV')),
#  (0, ('A085', 'R125', 'BROAD ST'))]

# %% [markdown]
# 16.Create a barchart for the number of riders. You don't need to keep track of the names of each station, as that would get really messy to plot. Instead, you can just use a list comprehension to save the rider numbers to the y-values and give the stations the numbers 0,1,2,3,... for the x-values. You can use the following piece of code. Remember to add in axis labels and a title.
#
# x = range(len(tuple_list))
#
# y = [tuple_list[i][0] for i in range(len(tuple_list))]
#
# plt.bar(x,y)

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

x = range(len(tuple_list))
y = [tuple_list[i][0] for i in range(len(tuple_list))]
plt.bar(x,y)
plt.xlabel('station number')
plt.ylabel('daily rider entries')

# %% [markdown]
# 17.Perhaps we don't care about total ridership in a 24 period. Perhaps we only care about the morning commute. Let's assume that the majority of people arrive at their work location subway exit between 8 and 9 am.
#
# Go back up to your frequency chart in Exercise 9. Note that the most common morning commutes would be gained from subtracting 9 am - 5 am and 10 am - 6 am and 11 am - 7 am and 12pm - 8am, for the stations that are broken down by those specific four hour intervals.
#
# As a dirty way to consider only the stations that are on these time intervals, save just the rows in your original monday dataframe that contain the TIME strings '05:00:00', '06:00:00',..., '12:00:00'. Remember you can do this by using OR statements using the "|" symbol and remembering parenthesis. Call this new dataframe "morning". Be sure to reset its index.

# %%
morning=monday[(monday.TIME =='12:00:00') | 
                (monday.TIME =='05:00:00') |
                (monday.TIME =='06:00:00') |
                (monday.TIME =='07:00:00') |
                (monday.TIME =='08:00:00') |
                (monday.TIME =='09:00:00') |
                (monday.TIME =='10:00:00') |
                (monday.TIME =='11:00:00') ]
morning = morning.reset_index(drop=True)

# %% [markdown]
# 18.Now create a morning_dict by repeating your work in Exercise 7 on this morning dataframe. The dictionary should map the tuple (C/A, UNIT, SCP,STATION) to an inner dictionary containing {TIME: EXITS} for all Monday rides.
#
# Hint: ('A002', 'R051', '02-00-00','59 ST') should map to {'08:00:00': 2104813, '12:00:00': 2105024}.

# %%
morning_dict={}
for i in range(len(morning.index)):
    mytuple = (morning['C/A'][i], morning.UNIT[i], morning.SCP[i],morning.STATION[i])
    if mytuple not in morning_dict.keys():
        morning_dict[mytuple]={morning.TIME[i]:morning.EXITS[i]}
    else:
        morning_dict[mytuple][morning.TIME[i]]=morning.EXITS[i]
morning_dict[('A002', 'R051', '02-00-00','59 ST')]
# Out:
# {'08:00:00': 2104813, '12:00:00': 2105024}

# %% [markdown]
# 19.We're almost ready to subtract the two consecutive times for each station to get the morning commutes. That is, if there are exactly two times for each station. Find which stations keys in your dictionary above do not contain exactly two times and delete them from the morning dictionary.
#
# How many keys are left in your morning_dict? There should be 4293.

# %%
delete_keys = []
for key,val in morning_dict.items():
    if len(val.keys())!=2:
        delete_keys.append(key)
print(delete_keys)

for key in delete_keys:
    if key in morning_dict:
        del morning_dict[key]
print(len(morning_dict.keys()))
# Out:
# [('N103', 'R127', '00-06-01', 'JAY ST-METROTEC'), ('PTH22', 'R540', '02-05-06', 'PATH NEW WTC'), ('R245', 'R051', '00-05-00', '59 ST'), ('R302', 'R324', '01-00-01', '116 ST'), ('R307', 'R207', '01-00-02', '135 ST'), ('R501', 'R054', '00-00-00', '5 AVE')]
# 4293

# %% [markdown]
# 20.Create a dictionary called morning_differences where (C/A, UNIT, STATION) maps to an inner dictionary containing {SCP: Morning Exit Differences}.
#
# For example, ('A002', 'R051', '59 ST') should map to:
#
# {'02-00-00': 211,
#  '02-00-01': 128,
#  '02-03-00': 654,
#  '02-03-01': 630,
#  '02-03-02': 533,
#  '02-03-03': 401,
#  '02-03-04': 186,
#  '02-03-05': 49,
#  '02-03-06': 8,
#  '02-05-00': 0,
#  '02-05-01': 0,
#  '02-06-00': 4}

# %%
morning_differences = {}
for turnstile,times in morning_dict.items():
    mytuple = (turnstile[0], turnstile[1], turnstile[3])
    count = 0
    for time, exit in times.items():
        count = exit - count
    if mytuple not in morning_differences:
        morning_differences[mytuple]={turnstile[2]:count}
    else:
        morning_differences[mytuple][turnstile[2]]=count
morning_differences[('A002', 'R051','59 ST')]
# Out:
# {'02-00-00': 211,
#  '02-00-01': 128,
#  '02-03-00': 654,
#  '02-03-01': 630,
#  '02-03-02': 533,
#  '02-03-03': 401,
#  '02-03-04': 186,
#  '02-03-05': 49,
#  '02-03-06': 8,
#  '02-05-00': 0,
#  '02-05-01': 0,
#  '02-06-00': 4}

# %% [markdown]
# 21.Create a dictionary called total_morning_diff that maps each (C/A, Unit, Station) location to the total morning riders passing through ALL of the turnstiles in that area.
#
# Hint 1: see your work in Exercise 13.
# Hint 2: ('A002', 'R051','59 ST') should have 2804 morning commuter exits.

# %%
total_morning_diff={}
for key,turnstiles in morning_differences.items():
    count = 0
    for turnstile,exits in turnstiles.items():
        count = count + exits
    total_morning_diff[key] = count
total_morning_diff[('A002', 'R051','59 ST')]
# Out:
# 2804

# %% [markdown]
# 22.Create a list of sorted tuples to see the most popular morning exits.
#
# Hint:  ('R238', 'R046', 'GRD CNTRL-42 ST') should be the highest with 17,300 morning exits.

# %%
tuple_list = []
for station, turnstiles in morning_differences.items():
    count = 0 
    for exit in turnstiles.values():
        count = count + exit
    tuple_list.append((count,station))
tuple_list.sort(reverse = True)
tuple_list
# Out:
# [(17300, ('R238', 'R046', 'GRD CNTRL-42 ST')),
#  (16250, ('N500', 'R020', '47-50 STS ROCK')),
#  (13194, ('N501', 'R020', '47-50 STS ROCK')),
#  (12576, ('N306', 'R017', 'LEXINGTON AV/53')),
#  (12545, ('R240', 'R047', 'GRD CNTRL-42 ST')),
#  (10593, ('N504', 'R021', '42 ST-BRYANT PK')),
#  (10213, ('A025', 'R023', '34 ST-HERALD SQ')),
#  (9605, ('N304', 'R015', '5 AV/53 ST')),
#  (9393, ('A021', 'R032', 'TIMES SQ-42 ST')),
#  (9234, ('N505', 'R022', '34 ST-HERALD SQ')),
#  (8903, ('R249', 'R179', '86 ST')),
#  (8893, ('N051', 'R084', '59 ST COLUMBUS')),
#  (8049, ('R116', 'R030', 'CHAMBERS ST')),
#  (7708, ('N049', 'R084', '59 ST COLUMBUS')),
#  (7641, ('N303', 'R015', '5 AV/53 ST')),
#  (7423, ('N305', 'R017', 'LEXINGTON AV/53')),
#  (7155, ('N507', 'R023', '34 ST-HERALD SQ')),
#  (6820, ('R143', 'R032', 'TIMES SQ-42 ST')),
#  (6776, ('R151', 'R033', 'TIMES SQ-42 ST')),
#  (6531, ('N506', 'R022', '34 ST-HERALD SQ')),
#  (6373, ('R145', 'R032', 'TIMES SQ-42 ST')),
#  (6360, ('N098', 'R028', 'FULTON ST')),
#  (6251, ('N503', 'R021', '42 ST-BRYANT PK')),
#  (6194, ('N501A', 'R020', '47-50 STS ROCK')),
#  (6187, ('R155', 'R116', '50 ST')),
#  (5974, ('R243', 'R049', '51 ST')),
#  (5929, ('N520', 'R240', 'GRAND ST')),
#  (5856, ('R245A', 'R051', '59 ST')),
#  (5727, ('R206', 'R014', 'FULTON ST')),
#  (5708, ('R202', 'R042', 'BOWLING GREEN')),
#  (5696, ('R258', 'R132', '125 ST')),
#  (5512, ('R236', 'R045', 'GRD CNTRL-42 ST')),
#  (5392, ('R182', 'R035', '168 ST')),
#  (5309, ('R246', 'R177', '68ST-HUNTER CO')),
#  (5046, ('A033', 'R170', '14 ST-UNION SQ')),
#  (5020, ('N509', 'R203', '23 ST')),
#  (5009, ('R111', 'R027', 'WALL ST')),
#  (4932, ('R210', 'R044', 'BROOKLYN BRIDGE')),
#  (4864, ('R533', 'R055', 'FLUSHING-MAIN')),
#  (4847, ('N092', 'R029', 'CHAMBERS ST')),
#  (4754, ('N305A', 'R016', 'LEXINGTON AV/53')),
#  (4751, ('N508', 'R453', '23 ST')),
#  (4658, ('N083', 'R138', 'W 4 ST-WASH SQ')),
#  (4650, ('R201', 'R041', 'BOWLING GREEN')),
#  (4635, ('R204', 'R043', 'WALL ST')),
#  (4617, ('R154', 'R116', '50 ST')),
#  (4571, ('R113', 'R028', 'FULTON ST')),
#  (4544, ('A022', 'R022', '34 ST-HERALD SQ')),
#  (4440, ('R244', 'R050', '59 ST')),
#  (4376, ('N102', 'R127', 'JAY ST-METROTEC')),
#  (4346, ('R221', 'R170', '14 ST-UNION SQ')),
#  (4336, ('R237', 'R046', 'GRD CNTRL-42 ST')),
#  (4324, ('R247', 'R178', '77 ST')),
#  (4312, ('H009', 'R235', 'BEDFORD AV')),
#  (4305, ('R550', 'R072', '34 ST-HUDSON YD')),
#  (4305, ('N089', 'R139', 'CANAL ST')),
#  (4266, ('A034', 'R170', '14 ST-UNION SQ')),
#  (4171, ('N601', 'R319', 'LEXINGTON AV/63')),
#  (4108, ('R244A', 'R050', '59 ST')),
#  (4094, ('N600', 'R302', '57 ST')),
#  (3965, ('N606', 'R025', 'JAMAICA CENTER')),
#  (3875, ('N067', 'R012', '34 ST-PENN STA')),
#  (3862, ('N301', 'R113', '7 AV')),
#  (3853, ('R110', 'R027', 'WALL ST')),
#  (3841, ('N103', 'R127', 'JAY ST-METROTEC')),
#  (3775, ('R501', 'R054', '5 AVE')),
#  (3765, ('R601A', 'R108', 'BOROUGH HALL')),
#  (3747, ('R142', 'R293', '34 ST-PENN STA')),
#  (3721, ('N091', 'R029', 'CHAMBERS ST')),
#  (3628, ('N062A', 'R010', '42 ST-PORT AUTH')),
#  (3611, ('N094', 'R029', 'WORLD TRADE CTR')),
#  (3580, ('N502', 'R021', '42 ST-BRYANT PK')),
#  (3575, ('N700A', 'R570', '72 ST-2 AVE')),
#  (3555, ('N026', 'R102', '125 ST')),
#  (3499, ('R158', 'R084', '59 ST COLUMBUS')),
#  (3495, ('N095A', 'R014', 'FULTON ST')),
#  (3481, ('N060', 'R010', '42 ST-PORT AUTH')),
#  (3446, ('R147', 'R033', 'TIMES SQ-42 ST')),
#  (3410, ('R169', 'R168', '96 ST')),
#  (3382, ('R516', 'R291', '33 ST-RAWSON ST')),
#  (3378, ('R148', 'R033', 'TIMES SQ-42 ST')),
#  (3347, ('R610', 'R057', 'ATL AV-BARCLAY')),
#  (3343, ('R112', 'R027', 'WALL ST')),
#  (3340, ('R200A', 'R041', 'BOWLING GREEN')),
#  (3315, ('N324', 'R018', 'JKSN HT-ROOSVLT')),
#  (3307, ('A006', 'R079', '5 AV/59 ST')),
#  (3302, ('R242', 'R049', '51 ST')),
#  (3285, ('N605', 'R024', 'SUTPHIN-ARCHER')),
#  (3270, ('N400A', 'R359', 'COURT SQ')),
#  (3210, ('N700', 'R570', '72 ST-2 AVE')),
#  (3204, ('R526', 'R096', '82 ST-JACKSON H')),
#  (3158, ('H008', 'R248', '1 AV')),
#  (3143, ('R228', 'R143', '28 ST')),
#  (3075, ('A042', 'R086', 'PRINCE ST')),
#  (3066, ('A029', 'R082', '28 ST')),
#  (3040, ('A031', 'R083', '23 ST')),
#  (3026, ('N090', 'R139', 'CANAL ST')),
#  (3024, ('N601A', 'R319', 'LEXINGTON AV/63')),
#  (3012, ('R161B', 'R452', '72 ST')),
#  (2957, ('A015', 'R081', '49 ST')),
#  (2956, ('R216', 'R322', 'SPRING ST')),
#  (2912, ('N519', 'R461', "B'WAY-LAFAYETTE")),
#  (2896, ('R602', 'R108', 'BOROUGH HALL')),
#  (2867, ('N078', 'R175', '14 ST')),
#  (2866, ('A035', 'R170', '14 ST-UNION SQ')),
#  (2864, ('R112A', 'R027', 'WALL ST')),
#  (2841, ('A046', 'R463', 'CANAL ST')),
#  (2828, ('A030', 'R083', '23 ST')),
#  (2810, ('A043', 'R462', 'CANAL ST')),
#  (2804, ('A002', 'R051', '59 ST')),
#  (2803, ('N071', 'R013', '34 ST-PENN STA')),
#  (2778, ('A010', 'R080', '57 ST-7 AV')),
#  (2745, ('C009', 'R057', 'ATL AV-BARCLAY')),
#  (2728, ('A049', 'R088', 'CORTLANDT ST')),
#  (2721, ('R101', 'R001', 'SOUTH FERRY')),
#  (2692, ('R226', 'R131', '23 ST')),
#  (2690, ('N108', 'R217', 'HOYT-SCHER')),
#  (2689, ('N063A', 'R011', '42 ST-PORT AUTH')),
#  (2641, ('N095', 'R014', 'FULTON ST')),
#  (2639, ('A013', 'R081', '49 ST')),
#  (2629, ('R138', 'R293', '34 ST-PENN STA')),
#  (2572, ('N020', 'R101', '145 ST')),
#  (2552, ('R159', 'R164', '66 ST-LINCOLN')),
#  (2549, ('N300', 'R113', '7 AV')),
#  (2538, ('R237B', 'R047', 'GRD CNTRL-42 ST')),
#  (2497, ('R210A', 'R044', 'BROOKLYN BRIDGE')),
#  (2490, ('R248', 'R178', '77 ST')),
#  (2487, ('A081', 'R028', 'FULTON ST')),
#  (2411, ('R141', 'R031', '34 ST-PENN STA')),
#  (2380, ('N070', 'R012', '34 ST-PENN STA')),
#  (2373, ('R232', 'R176', '33 ST')),
#  (2370, ('N076', 'R111', '23 ST')),
#  (2321, ('R114', 'R028', 'FULTON ST')),
#  (2317, ('H001', 'R175', '8 AV')),
#  (2310, ('C008', 'R099', 'DEKALB AV')),
#  (2302, ('N068', 'R012', '34 ST-PENN STA')),
#  (2262, ('N512', 'R163', '14 ST')),
#  (2255, ('A039', 'R085', '8 ST-NYU')),
#  (2238, ('N056', 'R188', '50 ST')),
#  (2235, ('R203', 'R043', 'WALL ST')),
#  (2218, ('A060', 'R001', 'WHITEHALL S-FRY')),
#  (2213, ('R252', 'R180', '103 ST')),
#  (2195, ('N309A', 'R140', 'QUEENS PLAZA')),
#  (2187, ('N046', 'R281', '72 ST')),
#  (2175, ('R168A', 'R168', '96 ST')),
#  (2162, ('H007', 'R248', '1 AV')),
#  (2155, ('R242A', 'R049', '51 ST')),
#  (2147, ('R507', 'R134', 'HUNTERS PT AV')),
#  (2134, ('R534', 'R055', 'FLUSHING-MAIN')),
#  (2115, ('N073', 'R013', '34 ST-PENN STA')),
#  (2066, ('R183', 'R260', '181 ST')),
#  (2059, ('A027', 'R082', '28 ST')),
#  (2053, ('N069', 'R013', '34 ST-PENN STA')),
#  (2052, ('N519A', 'R461', "B'WAY-LAFAYETTE")),
#  (2009, ('N510', 'R163', '14 ST')),
#  (2004, ('R102', 'R304', 'RECTOR ST')),
#  (1993, ('R137', 'R031', '34 ST-PENN STA')),
#  (1944, ('R229', 'R143', '28 ST')),
#  (1900, ('A058', 'R001', 'WHITEHALL S-FRY')),
#  (1878, ('N077', 'R111', '23 ST')),
#  (1863, ('R132', 'R190', '23 ST')),
#  (1853, ('R127', 'R105', '14 ST')),
#  (1830, ('R523', 'R147', '61 ST WOODSIDE')),
#  (1817, ('R208', 'R014', 'FULTON ST')),
#  (1810, ('A011', 'R080', '57 ST-7 AV')),
#  (1793, ('N523', 'R300', '2 AV')),
#  (1770, ('R508', 'R346', 'COURT SQ')),
#  (1768, ('A069', 'R044', 'CHAMBERS ST')),
#  (1766, ('R173', 'R159', '116 ST-COLUMBIA')),
#  (1745, ('N080', 'R138', 'W 4 ST-WASH SQ')),
#  (1719, ('R165', 'R167', '86 ST')),
#  (1717, ('A047', 'R087', 'CITY HALL')),
#  (1711, ('N072', 'R012', '34 ST-PENN STA')),
#  (1703, ('R124', 'R290', 'HOUSTON ST')),
#  (1682, ('R528', 'R097', 'JUNCTION BLVD')),
#  (1679, ('R261', 'R205', '149/GRAND CONC')),
#  (1661, ('R605', 'R456', 'HOYT ST')),
#  (1633, ('R220', 'R160', 'ASTOR PL')),
#  (1630, ('A061', 'R142', 'DELANCEY/ESSEX')),
#  (1613, ('B016', 'R098', 'CHURCH AV')),
#  (1612, ('N063', 'R011', '42 ST-PORT AUTH')),
#  (1607, ('R626', 'R062', 'CROWN HTS-UTICA')),
#  (1587, ('A037', 'R170', '14 ST-UNION SQ')),
#  (1578, ('R217A', 'R194', 'BLEECKER ST')),
#  (1571, ('R115', 'R029', 'PARK PLACE')),
#  (1561, ('A014', 'R081', '49 ST')),
#  (1552, ('R161A', 'R452', '72 ST')),
#  (1532, ('D002', 'R390', '8 AV')),
#  (1525, ('R412', 'R146', 'HUNTS POINT AV')),
#  (1522, ('N044', 'R187', '81 ST-MUSEUM')),
#  (1513, ('N511', 'R163', '14 ST')),
#  (1507, ('R529', 'R208', '103 ST-CORONA')),
#  (1503, ('R301', 'R323', 'CENTRAL PK N110')),
#  (1502, ('R135', 'R031', '34 ST-PENN STA')),
#  (1488, ('N607', 'R025', 'JAMAICA CENTER')),
#  (1446, ('R174', 'R034', '125 ST')),
#  (1444, ('N536', 'R270', 'SMITH-9 ST')),
#  (1436, ('H005', 'R330', '3 AV')),
#  (1434, ('R609', 'R056', 'NEVINS ST')),
#  (1430, ('N101', 'R252', 'HIGH ST')),
#  (1420, ('R420', 'R107', 'WESTCHESTER SQ')),
#  (1412, ('R283', 'R221', '167 ST')),
#  (1399, ('R331', 'R364', 'GUN HILL RD')),
#  (1393, ('R518', 'R261', '40 ST LOWERY ST')),
#  (1390, ('R204A', 'R043', 'WALL ST')),
#  (1390, ('N603', 'R303', '21 ST-QNSBRIDGE')),
#  (1390, ('C012', 'R258', '4AV-9 ST')),
#  (1387, ('N062', 'R011', '42 ST-PORT AUTH')),
#  (1374, ('R185', 'R274', '191 ST')),
#  (1367, ('A041', 'R086', 'PRINCE ST')),
#  (1365, ('R612', 'R057', 'ATL AV-BARCLAY')),
#  (1344, ('R130', 'R321', '18 ST')),
#  (1341, ('N405', 'R239', 'GREENPOINT AV')),
#  (1335, ('R250', 'R179', '86 ST')),
#  (1331, ('C018', 'R197', '36 ST')),
#  (1331, ('B031', 'R172', 'BRIGHTON BEACH')),
#  (1325, ('A016', 'R081', '49 ST')),
#  (1323, ('N539A', 'R288', '7 AV')),
#  (1313, ('R126', 'R189', 'CHRISTOPHER ST')),
#  (1312, ('R134', 'R272', '28 ST')),
#  (1295, ('R251', 'R144', '96 ST')),
#  (1286, ('N057', 'R188', '50 ST')),
#  (1276, ('R205A', 'R014', 'FULTON ST')),
#  (1269, ('N525', 'R142', 'DELANCEY/ESSEX')),
#  (1269, ('N043', 'R186', '86 ST')),
#  (1255, ('R164', 'R167', '86 ST')),
#  (1252, ('R256', 'R182', '116 ST')),
#  (1250, ('R160A', 'R164', '66 ST-LINCOLN')),
#  (1245, ('N521', 'R300', '2 AV')),
#  (1241, ('R509', 'R121', 'QUEENSBORO PLZ')),
#  (1234, ('R160', 'R164', '66 ST-LINCOLN')),
#  (1226, ('R503', 'R276', 'VERNON-JACKSON')),
#  (1223, ('N513', 'R163', '14 ST')),
#  (1221, ('N701A', 'R571', '86 ST-2 AVE')),
#  (1210, ('R311', 'R053', '3 AV-149 ST')),
#  (1191, ('N124', 'R103', 'BROADWAY JCT')),
#  (1190, ('R417', 'R222', 'PARKCHESTER')),
#  (1184, ('B024', 'R211', 'KINGS HWY')),
#  (1180, ('A083', 'R125', 'BROAD ST')),
#  (1172, ('R231A', 'R176', '33 ST')),
#  (1171, ('J001', 'R460', 'MARCY AV')),
#  (1166, ('JFK03', 'R536', 'JFK JAMAICA CT1')),
#  (1162, ('R231', 'R176', '33 ST')),
#  (1149, ('R513', 'R093', '30 AV')),
#  (1134, ('R608', 'R056', 'NEVINS ST')),
#  (1122, ('R527', 'R122', '90 ST-ELMHURST')),
#  (1116, ('R512', 'R092', 'BROADWAY')),
#  (1115, ('N040', 'R251', '96 ST')),
#  (1113, ('N315', 'R238', 'STEINWAY ST')),
#  (1108, ('R284', 'R243', '170 ST')),
#  (1091, ('N327', 'R254', 'GRAND-NEWTOWN')),
#  (1074, ('A050', 'R088', 'CORTLANDT ST')),
#  (1072, ('R245', 'R051', '59 ST')),
#  (1060, ('R515', 'R095', 'ASTORIA DITMARS')),
#  (1058, ('J002', 'R460', 'MARCY AV')),
#  (1058, ('A007', 'R079', '5 AV/59 ST')),
#  (1051, ('N323', 'R018', 'JKSN HT-ROOSVLT')),
#  (1050, ('R519', 'R223', '46 ST BLISS ST')),
#  (1050, ('B027', 'R136', 'SHEEPSHEAD BAY')),
#  (1049, ('H016', 'R250', 'GRAND ST')),
#  (1026, ('N339A', 'R114', 'PARSONS BLVD')),
#  (1025, ('R120', 'R320', 'CANAL ST')),
#  (1024, ('N702', 'R572', '96 ST-2 AVE')),
#  (1007, ('R511', 'R091', '36 AV')),
#  (999, ('N422', 'R318', 'FULTON ST')),
#  (964, ('R604', 'R108', 'BOROUGH HALL')),
#  (954, ('B024A', 'R211', 'KINGS HWY')),
#  (952, ('C003', 'R089', 'JAY ST-METROTEC')),
#  (946, ('N702A', 'R572', '96 ST-2 AVE')),
#  (944, ('N329', 'R201', 'WOODHAVEN BLVD')),
#  (938, ('R253', 'R181', '110 ST')),
#  (932, ('R128', 'R105', '14 ST')),
#  (930, ('N330', 'R202', '63 DR-REGO PARK')),
#  (924, ('R232A', 'R176', '33 ST')),
#  (918, ('A064', 'R311', 'BOWERY')),
#  (912, ('C025', 'R215', '86 ST')),
#  (907, ('N116', 'R198', 'NOSTRAND AV')),
#  (902, ('B004', 'R171', '7 AV')),
#  (898, ('N117', 'R198', 'NOSTRAND AV')),
#  (885, ('N528', 'R257', 'EAST BROADWAY')),
#  (882, ('R238A', 'R046', 'GRD CNTRL-42 ST')),
#  (882, ('N217', 'R112', 'FORDHAM RD')),
#  (879, ('A077', 'R028', 'FULTON ST')),
#  (875, ('N310', 'R140', 'QUEENS PLAZA')),
#  (869, ('N526', 'R142', 'DELANCEY/ESSEX')),
#  (866, ('R304', 'R206', '125 ST')),
#  (866, ('N535', 'R220', 'CARROLL ST')),
#  (864, ('B029', 'R172', 'BRIGHTON BEACH')),
#  (861, ('N537', 'R258', '4 AV-9 ST')),
#  (859, ('H014', 'R249', 'GRAHAM AV')),
#  (859, ('B022', 'R229', 'AVENUE M')),
#  (850, ('N604', 'R342', 'JAMAICA VAN WK')),
#  (848, ('R423', 'R429', 'PELHAM BAY PARK')),
#  (843, ('R230', 'R143', '28 ST')),
#  (836, ('R530', 'R310', '111 ST')),
#  (835, ('H003', 'R163', '6 AV')),
#  (834, ('E004', 'R234', '50 ST')),
#  (833, ('N120', 'R153', 'UTICA AV')),
#  (833, ('N013', 'R035', '168 ST')),
#  (828, ('R629', 'R065', 'ROCKAWAY AV')),
#  (824, ('G009', 'R151', 'CONEY IS-STILLW')),
#  (819, ('N307', 'R359', 'COURT SQ-23 ST')),
#  (814, ('R517', 'R291', '33 ST-RAWSON ST')),
#  (809, ('R418', 'R106', 'CASTLE HILL AV')),
#  (803, ('G011', 'R312', 'W 8 ST-AQUARIUM')),
#  (802, ('R401', 'R445', '3 AV 138 ST')),
#  (797, ('R103', 'R304', 'RECTOR ST')),
#  (797, ('N602', 'R259', 'ROOSEVELT ISLND')),
#  (796, ('R175', 'R169', '137 ST CITY COL')),
#  (794, ('R171', 'R192', 'CATHEDRAL PKWY')),
#  (794, ('N025', 'R102', '125 ST')),
#  (792, ('R287', 'R244', 'BURNSIDE AV')),
#  (790, ('N546', 'R204', 'CHURCH AV')),
#  (788, ('R291', 'R183', 'BEDFORD PK BLVD')),
#  (786, ('R622', 'R123', 'FRANKLIN AV')),
#  (780, ('R336', 'R145', 'WAKEFIELD/241')),
#  (779, ('A054', 'R227', 'RECTOR ST')),
#  (766, ('R634', 'R069', 'NEW LOTS AV')),
#  (766, ('N549', 'R242', '18 AV')),
#  (766, ('N196', 'R285', 'FAR ROCKAWAY')),
#  (760, ('N213', 'R154', 'TREMONT AV')),
#  (753, ('N312', 'R339', '36 ST')),
#  (749, ('R290', 'R161', 'KINGSBRIDGE RD')),
#  (741, ('C019', 'R232', '45 ST')),
#  (739, ('N316A', 'R267', '46 ST')),
#  (736, ('R635', 'R277', 'PRESIDENT ST')),
#  (736, ('N530', 'R301', 'YORK ST')),
#  (733, ('R310', 'R053', '3 AV-149 ST')),
#  (728, ('J007', 'R377', 'FLUSHING AV')),
#  (726, ('H019', 'R294', 'MORGAN AV')),
#  (725, ('H026', 'R137', 'MYRTLE-WYCKOFF')),
#  (724, ('R177', 'R273', '145 ST')),
#  (721, ('N701', 'R571', '86 ST-2 AVE')),
#  (721, ('N086', 'R282', 'SPRING ST')),
#  (715, ('N333B', 'R141', 'FOREST HILLS 71')),
#  (714, ('N100', 'R252', 'HIGH ST')),
#  (709, ('N419', 'R287', 'CLASSON AV')),
#  (707, ('R285', 'R308', 'MT EDEN AV')),
#  (707, ('R254', 'R181', '110 ST')),
#  (699, ('R514', 'R094', 'ASTORIA BLVD')),
#  (697, ('H006', 'R330', '3 AV')),
#  (696, ('D005', 'R398', 'NEW UTRECHT AV')),
#  (694, ('R131', 'R190', '23 ST')),
#  (690, ('N401', 'R360', '21 ST')),
#  (689, ('R227A', 'R131', '23 ST')),
#  (689, ('B019', 'R149', 'NEWKIRK PLAZA')),
#  (688, ('R730', 'R431', 'EASTCHSTER/DYRE')),
#  (687, ('R133', 'R272', '28 ST')),
#  (682, ('R525', 'R018', '74 ST-BROADWAY')),
#  (677, ('R219', 'R160', 'ASTOR PL')),
#  (676, ('N010', 'R126', '175 ST')),
#  (674, ('R624', 'R124', 'KINGSTON AV')),
#  (673, ('R628', 'R064', 'SARATOGA AV')),
#  (673, ('R170', 'R191', '103 ST')),
#  (671, ('R162', 'R166', '79 ST')),
#  (668, ('J020', 'R433', 'ALABAMA AV')),
#  (666, ('R510', 'R090', '39 AV')),
#  (657, ('R600', 'R224', 'CLARK ST')),
#  (654, ('N408A', 'R256', 'NASSAU AV')),
#  (654, ('H039', 'R375', 'NEW LOTS')),
#  (652, ('N409', 'R268', 'METROPOLITAN AV')),
#  (652, ('N039', 'R251', '96 ST')),
#  (652, ('H027', 'R137', 'MYRTLE-WYCKOFF')),
#  (649, ('A038', 'R085', '8 ST-NYU')),
#  (647, ('N529', 'R257', 'EAST BROADWAY')),
#  (646, ('N019', 'R101', '145 ST')),
#  (645, ('N141', 'R356', 'OZONE PK LEFFRT')),
#  (643, ('R504', 'R276', 'VERNON-JACKSON')),
#  (641, ('R323', 'R387', 'WEST FARMS SQ')),
#  (637, ('R215', 'R322', 'SPRING ST')),
#  (634, ('R606', 'R225', 'HOYT ST')),
#  (634, ('B012', 'R196', 'PROSPECT PARK')),
#  (629, ('A066', 'R118', 'CANAL ST')),
#  (628, ('R118', 'R343', 'FRANKLIN ST')),
#  (621, ('H040', 'R376', 'EAST 105 ST')),
#  (619, ('R623', 'R061', 'NOSTRAND AV')),
#  (618, ('N531', 'R129', 'BERGEN ST')),
#  (618, ('N343', 'R019', 'JAMAICA 179 ST')),
#  (615, ('R625', 'R062', 'CROWN HTS-UTICA')),
#  (612, ('B021', 'R228', 'AVENUE J')),
#  (609, ('H017', 'R265', 'MONTROSE AV')),
#  (598, ('R415', 'R120', 'MORISN AV/SNDVW')),
#  (591, ('R129', 'R321', '18 ST')),
#  (589, ('R403', 'R446', 'BROOK AV')),
#  (588, ('R621', 'R060', 'EASTN PKWY-MUSM')),
#  (587, ('J009', 'R378', 'MYRTLE AV')),
#  (585, ('R286', 'R309', '176 ST')),
#  (584, ('R414', 'R162', 'ELDER AV')),
#  (583, ('R163', 'R166', '79 ST')),
#  (577, ('R524', 'R347', '69 ST')),
#  (574, ('R325', 'R388', 'E 180 ST')),
#  (571, ('H015', 'R250', 'GRAND ST')),
#  (568, ('G001', 'R151', 'CONEY IS-STILLW')),
#  (567, ('R139', 'R031', '34 ST-PENN STA')),
#  (557, ('N128', 'R200', 'EUCLID AV')),
#  (555, ('N024', 'R332', '135 ST')),
#  (551, ('R259', 'R307', '138/GRAND CONC')),
#  (537, ('R186', 'R036', 'DYCKMAN ST')),
#  (535, ('N111', 'R284', 'CLINTON-WASH AV')),
#  (532, ('R532', 'R328', 'METS-WILLETS PT')),
#  (531, ('N340', 'R115', '169 ST')),
#  (531, ('C021', 'R212', '59 ST')),
#  (524, ('R309', 'R345', 'HARLEM 148 ST')),
#  (522, ('R293', 'R133', 'MOSHOLU PKWY')),
#  (518, ('R123', 'R290', 'HOUSTON ST')),
#  (513, ('N207', 'R104', '167 ST')),
#  (512, ('C017', 'R455', '25 ST')),
#  (511, ('E001', 'R368', '9 AV')),
#  (510, ('R203A', 'R043', 'WALL ST')),
#  (510, ('B013', 'R196', 'PROSPECT PARK')),
#  (505, ('R316', 'R407', 'INTERVALE AV')),
#  (504, ('H023', 'R236', 'DEKALB AV')),
#  (502, ('R619', 'R059', 'GRAND ARMY PLAZ')),
#  (494, ('R321', 'R386', '174 ST')),
#  (493, ('N118', 'R199', 'KINGSTON-THROOP')),
#  (490, ('N412', 'R299', 'BROADWAY')),
#  (489, ('R188', 'R037', '207 ST')),
#  (488, ('C011', 'R231', 'UNION ST')),
#  (487, ('R176', 'R169', '137 ST CITY COL')),
#  (485, ('R521', 'R327', '52 ST')),
#  (482, ('N114', 'R297', 'FRANKLIN AV')),
#  (478, ('R411', 'R450', 'LONGWOOD AV')),
#  (478, ('R197', 'R117', 'V.CORTLANDT PK')),
#  (477, ('N314', 'R238', 'STEINWAY ST')),
#  (470, ('N331', 'R219', '67 AV')),
#  (469, ('D010', 'R394', 'BAY PKWY')),
#  (467, ('N340A', 'R115', '169 ST')),
#  (467, ('E014', 'R374', 'BAY PKWY')),
#  (465, ('B010', 'R412', 'BOTANIC GARDEN')),
#  (458, ('R257', 'R182', '116 ST')),
#  (455, ('N129', 'R382', 'GRANT AV')),
#  (444, ('B023', 'R211', 'KINGS HWY')),
#  (442, ('R288', 'R275', '183 ST')),
#  (441, ('R226A', 'R131', '23 ST')),
#  (441, ('N222', 'R156', 'BEDFORD PK BLVD')),
#  (436, ('N030', 'R333', '116 ST')),
#  (430, ('R319', 'R409', 'FREEMAN ST')),
#  (430, ('N120A', 'R153', 'UTICA AV')),
#  (427, ('R125', 'R189', 'CHRISTOPHER ST')),
#  (420, ('R647', 'R110', 'FLATBUSH AV-B.C')),
#  (420, ('N417', 'R269', 'BEDFORD-NOSTRAN')),
#  (420, ('B015', 'R098', 'CHURCH AV')),
#  (419, ('R409', 'R449', 'E 149 ST')),
#  (417, ('R305', 'R206', '125 ST')),
#  (416, ('E003', 'R369', 'FT HAMILTON PKY')),
#  (415, ('R172', 'R192', 'CATHEDRAL PKWY')),
#  (415, ('C001', 'R108', 'BOROUGH HALL')),
#  (412, ('N414', 'R316', 'FLUSHING AV')),
#  (410, ('R416', 'R245', 'ST LAWRENCE AV')),
#  (408, ('R405', 'R447', 'CYPRESS AV')),
#  (407, ('C027', 'R216', 'BAY RIDGE-95 ST')),
#  (405, ('N319', 'R298', 'NORTHERN BLVD')),
#  (403, ('B020', 'R263', 'AVENUE H')),
#  (402, ('R419', 'R326', 'ZEREGA AV')),
#  (399, ('N333A', 'R141', 'FOREST HILLS 71')),
#  (393, ('J024', 'R437', 'CRESCENT ST')),
#  (387, ('N342', 'R019', 'JAMAICA 179 ST')),
#  (386, ('R178', 'R273', '145 ST')),
#  (385, ('N318', 'R298', 'NORTHERN BLVD')),
#  (385, ('N035', 'R334', 'CATHEDRAL PKWY')),
#  (384, ('N122', 'R439', 'ROCKAWAY AV')),
#  (379, ('R632', 'R067', 'PENNSYLVANIA AV')),
#  (377, ('N532', 'R129', 'BERGEN ST')),
#  (377, ('N023', 'R332', '135 ST')),
#  (376, ('R289', 'R119', 'FORDHAM RD')),
#  (372, ('N075', 'R111', '23 ST')),
#  (367, ('N045', 'R187', '81 ST-MUSEUM')),
#  (366, ('R166', 'R167', '86 ST')),
#  (365, ('H032', 'R295', 'WILSON AV')),
#  (364, ('R408', 'R449', 'E 149 ST')),
#  (361, ('R303', 'R324', '116 ST')),
#  (360, ('A071', 'R044', 'CHAMBERS ST')),
#  (359, ('J028', 'R004', '75 ST-ELDERTS')),
#  (358, ('JFK02', 'R535', 'HOWARD BCH JFK')),
#  (357, ('N037', 'R314', '103 ST')),
#  (357, ('B014', 'R148', 'PARKSIDE AV')),
#  (356, ('R636', 'R209', 'STERLING ST')),
#  (356, ('E011', 'R371', '79 ST')),
#  (354, ('N224', 'R157', 'NORWOOD 205 ST')),
#  (348, ('N112A', 'R284', 'CLINTON-WASH AV')),
#  (346, ('R644', 'R135', 'NEWKIRK AV')),
#  (345, ('R179', 'R193', '157 ST')),
#  (345, ('C024', 'R214', '77 ST')),
#  (342, ('N087', 'R282', 'SPRING ST')),
#  (342, ('N009', 'R174', '181 ST')),
#  (341, ('N191', 'R335', 'BEACH 67 ST')),
#  (339, ('R302', 'R324', '116 ST')),
#  (339, ('N557', 'R130', 'KINGS HWY')),
#  (339, ('K026', 'R100', 'METROPOLITAN AV')),
#  (338, ('N220', 'R155', 'KINGSBRIDGE RD')),
#  (336, ('R645', 'R110', 'FLATBUSH AV-B.C')),
#  (334, ('E005', 'R247', '55 ST')),
#  (328, ('N034', 'R334', 'CATHEDRAL PKWY')),
#  (325, ('R727', 'R430', 'PELHAM PKWY')),
#  (323, ('R633', 'R068', 'VAN SICLEN AV')),
#  (322, ('B009', 'R411', 'PARK PLACE')),
#  (320, ('R328', 'R361', 'PELHAM PKWY')),
#  (320, ('K025', 'R404', 'FRESH POND RD')),
#  (317, ('R119', 'R320', 'CANAL ST')),
#  (316, ('H041', 'R152', 'CANARSIE-ROCKAW')),
#  (316, ('D003', 'R391', 'FT HAMILTON PKY')),
#  (315, ('R306', 'R207', '135 ST')),
#  (314, ('H038', 'R350', 'LIVONIA AV')),
#  (312, ('R227', 'R131', '23 ST')),
#  (312, ('B028', 'R136', 'SHEEPSHEAD BAY')),
#  (308, ('N556', 'R424', 'AVENUE P')),
#  (307, ('B032', 'R264', 'OCEAN PKWY')),
#  (305, ('N551', 'R421', 'AVENUE I')),
#  (305, ('N414A', 'R316', 'FLUSHING AV')),
#  (299, ('N006A', 'R280', '190 ST')),
#  (299, ('K019', 'R413', 'KNICKERBOCKER')),
#  (298, ('J035', 'R008', '111 ST')),
#  (295, ('N555', 'R423', 'AVENUE N')),
#  (295, ('K017', 'R401', 'CENTRAL AV')),
#  (294, ('R637', 'R451', 'WINTHROP ST')),
#  (294, ('N221', 'R155', 'KINGSBRIDGE RD')),
#  (294, ('N121B', 'R438', 'RALPH AV')),
#  (294, ('H022', 'R279', 'JEFFERSON ST')),
#  (293, ('J031', 'R006', 'WOODHAVEN BLVD')),
#  (291, ('C010', 'R231', 'UNION ST')),
#  (289, ('H037', 'R349', 'SUTTER AV')),
#  (288, ('N415', 'R286', 'MYRTLE-WILLOUGH')),
#  (288, ('N113', 'R297', 'FRANKLIN AV')),
#  (288, ('J005', 'R353', 'LORIMER ST')),
#  (288, ('B018', 'R184', 'CORTELYOU RD')),
#  (287, ('R404', 'R447', 'CYPRESS AV')),
#  (286, ('N561', 'R271', 'AVENUE X')),
#  (285, ('N209', 'R443', '170 ST')),
#  (285, ('J023', 'R436', 'NORWOOD AV')),
#  (284, ('R402', 'R446', 'BROOK AV')),
#  (284, ('N338B', 'R128', 'SUTPHIN BLVD')),
#  (284, ('N119', 'R199', 'KINGSTON-THROOP')),
#  (283, ('N325A', 'R218', 'ELMHURST AV')),
#  (281, ('R180', 'R193', '157 ST')),
#  (279, ('R618', 'R058', 'BERGEN ST')),
#  (277, ('R413', 'R325', 'WHITLOCK AV')),
#  (272, ('R307', 'R207', '135 ST')),
#  (272, ('C016', 'R278', '25 ST')),
#  (270, ('D012', 'R395', 'KINGS HWY')),
#  (270, ('B025', 'R150', 'AVENUE U')),
#  (266, ('R421', 'R427', 'MIDDLETOWN RD')),
#  (266, ('N125', 'R440', 'LIBERTY AV')),
#  (265, ('R407', 'R448', "E 143/ST MARY'S")),
#  (264, ('E016', 'R400', 'BAY 50 ST')),
#  (263, ('N007A', 'R174', '181 ST')),
#  (258, ('N195', 'R358', 'BEACH 25 ST')),
#  (257, ('N559', 'R425', 'AVENUE U')),
#  (257, ('N110', 'R283', 'LAFAYETTE AV')),
#  (257, ('H030', 'R266', 'HALSEY ST')),
#  (256, ('N311', 'R339', '36 ST')),
#  (255, ('J013', 'R380', 'GATES AV')),
#  (253, ('J022', 'R435', 'CLEVELAND ST')),
#  (250, ('B017', 'R262', 'BEVERLEY ROAD')),
#  (249, ('R639', 'R109', 'CHURCH AV')),
#  (247, ('J012', 'R379', 'KOSCIUSZKO ST')),
#  (246, ('N333', 'R141', 'FOREST HILLS 71')),
#  (245, ('N126', 'R441', 'VAN SICLEN AVE')),
#  (245, ('J021', 'R434', 'VAN SICLEN AV')),
#  (243, ('R294', 'R052', 'WOODLAWN')),
#  (239, ('N337', 'R255', 'BRIARWOOD')),
#  (238, ('N202', 'R315', '155 ST')),
#  (234, ('N215', 'R237', '182-183 STS')),
#  (233, ('J016', 'R381', 'HALSEY ST')),
#  (225, ('R410', 'R450', 'LONGWOOD AV')),
#  (220, ('A055', 'R227', 'RECTOR ST')),
#  (218, ('E012', 'R372', '18 AV')),
#  (216, ('R329', 'R362', 'ALLERTON AV')),
#  (216, ('R117', 'R343', 'FRANKLIN ST')),
#  (212, ('R617', 'R058', 'BERGEN ST')),
#  (212, ('R327', 'R361', 'PELHAM PKWY')),
#  (212, ('R326', 'R389', 'BRONX PARK EAST')),
#  (212, ('N316', 'R267', '46 ST')),
#  (208, ('N192', 'R336', 'BEACH 60 ST')),
#  (207, ('N548', 'R420', 'DITMAS AV')),
#  (203, ('N534', 'R220', 'CARROLL ST')),
#  (202, ('R422', 'R428', 'BUHRE AV')),
#  (200, ('R728', 'R226', 'GUN HILL RD')),
#  (200, ('N225', 'R157', 'NORWOOD 205 ST')),
#  (199, ('H013', 'R249', 'GRAHAM AV')),
#  (196, ('N212', 'R253', '174-175 STS')),
#  (194, ('N001', 'R173', 'INWOOD-207 ST')),
#  (193, ('R333', 'R366', '225 ST')),
#  (193, ('R121', 'R290', 'HOUSTON ST')),
#  (192, ('N134', 'R385', 'ROCKAWAY BLVD')),
#  (192, ('D015', 'R396', 'AVENUE U')),
#  (189, ('N017', 'R331', '155 ST')),
#  (188, ('E009', 'R370', '71 ST')),
#  (186, ('R260', 'R205', '149/GRAND CONC')),
#  (186, ('R122', 'R290', 'HOUSTON ST')),
#  (185, ('H035', 'R348', 'ATLANTIC AV')),
#  (182, ('N322', 'R340', '65 ST')),
#  (182, ('N012', 'R035', '168 ST')),
#  (181, ('R194', 'R040', '231 ST')),
#  (180, ('R312', 'R405', 'JACKSON AV')),
#  (180, ('N553', 'R422', 'BAY PKWY')),
#  (179, ('N127', 'R442', 'SHEPHERD AV')),
#  (177, ('N206', 'R104', '167 ST')),
#  (176, ('N002A', 'R173', 'INWOOD-207 ST')),
#  (175, ('H028', 'R266', 'HALSEY ST')),
#  (174, ('R190', 'R038', '215 ST')),
#  (174, ('N011', 'R126', '175 ST')),
#  (172, ('R315', 'R406', 'PROSPECT AV')),
#  (169, ('J030', 'R005', '85 ST-FOREST PK')),
#  (168, ('E013', 'R373', '20 AV')),
#  (167, ('N332', 'R219', '67 AV')),
#  (166, ('R192', 'R039', 'MARBLE HILL-225')),
#  (164, ('R334', 'R367', '233 ST')),
#  (156, ('J003', 'R352', 'HEWES ST')),
#  (155, ('K024', 'R403', 'FOREST AVE')),
#  (152, ('R335', 'R444', 'NEREID AV')),
#  (152, ('N210', 'R253', '174-175 STS')),
#  (152, ('C022', 'R212', '59 ST')),
#  (150, ('N208', 'R443', '170 ST')),
#  (148, ('N562', 'R426', 'NEPTUNE AV')),
#  (143, ('A082', 'R028', 'FULTON ST')),
#  (142, ('R726', 'R329', 'MORRIS PARK')),
#  (142, ('C004', 'R089', 'JAY ST-METROTEC')),
#  (139, ('N194', 'R338', 'BEACH 36 ST')),
#  (139, ('N187', 'R419', 'ROCKAWAY PARK B')),
#  (138, ('H012', 'R268', 'LORIMER ST')),
#  (136, ('J017', 'R432', 'CHAUNCEY ST')),
#  (135, ('JFK01', 'R535', 'HOWARD BCH JFK')),
#  (127, ('R646', 'R110', 'FLATBUSH AV-B.C')),
#  (124, ('N543', 'R289', 'FT HAMILTON PKY')),
#  (123, ('N185', 'R417', 'BEACH 98 ST')),
#  (122, ('R314', 'R406', 'PROSPECT AV')),
#  (118, ('H033', 'R313', 'BUSHWICK AV')),
#  (117, ('K022', 'R402', 'SENECA AVE')),
#  (115, ('R406', 'R448', "E 143/ST MARY'S")),
#  (114, ('R318', 'R408', 'SIMPSON ST')),
#  (112, ('R332', 'R365', '219 ST')),
#  (112, ('R317', 'R408', 'SIMPSON ST')),
#  (109, ('J025', 'R003', 'CYPRESS HILLS')),
#  (109, ('D016', 'R397', '86 ST')),
#  (106, ('R330', 'R363', 'BURKE AV')),
#  (106, ('N317', 'R267', '46 ST')),
#  (104, ('B026', 'R230', 'NECK RD')),
#  (103, ('N330C', 'R202', '63 DR-REGO PARK')),
#  (102, ('B034', 'R264', 'OCEAN PKWY')),
#  (97, ('N545', 'R204', 'CHURCH AV')),
#  (96, ('R641', 'R210', 'BEVERLY RD')),
#  (96, ('R520', 'R223', '46 ST BLISS ST')),
#  (96, ('N016A', 'R296', '163 ST-AMSTERDM')),
#  (95, ('N533', 'R129', 'BERGEN ST')),
#  (91, ('N193', 'R337', 'BEACH 44 ST')),
#  (89, ('N181', 'R357', 'AQUEDUCT N.COND')),
#  (89, ('N135', 'R385', 'ROCKAWAY BLVD')),
#  (87, ('E015', 'R399', '25 AV')),
#  (84, ('R322', 'R386', '174 ST')),
#  (73, ('N334B', 'R341', '75 AV')),
#  (71, ('R320', 'R409', 'FREEMAN ST')),
#  (68, ('N137', 'R354', '104 ST')),
#  (65, ('N418', 'R269', 'BEDFORD-NOSTRAN')),
#  (65, ('N131', 'R383', '80 ST')),
#  (64, ('R729', 'R292', 'BAYCHESTER AV')),
#  (62, ('N420B', 'R317', 'CLINTON-WASH AV')),
#  (62, ('N218', 'R112', 'FORDHAM RD')),
#  (52, ('C026', 'R215', '86 ST')),
#  (50, ('N558', 'R130', 'KINGS HWY')),
#  (50, ('N182', 'R414', 'HOWARD BCH JFK')),
#  (49, ('N184', 'R416', 'BEACH 90 ST')),
#  (48, ('N133', 'R384', '88 ST')),
#  (45, ('R308', 'R344', '145 ST')),
#  (45, ('J032', 'R006', 'WOODHAVEN BLVD')),
#  (44, ('R643', 'R135', 'NEWKIRK AV')),
#  (42, ('N339', 'R114', 'PARSONS BLVD')),
#  (40, ('N186', 'R418', 'BEACH 105 ST')),
#  (38, ('N547', 'R420', 'DITMAS AV')),
#  (38, ('N544', 'R289', 'FT HAMILTON PKY')),
#  (37, ('G015', 'R312', 'W 8 ST-AQUARIUM')),
#  (36, ('J037', 'R009', '121 ST')),
#  (36, ('D009', 'R393', '20 AV')),
#  (34, ('N181A', 'R464', 'AQUEDUCT RACETR')),
#  (34, ('D008', 'R392', '18 AV')),
#  (32, ('C028', 'R216', 'BAY RIDGE-95 ST')),
#  (28, ('N338', 'R128', 'SUTPHIN BLVD')),
#  (28, ('N130', 'R383', '80 ST')),
#  (27, ('N139', 'R355', '111 ST')),
#  (23, ('N416', 'R286', 'MYRTLE-WILLOUGH')),
#  (23, ('N329A', 'R201', 'WOODHAVEN BLVD')),
#  (22, ('N003', 'R185', 'DYCKMAN ST')),
#  (21, ('R506', 'R276', 'VERNON-JACKSON')),
#  (16, ('N183', 'R415', 'BROAD CHANNEL')),
#  (15, ('J034', 'R007', '104 ST')),
#  (12, ('N022', 'R332', '135 ST')),
#  (10, ('R196', 'R306', '238 ST')),
#  (8, ('TRAM2', 'R469', 'RIT-ROOSEVELT')),
#  (7, ('N123B', 'R439', 'ROCKAWAY AV')),
#  (6, ('R532H', 'R328', 'METS-WILLETS PT')),
#  (5, ('N223', 'R156', 'BEDFORD PK BLVD')),
#  (5, ('A084', 'R125', 'BROAD ST')),
#  (4, ('TRAM1', 'R468', 'RIT-MANHATTAN')),
#  (2, ('N138', 'R355', '111 ST')),
#  (0, ('S102', 'R165', 'TOMPKINSVILLE')),
#  (0, ('S101A', 'R070', 'ST. GEORGE')),
#  (0, ('S101', 'R070', 'ST. GEORGE')),
#  (0, ('OB01', 'R459', 'ORCHARD BEACH')),
#  (0, ('N554', 'R423', 'AVENUE N')),
#  (0, ('N550', 'R242', '18 AV')),
#  (0, ('A085', 'R125', 'BROAD ST')),
#  (-18, ('N029', 'R333', '116 ST')),
#  (-1189, ('R241A', 'R048', 'GRD CNTRL-42 ST'))]

# %% [markdown]
# 23.We notice that the ('R204', 'R043', 'WALL ST') stop is pretty high on the Monday morning list. How can we tell if this exit is more of a commuter or tourist exit? Maybe we'll see if the total number of people is higher on a weekday than a weekend. Go back to the original df dataframe. Save only the items that contain ('R204', 'R043', 'WALL ST') to a dataframe called wallstreet and create a list of tuples where the first entry is the date and the second entry is the total ridership. Sort in ascending order.
#
# Hint: there should be 9936 riders on 06/15/2017.

# %%
wallstreet = df[(df['C/A'] == 'R204') 
                & (df['UNIT'] == 'R043')
                & (df['STATION'] == 'WALL ST')]
wallstreet = wallstreet.reset_index(drop=True)

wall_dict={}

for i in range(len(wallstreet.index)):
    mytuple = wallstreet.DATE[i]
    if mytuple not in wall_dict.keys():
        wall_dict[mytuple]={wallstreet.SCP[i]:{wallstreet.TIME[i]:wallstreet.EXITS[i]}}
    if wallstreet.SCP[i] not in wall_dict[mytuple].keys():
         wall_dict[mytuple][wallstreet.SCP[i]]={wallstreet.TIME[i]:wallstreet.EXITS[i]}
    else:
        wall_dict[mytuple][wallstreet.SCP[i]][wallstreet.TIME[i]]=wallstreet.EXITS[i]
wall_dict['06/12/2017']

wall_exits = {}
for station,turnstiles in wall_dict.items():
    for turnstile,times in turnstiles.items():
        for i,exit in enumerate(times.values()):
            if i==0:
                begin = exit
            if i == len(times.values())-1:
                end = exit
        if station not in wall_exits.keys():
            wall_exits[station] = {turnstile:end-begin}
        else:
            wall_exits[station][turnstile]=end-begin
print(wall_exits['06/12/2017'])

tuple_list = []
for date, turnstiles in wall_exits.items():
    count = 0 
    for exit in turnstiles.values():
        count = count + exit
    tuple_list.append((date, count))
tuple_list.sort()
tuple_list
# Out:
# {'02-00-00': 1388, '02-00-01': 1180, '02-03-00': 2003, '02-03-01': 727, '02-03-02': 567, '02-03-03': 782, '02-05-00': 1043, '02-05-01': 372, '02-06-00': 1135, '02-06-01': 200}
# [('06/10/2017', 11),
#  ('06/11/2017', 1745),
#  ('06/12/2017', 9397),
#  ('06/13/2017', 9730),
#  ('06/14/2017', 9501),
#  ('06/15/2017', 9936),
#  ('06/16/2017', 8778)]

# %% [markdown]
# 24.Plot the list of tuples you made where date is the x-axis and ridership is the y-axis for this wall street station.
#
# Hint: you'll first need to use datetime to convert the dates to datetime format.

# %%
from datetime import datetime
x = [datetime.strptime(tuple_list[i][0],'%m/%d/%Y') for i in range(len(tuple_list))]
y = [tuple_list[i][1] for i in range(len(tuple_list))]
plt.plot(x,y,'.')

# %% [markdown]
# 25.Now use datetime to convert the dates to "Mon", "Tues", etc and print the days of the week with corresponding ridership. Is this a commuter stop or a tourist stop?

# %%
days = [date.strftime("%a") for date in x]
for i in range(len(days)):
    print(days[i], y[i])
# Out:
# Sat 11
# Sun 1745
# Mon 9397
# Tue 9730
# Wed 9501
# Thu 9936
# Fri 8778
