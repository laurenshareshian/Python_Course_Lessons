# %% [markdown]
# Selenium
# ---
# <a class="anchor" id="selenium"></a>
#
# Often, you're going to need to go to many different websites to scrape data. The package Selenium automates this process for you.
#
# First, we'll need to download it.
#
# On a Mac, try typing into your terminal:
#
# conda install -c conda-forge selenium
#
# Then type:
#
# which chromedriver
#
# If it works, great, if not (or if you have a PC), download it directly from
#
# http://chromedriver.storage.googleapis.com/index.html
#
# After you've downloaded it, type "which chromedriver" into your terminal to make sure it gives you a path. Everyone will have a slighty different path. Mine is "/usr/local/bin/chromedriver." Replace what mine is to what yours is in the code below.

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# type `which chromedriver` from shell to find chromedriver. Then change the next line!!!
chromedriver = "/usr/local/bin/chromedriver"
driver = webdriver.Chrome(chromedriver)
driver.get("https://images.google.com")

# %% [markdown]
# What happened? You should have gotten a browser window that popped up and went to the google images site. Whoa! What if we want to search for Kanye West pics? We'll need to type something into the search text box. Once again, to find how to reference the text box, we'll right click on it and go to Inspect. It seems to be referenced by id=lst-ib so let's tell Chromium to look for that:

# %%
search_box = driver.find_element_by_id("lst-ib")
print(search_box)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="f4ab5ac08cccb88e640bdfde0d488ca7", element="0.6447736553766905-1")>

# %% [markdown]
# Okay, it found it. Now let's tell Chromium to type "Kanye West" into the search box:

# %%
search_box.send_keys("Kanye West")

# %% [markdown]
# Did you see what just happened on your google webpage? Now, let's press enter to complete our search:

# %%
search_box.send_keys(Keys.RETURN)

# %% [markdown]
# What if we want to download the first image that comes up? Right click on it and press inspect to see that the the name is "hN6qb_8t9e0lcM:". Let's tell Selenium to search for this name:

# %%
search = driver.find_element_by_name('hN6qb_8t9e0lcM:')

# %% [markdown]
# Let's click on this pic:

# %%
search.click()

# %% [markdown]
# Now we are on a new page. If we wanted to know the url of the page we are currently on, we could type:

# %%
driver.current_url
# Out:
# 'https://www.google.com/search?tbm=isch&source=hp&biw=1200&bih=672&ei=tPimWoWRIMPk0gKEsIugCw&q=Kanye+West&oq=Kanye+West&gs_l=img.3..0l10.9153.9228.0.52295.10.2.0.0.0.0.82.138.2.2.0....0...1ac..64.img..8.2.136....0.5WPJdzhJvVg#imgrc=hN6qb_8t9e0lcM:'

# %% [markdown]
# Okay. This new image location is a little harder to find using id or class. Instead, we'll use XPath, which is typically the easiest way to search for something on a webpage. To do this, right click on the Kanye image, choose inspect, and see the blue text that got highlighted. Now, right click on the blue text and choose "Copy - XPath". It should look like this:
#
# <img src="xpath.jpg" style="width: 200px;"/>
#
# Now, we can paste what we just copied into this new search:

# %%
pic = search.find_element_by_xpath('//*[@id="irc_cc"]/div[2]/div[1]/div[2]/div[2]/a/img')
pic
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="f4ab5ac08cccb88e640bdfde0d488ca7", element="0.6236586095908558-2")>

# %% [markdown]
# We can use the .get_attribute method to access this hyperlink:

# %%
url = pic.get_attribute('src')
print(url)
# Out:
# https://upload.wikimedia.org/wikipedia/commons/thumb/1/11/Kanye_West_at_the_2009_Tribeca_Film_Festival.jpg/1200px-Kanye_West_at_the_2009_Tribeca_Film_Festival.jpg

# %% [markdown]
# How can we download this picture? We can use requests to communicate with this url and write its contents to a file called kanye.jpg:

# %%
import requests

response = requests.get(url)
with open('kanye.jpg', 'wb') as f:
        f.write(response.content)

# %% [markdown]
# ### Exercise - Selenium 1
#
# Use Selenium to go to "http://www.boxofficemojo.com/movies/?id=matrix.htm" http://www.boxofficemojo.com and use Selenium to print the Domestic Total Gross.

# %%
chromedriver = "/usr/local/bin/chromedriver"
driver = webdriver.Chrome(chromedriver)
matrix_url = "http://www.boxofficemojo.com/movies/?id=matrix.htm"
driver.get(matrix_url)
gross_selector = '//font[contains(text(), "Domestic")]/b'
print(driver.find_element_by_xpath(gross_selector).text)
# Out:
# $171,479,930

# %% [markdown]
# ### Exercise - Selenium 2
#
# Use Selenium to go to "http://www.boxofficemojo.com/movies/?id=matrix.htm" http://www.boxofficemojo.com and use Selenium to print the genres.
# Hint: driver.find_elements_by_xpath may contain more than one thing so you might need a loop.

# %%
chromedriver = "/usr/local/bin/chromedriver"
driver = webdriver.Chrome(chromedriver)
matrix_url = "http://www.boxofficemojo.com/movies/?id=matrix.htm"
driver.get(matrix_url)
genre_selector = '//a[contains(@href, "/genres/chart/")]/b'
for genre_anchor in driver.find_elements_by_xpath(genre_selector):
    print(genre_anchor.text)
# Out:
# Action - Wire-Fu
# Man vs. Machine
# Post-Apocalypse
# Virtual Reality

# %% [markdown]
# ### Exercise - Selenium 3
# Use Selenium and XPath to click on the tab that says "Similar Movies." Print the new url location.

# %%
chromedriver = "/usr/local/bin/chromedriver"
driver = webdriver.Chrome(chromedriver)
matrix_url = "http://www.boxofficemojo.com/movies/?id=matrix.htm"
driver.get(matrix_url)
similar_selector = '//*[@id="body"]/table[2]/tbody/tr/td/table[2]/tbody/tr[1]/td/ul/li[6]/a'
driver.find_element_by_xpath(similar_selector).click()
print(driver.current_url)
# Out:
# http://www.boxofficemojo.com/movies/?page=similar&id=matrix.htm

# %% [markdown]
# ### Exercise - Selenium 4
# Use pd.read_html to read in the table of similar movies that you are viewing on the similar movie page that you are now on.

# %%
import pandas as pd
tables = pd.read_html(driver.current_url)
tables[2]
# Out:
#                                                   0    \
# 0   The Matrix  Domestic Total Gross: $171,479,930...
# 1                                                 NaN
# 2   Domestic Total Gross: $171,479,930Distributor:...
# 3                  Domestic Total Gross: $171,479,930
# 4                           Distributor: Warner Bros.
# 5                                Genre: Sci-Fi Action
# 6                                      MPAA Rating: R
# 7                               Title (click to view)
# 8                                           Self/Less
# 9                                        Tomorrowland
# 10                                 Mad Max: Fury Road
# 11                    The Divergent Series: Insurgent
# 12                                  Jupiter Ascending
# 13              The Hunger Games: Mockingjay - Part 1
# 14                                          John Wick
# 15                                          The Giver
# 16                     Dawn of the Planet of the Apes
# 17                    Transformers: Age of Extinction
# 18                                   Edge of Tomorrow
# 19                Captain America: The Winter Soldier
# 20                                     3 Days to Kill
# 21                                     RoboCop (2014)
# 22                                           47 Ronin
# 23                    The Hunger Games: Catching Fire
# 24                                       Ender's Game
# 25                                            Elysium
# 26                                        Pacific Rim
# 27                                           Oblivion
# 28                                    The Host (2013)
# 29                                        Cloud Atlas
# ..                                                ...
# 43                         Clash of the Titans (2010)
# 44                                    The Book of Eli
# 45                                        Daybreakers
# 46                                           The Road
# 47                Transformers: Revenge of the Fallen
# 48                               Terminator Salvation
# 49                                           Watchmen
# 50               The Day the Earth Stood Still (2008)
# 51                                    The Dark Knight
# 52                                             Wanted
# 53                                        I Am Legend
# 54                                       Transformers
# 55           Pirates of the Caribbean: At World's End
# 56                                     V for Vendetta
# 57                                        Ultraviolet
# 58                                          Aeon Flux
# 59                                         The Island
# 60                                      Batman Begins
# 61       Star Wars: Episode III - Revenge of the Sith
# 62                                        Constantine
# 63                                           I, Robot
# 64                             The Matrix Revolutions
# 65                 Terminator 3: Rise of the Machines
# 66                                The Matrix Reloaded
# 67                                      Reign of Fire
# 68                      Universal Soldier: The Return
# 69                                  Universal Soldier
# 70                         Terminator 2: Judgment Day
# 71                                     The Terminator
# 72                                          Averages:
#
#                                                   1    \
# 0                                                 NaN
# 1   The Matrix  Domestic Total Gross: $171,479,930...
# 2                  Domestic Total Gross: $171,479,930
# 3                                                 NaN
# 4                        Release Date: March 31, 1999
# 5                             Runtime: 2 hrs. 16 min.
# 6                      Production Budget: $63 million
# 7                                              Studio
# 8                                               Focus
# 9                                                  BV
# 10                                                 WB
# 11                                               LG/S
# 12                                                 WB
# 13                                                LGF
# 14                                               LG/S
# 15                                              Wein.
# 16                                                Fox
# 17                                               Par.
# 18                                                 WB
# 19                                                 BV
# 20                                              Rela.
# 21                                               Sony
# 22                                               Uni.
# 23                                                LGF
# 24                                               LG/S
# 25                                               TriS
# 26                                                 WB
# 27                                               Uni.
# 28                                                ORF
# 29                                                 WB
# ..                                                ...
# 43                                                 WB
# 44                                                 WB
# 45                                                LGF
# 46                                             W/Dim.
# 47                                               P/DW
# 48                                                 WB
# 49                                                 WB
# 50                                                Fox
# 51                                                 WB
# 52                                               Uni.
# 53                                                 WB
# 54                                               P/DW
# 55                                                 BV
# 56                                                 WB
# 57                                               SGem
# 58                                               Par.
# 59                                                 DW
# 60                                                 WB
# 61                                                Fox
# 62                                                 WB
# 63                                                Fox
# 64                                                 WB
# 65                                                 WB
# 66                                                 WB
# 67                                                 BV
# 68                                               Sony
# 69                                               TriS
# 70                                               TriS
# 71                                              Orion
# 72                                       $146,573,152
#
#                                                   2    \
# 0   The Matrix  Domestic Total Gross: $171,479,930...
# 1   Domestic Total Gross: $171,479,930Distributor:...
# 2                           Distributor: Warner Bros.
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                           Release Gross* / Theaters
# 8                                         $12,279,691
# 9                                         $93,436,322
# 10                                       $153,636,354
# 11                                       $130,179,072
# 12                                        $47,387,723
# 13                                       $337,135,885
# 14                                        $43,037,835
# 15                                        $45,090,374
# 16                                       $208,545,589
# 17                                       $245,439,076
# 18                                       $100,206,256
# 19                                       $259,766,572
# 20                                        $30,697,999
# 21                                        $58,607,007
# 22                                        $38,362,475
# 23                                       $424,668,047
# 24                                        $61,737,191
# 25                                        $93,050,117
# 26                                       $101,802,906
# 27                                        $89,107,235
# 28                                        $26,627,201
# 29                                        $27,108,272
# ..                                                ...
# 43                                       $163,214,888
# 44                                        $94,835,059
# 45                                        $30,101,577
# 46                                         $8,117,000
# 47                                       $402,111,870
# 48                                       $125,322,469
# 49                                       $107,509,799
# 50                                        $79,366,978
# 51                                       $533,345,358
# 52                                       $134,508,551
# 53                                       $256,393,010
# 54                                       $319,246,193
# 55                                       $309,420,425
# 56                                        $70,511,035
# 57                                        $18,535,812
# 58                                        $25,874,337
# 59                                        $35,818,913
# 60                                       $205,343,774
# 61                                       $380,270,577
# 62                                        $75,976,178
# 63                                       $144,801,023
# 64                                       $139,313,948
# 65                                       $150,371,112
# 66                                       $281,576,461
# 67                                        $43,061,982
# 68                                        $10,667,893
# 69                                        $36,299,898
# 70                                       $204,843,345
# 71                                        $38,371,200
# 72                                               3319
#
#                                                   3    \
# 0   Domestic Total Gross: $171,479,930Distributor:...
# 1                  Domestic Total Gross: $171,479,930
# 2                        Release Date: March 31, 1999
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                  Opening / Theaters
# 8                                                2353
# 9                                                3972
# 10                                               3722
# 11                                               3875
# 12                                               3181
# 13                                               4151
# 14                                               2589
# 15                                               3003
# 16                                               3969
# 17                                               4233
# 18                                               3505
# 19                                               3938
# 20                                               2872
# 21                                               3372
# 22                                               2690
# 23                                               4163
# 24                                               3407
# 25                                               3284
# 26                                               3285
# 27                                               3792
# 28                                               3202
# 29                                               2023
# ..                                                ...
# 43                                               3802
# 44                                               3111
# 45                                               2523
# 46                                                396
# 47                                               4293
# 48                                               3602
# 49                                               3611
# 50                                               3560
# 51                                               4366
# 52                                               3185
# 53                                               3648
# 54                                               4050
# 55                                               4362
# 56                                               3365
# 57                                               2558
# 58                                               2608
# 59                                               3138
# 60                                               3858
# 61                                               3663
# 62                                               3006
# 63                                               3494
# 64                                               3502
# 65                                               3504
# 66                                               3603
# 67                                               2629
# 68                                               1639
# 69                                               1925
# 70                                               2495
# 71                                               1112
# 72                                        $48,255,848
#
#                                    4                             5    \
# 0   Domestic Total Gross: $171,479,930     Distributor: Warner Bros.
# 1            Distributor: Warner Bros.  Release Date: March 31, 1999
# 2                 Genre: Sci-Fi Action       Runtime: 2 hrs. 16 min.
# 3                                  NaN                           NaN
# 4                                  NaN                           NaN
# 5                                  NaN                           NaN
# 6                                  NaN                           NaN
# 7                                Date^                           NaN
# 8                           $5,403,460                          2353
# 9                          $33,028,165                          3972
# 10                         $45,428,128                          3702
# 11                         $52,263,680                          3875
# 12                         $18,372,372                          3181
# 13                        $121,897,634                          4151
# 14                         $14,415,922                          2589
# 15                         $12,305,016                          3003
# 16                         $72,611,427                          3967
# 17                        $100,038,390                          4233
# 18                         $28,760,246                          3490
# 19                         $95,023,721                          3938
# 20                         $12,242,218                          2872
# 21                         $21,681,430                          3372
# 22                          $9,910,310                          2689
# 23                        $158,074,286                          4163
# 24                         $27,017,351                          3407
# 25                         $29,807,393                          3284
# 26                         $37,285,325                          3275
# 27                         $37,054,485                          3783
# 28                         $10,600,112                          3202
# 29                          $9,612,247                          2008
# ..                                 ...                           ...
# 43                         $61,235,105                          3777
# 44                         $32,789,494                          3111
# 45                         $15,146,692                          2523
# 46                          $1,502,231                           111
# 47                        $108,966,307                          4234
# 48                         $42,558,390                          3530
# 49                         $55,214,334                          3611
# 50                         $30,480,153                          3560
# 51                        $158,411,483                          4366
# 52                         $50,927,085                          3175
# 53                         $77,211,321                          3606
# 54                         $70,502,384                          4011
# 55                        $114,732,820                          4362
# 56                         $25,642,340                          3365
# 57                          $9,064,880                          2558
# 58                         $12,661,112                          2608
# 59                         $12,409,070                          3122
# 60                         $48,745,440                          3858
# 61                        $108,435,841                          3661
# 62                         $29,769,098                          3006
# 63                         $52,179,887                          3420
# 64                         $48,475,154                          3502
# 65                         $44,041,440                          3504
# 66                         $91,774,413                          3603
# 67                         $15,632,281                          2629
# 68                          $4,605,167                          1639
# 69                         $10,057,084                          1916
# 70                         $31,765,506                          2274
# 71                          $4,020,663                          1005
# 72                                3301                           NaN
#
#                              6                               7    \
# 0   Release Date: March 31, 1999            Genre: Sci-Fi Action
# 1           Genre: Sci-Fi Action         Runtime: 2 hrs. 16 min.
# 2                 MPAA Rating: R  Production Budget: $63 million
# 3                            NaN                             NaN
# 4                            NaN                             NaN
# 5                            NaN                             NaN
# 6                            NaN                             NaN
# 7                            NaN                             NaN
# 8                        7/10/15                             NaN
# 9                        5/22/15                             NaN
# 10                       5/15/15                             NaN
# 11                       3/20/15                             NaN
# 12                        2/6/15                             NaN
# 13                      11/21/14                             NaN
# 14                      10/24/14                             NaN
# 15                       8/15/14                             NaN
# 16                       7/11/14                             NaN
# 17                       6/27/14                             NaN
# 18                        6/6/14                             NaN
# 19                        4/4/14                             NaN
# 20                       2/21/14                             NaN
# 21                       2/12/14                             NaN
# 22                      12/25/13                             NaN
# 23                      11/22/13                             NaN
# 24                       11/1/13                             NaN
# 25                        8/9/13                             NaN
# 26                       7/12/13                             NaN
# 27                       4/19/13                             NaN
# 28                       3/29/13                             NaN
# 29                      10/26/12                             NaN
# ..                           ...                             ...
# 43                        4/2/10                             NaN
# 44                       1/15/10                             NaN
# 45                        1/8/10                             NaN
# 46                      11/25/09                             NaN
# 47                       6/24/09                             NaN
# 48                       5/21/09                             NaN
# 49                        3/6/09                             NaN
# 50                      12/12/08                             NaN
# 51                       7/18/08                             NaN
# 52                       6/27/08                             NaN
# 53                      12/14/07                             NaN
# 54                        7/3/07                             NaN
# 55                       5/25/07                             NaN
# 56                       3/17/06                             NaN
# 57                        3/3/06                             NaN
# 58                       12/2/05                             NaN
# 59                       7/22/05                             NaN
# 60                       6/15/05                             NaN
# 61                       5/19/05                             NaN
# 62                       2/18/05                             NaN
# 63                       7/16/04                             NaN
# 64                       11/5/03                             NaN
# 65                        7/2/03                             NaN
# 66                       5/15/03                             NaN
# 67                       7/12/02                             NaN
# 68                       8/20/99                             NaN
# 69                       7/10/92                             NaN
# 70                        7/3/91                             NaN
# 71                      10/26/84                             NaN
# 72                           NaN                             NaN
#
#                         8                               9   ...     461  \
# 0   Runtime: 2 hrs. 16 min.                  MPAA Rating: R ...  1112.0
# 1            MPAA Rating: R  Production Budget: $63 million ...     NaN
# 2                       NaN                             NaN ...     NaN
# 3                       NaN                             NaN ...     NaN
# 4                       NaN                             NaN ...     NaN
# 5                       NaN                             NaN ...     NaN
# 6                       NaN                             NaN ...     NaN
# 7                       NaN                             NaN ...     NaN
# 8                       NaN                             NaN ...     NaN
# 9                       NaN                             NaN ...     NaN
# 10                      NaN                             NaN ...     NaN
# 11                      NaN                             NaN ...     NaN
# 12                      NaN                             NaN ...     NaN
# 13                      NaN                             NaN ...     NaN
# 14                      NaN                             NaN ...     NaN
# 15                      NaN                             NaN ...     NaN
# 16                      NaN                             NaN ...     NaN
# 17                      NaN                             NaN ...     NaN
# 18                      NaN                             NaN ...     NaN
# 19                      NaN                             NaN ...     NaN
# 20                      NaN                             NaN ...     NaN
# 21                      NaN                             NaN ...     NaN
# 22                      NaN                             NaN ...     NaN
# 23                      NaN                             NaN ...     NaN
# 24                      NaN                             NaN ...     NaN
# 25                      NaN                             NaN ...     NaN
# 26                      NaN                             NaN ...     NaN
# 27                      NaN                             NaN ...     NaN
# 28                      NaN                             NaN ...     NaN
# 29                      NaN                             NaN ...     NaN
# ..                      ...                             ... ...     ...
# 43                      NaN                             NaN ...     NaN
# 44                      NaN                             NaN ...     NaN
# 45                      NaN                             NaN ...     NaN
# 46                      NaN                             NaN ...     NaN
# 47                      NaN                             NaN ...     NaN
# 48                      NaN                             NaN ...     NaN
# 49                      NaN                             NaN ...     NaN
# 50                      NaN                             NaN ...     NaN
# 51                      NaN                             NaN ...     NaN
# 52                      NaN                             NaN ...     NaN
# 53                      NaN                             NaN ...     NaN
# 54                      NaN                             NaN ...     NaN
# 55                      NaN                             NaN ...     NaN
# 56                      NaN                             NaN ...     NaN
# 57                      NaN                             NaN ...     NaN
# 58                      NaN                             NaN ...     NaN
# 59                      NaN                             NaN ...     NaN
# 60                      NaN                             NaN ...     NaN
# 61                      NaN                             NaN ...     NaN
# 62                      NaN                             NaN ...     NaN
# 63                      NaN                             NaN ...     NaN
# 64                      NaN                             NaN ...     NaN
# 65                      NaN                             NaN ...     NaN
# 66                      NaN                             NaN ...     NaN
# 67                      NaN                             NaN ...     NaN
# 68                      NaN                             NaN ...     NaN
# 69                      NaN                             NaN ...     NaN
# 70                      NaN                             NaN ...     NaN
# 71                      NaN                             NaN ...     NaN
# 72                      NaN                             NaN ...     NaN
#
#            462     463       464        465           466     467  \
# 0   $4,020,663  1005.0  10/26/84  Averages:  $146,573,152  3319.0
# 1          NaN     NaN       NaN        NaN           NaN     NaN
# 2          NaN     NaN       NaN        NaN           NaN     NaN
# 3          NaN     NaN       NaN        NaN           NaN     NaN
# 4          NaN     NaN       NaN        NaN           NaN     NaN
# 5          NaN     NaN       NaN        NaN           NaN     NaN
# 6          NaN     NaN       NaN        NaN           NaN     NaN
# 7          NaN     NaN       NaN        NaN           NaN     NaN
# 8          NaN     NaN       NaN        NaN           NaN     NaN
# 9          NaN     NaN       NaN        NaN           NaN     NaN
# 10         NaN     NaN       NaN        NaN           NaN     NaN
# 11         NaN     NaN       NaN        NaN           NaN     NaN
# 12         NaN     NaN       NaN        NaN           NaN     NaN
# 13         NaN     NaN       NaN        NaN           NaN     NaN
# 14         NaN     NaN       NaN        NaN           NaN     NaN
# 15         NaN     NaN       NaN        NaN           NaN     NaN
# 16         NaN     NaN       NaN        NaN           NaN     NaN
# 17         NaN     NaN       NaN        NaN           NaN     NaN
# 18         NaN     NaN       NaN        NaN           NaN     NaN
# 19         NaN     NaN       NaN        NaN           NaN     NaN
# 20         NaN     NaN       NaN        NaN           NaN     NaN
# 21         NaN     NaN       NaN        NaN           NaN     NaN
# 22         NaN     NaN       NaN        NaN           NaN     NaN
# 23         NaN     NaN       NaN        NaN           NaN     NaN
# 24         NaN     NaN       NaN        NaN           NaN     NaN
# 25         NaN     NaN       NaN        NaN           NaN     NaN
# 26         NaN     NaN       NaN        NaN           NaN     NaN
# 27         NaN     NaN       NaN        NaN           NaN     NaN
# 28         NaN     NaN       NaN        NaN           NaN     NaN
# 29         NaN     NaN       NaN        NaN           NaN     NaN
# ..         ...     ...       ...        ...           ...     ...
# 43         NaN     NaN       NaN        NaN           NaN     NaN
# 44         NaN     NaN       NaN        NaN           NaN     NaN
# 45         NaN     NaN       NaN        NaN           NaN     NaN
# 46         NaN     NaN       NaN        NaN           NaN     NaN
# 47         NaN     NaN       NaN        NaN           NaN     NaN
# 48         NaN     NaN       NaN        NaN           NaN     NaN
# 49         NaN     NaN       NaN        NaN           NaN     NaN
# 50         NaN     NaN       NaN        NaN           NaN     NaN
# 51         NaN     NaN       NaN        NaN           NaN     NaN
# 52         NaN     NaN       NaN        NaN           NaN     NaN
# 53         NaN     NaN       NaN        NaN           NaN     NaN
# 54         NaN     NaN       NaN        NaN           NaN     NaN
# 55         NaN     NaN       NaN        NaN           NaN     NaN
# 56         NaN     NaN       NaN        NaN           NaN     NaN
# 57         NaN     NaN       NaN        NaN           NaN     NaN
# 58         NaN     NaN       NaN        NaN           NaN     NaN
# 59         NaN     NaN       NaN        NaN           NaN     NaN
# 60         NaN     NaN       NaN        NaN           NaN     NaN
# 61         NaN     NaN       NaN        NaN           NaN     NaN
# 62         NaN     NaN       NaN        NaN           NaN     NaN
# 63         NaN     NaN       NaN        NaN           NaN     NaN
# 64         NaN     NaN       NaN        NaN           NaN     NaN
# 65         NaN     NaN       NaN        NaN           NaN     NaN
# 66         NaN     NaN       NaN        NaN           NaN     NaN
# 67         NaN     NaN       NaN        NaN           NaN     NaN
# 68         NaN     NaN       NaN        NaN           NaN     NaN
# 69         NaN     NaN       NaN        NaN           NaN     NaN
# 70         NaN     NaN       NaN        NaN           NaN     NaN
# 71         NaN     NaN       NaN        NaN           NaN     NaN
# 72         NaN     NaN       NaN        NaN           NaN     NaN
#
#             468     469 470
# 0   $48,255,848  3301.0 NaN
# 1           NaN     NaN NaN
# 2           NaN     NaN NaN
# 3           NaN     NaN NaN
# 4           NaN     NaN NaN
# 5           NaN     NaN NaN
# 6           NaN     NaN NaN
# 7           NaN     NaN NaN
# 8           NaN     NaN NaN
# 9           NaN     NaN NaN
# 10          NaN     NaN NaN
# 11          NaN     NaN NaN
# 12          NaN     NaN NaN
# 13          NaN     NaN NaN
# 14          NaN     NaN NaN
# 15          NaN     NaN NaN
# 16          NaN     NaN NaN
# 17          NaN     NaN NaN
# 18          NaN     NaN NaN
# 19          NaN     NaN NaN
# 20          NaN     NaN NaN
# 21          NaN     NaN NaN
# 22          NaN     NaN NaN
# 23          NaN     NaN NaN
# 24          NaN     NaN NaN
# 25          NaN     NaN NaN
# 26          NaN     NaN NaN
# 27          NaN     NaN NaN
# 28          NaN     NaN NaN
# 29          NaN     NaN NaN
# ..          ...     ...  ..
# 43          NaN     NaN NaN
# 44          NaN     NaN NaN
# 45          NaN     NaN NaN
# 46          NaN     NaN NaN
# 47          NaN     NaN NaN
# 48          NaN     NaN NaN
# 49          NaN     NaN NaN
# 50          NaN     NaN NaN
# 51          NaN     NaN NaN
# 52          NaN     NaN NaN
# 53          NaN     NaN NaN
# 54          NaN     NaN NaN
# 55          NaN     NaN NaN
# 56          NaN     NaN NaN
# 57          NaN     NaN NaN
# 58          NaN     NaN NaN
# 59          NaN     NaN NaN
# 60          NaN     NaN NaN
# 61          NaN     NaN NaN
# 62          NaN     NaN NaN
# 63          NaN     NaN NaN
# 64          NaN     NaN NaN
# 65          NaN     NaN NaN
# 66          NaN     NaN NaN
# 67          NaN     NaN NaN
# 68          NaN     NaN NaN
# 69          NaN     NaN NaN
# 70          NaN     NaN NaN
# 71          NaN     NaN NaN
# 72          NaN     NaN NaN
#
# [73 rows x 471 columns]

# %% [markdown]
# ### Exercise - Selenium 5
#
# Use Selenium to go to http://www.imdb.com/ and to type into the search box Kanye West. You won't quite be there yet because two names are listed. Use Selenium again to click on Kanye West.

# %%
chromedriver = "/usr/local/bin/chromedriver"
driver = webdriver.Chrome(chromedriver)

url = "http://www.imdb.com"
driver.get(url)

query = driver.find_element_by_id("navbar-query")
query.send_keys("Kanye West")
query.send_keys(Keys.RETURN)
name_selector = '//*[@id="main"]/div/div[2]/table/tbody/tr[1]/td[2]/a'
driver.find_element_by_xpath(name_selector).click()
