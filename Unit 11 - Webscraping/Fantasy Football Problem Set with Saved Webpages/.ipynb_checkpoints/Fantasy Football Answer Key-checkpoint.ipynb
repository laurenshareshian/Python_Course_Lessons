# %% [markdown]
# In this lesson, you will investigate how well ESPN does at predicting NFL fantasy football player performance. First, import these modules.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 1.) We are interested in how well ESPN does at predicting how well a player will do in fantasy football.
#
# The ESPN website from 2017 listed how many fantasy points each player had ACTUALLY scored by the end of the season. The website used to be here:
#
# http://games.espn.com/ffl/leaders
#
# and every tab had the pattern http://games.espn.com/ffl/leaders?startIndex=0, http://games.espn.com/ffl/leaders?startIndex=50, ..., http://games.espn.com/ffl/leaders?startIndex=850 , where each page contained 50 more players' info.
#
# We have saved these webpages locally, and they are called "fftrankings0.htm", "fftrankings50.htm", ..., "fftrankings850.htm".
#
# Create a list called "urls" containing each of the these fftrankings file names.

# %%
urls = []
for i in range(0,900,50):
    urls.append('fftrankings'+str(i)+'.htm')

# %% [markdown]
# 2.We can go to the first url and use pd.read_html to read in the info. "pd.read_html" is an awesome command when it works! It reads tables directly off of websites and saves them to a pandas dataframe. We'll save the dataframe with the name "df". Notice, those, that for some reason reading from the file creates a lot of duplicates. The page is a big buggy when it is saved locally, therefore, once you are done reading in the file, delete all of the duplicates. Google "pandas remove duplicates" to see how to do this in one line.

# %%
import pandas as pd
tables = pd.read_html(urls[0])
df = tables[0]
df.drop_duplicates(subset=None, keep='first', inplace=True)

# %% [markdown]
# 3.There are many columns. Let's only save the player name and points columns. Let's also drop the first three rows which are headers and not player names. "player" and "2017 points."

# %%
df = df[df.columns[[0,20]]]
df = df.rename(columns={0: 'player', 20: '2017 points'})
df.drop(df.index[0:3], inplace = True)

# %% [markdown]
# 4.Okay. Now we are going to loop through and add the dataframes you get from visiting the other urls to the bottom of the dataframe you got from the first url. You can do this by using the following command within the for loop:
#
# table = pd.concat([table, new_table])
#
# Be sure to drop the first three rows from the new table that you read in each time before you add them to the old table (since they don't contain player names). Also, remove the duplicates. Then, only save the player name and points columns and rename those columns "player" and "2017 points." Finally, concatenate the old table with the new each time. Your final dataframe should have 1008 rows.

# %%
for i in range(1,len(urls)):
    df2 = pd.read_html(urls[i])[0]
    df2.drop_duplicates(subset=None, keep='first', inplace=True)
    df2 = df2[df2.columns[[0,20]]]
    df2 = df2.rename(columns={0: 'player', 20: '2017 points'})
    df2.drop(df2.index[0:3], inplace = True)
    df = pd.concat([df, df2])
df.head()
# Out:
#                    player 2017 points
# 3  Todd Gurley II, LAR RB       383.3
# 4  Russell Wilson, Sea QB       347.9
# 5    Le'Veon Bell, Pit RB       341.6
# 6     Alvin Kamara, NO RB       320.4
# 7   Antonio Brown, Pit WR       310.3

# %% [markdown]
# 5.Drop rows that are missing ANY entries. Then, reset the index. Your final dataframe should have 890 rows.

# %%
df = df.dropna(how = 'any')
df = df.reset_index(drop=True)
df.head()
# Out:
#                    player 2017 points
# 0  Todd Gurley II, LAR RB       383.3
# 1  Russell Wilson, Sea QB       347.9
# 2    Le'Veon Bell, Pit RB       341.6
# 3     Alvin Kamara, NO RB       320.4
# 4   Antonio Brown, Pit WR       310.3

# %% [markdown]
# 6.Notice that the player names contain the name, team, and position. We will want to break this up. First, create a list called playernames that just contains the player names and teams (we need the team, too, because there are common names like David Johnson that play on two different teams).

# %%
playernames = []
for i, player in enumerate(df['player'].values):
    playername = player.split(',')[0]+', '+player.split(',')[1:][0].split()[0].upper()
    playernames.append(playername)
    print(i, playername)
# Out:
# 0 Todd Gurley II, LAR
# 1 Russell Wilson, SEA
# 2 Le'Veon Bell, PIT
# 3 Alvin Kamara, NO
# 4 Antonio Brown, PIT
# 5 DeAndre Hopkins, HOU
# 6 Cam Newton, CAR
# 7 Tom Brady, NE
# 8 Kareem Hunt, KC
# 9 Alex Smith, WSH
# 10 Melvin Gordon, LAC
# 11 Keenan Allen, LAC
# 12 Carson Wentz, PHI
# 13 Mark Ingram, NO
# 14 Kirk Cousins, MIN
# 15 Matthew Stafford, DET
# 16 Philip Rivers, LAC
# 17 LeSean McCoy, BUF
# 18 Drew Brees, NO
# 19 Larry Fitzgerald, ARI
# 20 Ben Roethlisberger, PIT
# 21 Dak Prescott, DAL
# 22 Jarvis Landry, CLE
# 23 Michael Thomas, NO
# 24 Jared Goff, LAR
# 25 Julio Jones, ATL
# 26 Blake Bortles, JAX
# 27 Tyreek Hill, KC
# 28 Adam Thielen, MIN
# 29 Case Keenum, DEN
# 30 Carlos Hyde, CLE
# 31 Travis Kelce, KC
# 32 Leonard Fournette, JAX
# 33 Christian McCaffrey, CAR
# 34 Matt Ryan, ATL
# 35 Rob Gronkowski, NE
# 36 A.J. Green, CIN
# 37 Marvin Jones Jr., DET
# 38 Golden Tate, DET
# 39 Doug Baldwin, SEA
# 40 Tyrod Taylor, CLE
# 41 Davante Adams, GB
# 42 Brandin Cooks, LAR
# 43 Duke Johnson Jr., CLE
# 44 Andy Dalton, CIN
# 45 Marcus Mariota, TEN
# 46 Derek Carr, OAK
# 47 Jacoby Brissett, IND
# 48 Demaryius Thomas, DEN
# 49 Josh McCown, NYJ
# 50 Ezekiel Elliott, DAL
# 51 Mike Evans, TB
# 52 Dion Lewis, TEN
# 53 Zach Ertz, PHI
# 54 Jameis Winston, TB
# 55 Devonta Freeman, ATL
# 56 Robby Anderson, NYJ
# 57 Jordan Howard, CHI
# 58 Stefon Diggs, MIN
# 59 JuJu Smith-Schuster, PIT
# 60 Alshon Jeffery, PHI
# 61 Devin Funchess, CAR
# 62 Lamar Miller, HOU
# 63 Nelson Agholor, PHI
# 64 Eli Manning, NYG
# 65 Dez Bryant, FA
# 66 Joe Flacco, BAL
# 67 Jerick McKinnon, SF
# 68 Cooper Kupp, LAR
# 69 Jermaine Kearse, NYJ
# 70 DeShone Kizer, GB
# 71 T.Y. Hilton, IND
# 72 C.J. Anderson, CAR
# 73 Kenny Stills, MIA
# 74 Delanie Walker, TEN
# 75 Mohamed Sanu, ATL
# 76 Frank Gore, MIA
# 77 Evan Engram, NYG
# 78 Michael Crabtree, BAL
# 79 DeMarco Murray, FA
# 80 Jimmy Graham, GB
# 81 Alex Collins, BAL
# 82 Jack Doyle, IND
# 83 Deshaun Watson, HOU
# 84 Marquise Goodwin, SF
# 85 Tevin Coleman, ATL
# 86 Javorius Allen, BAL
# 87 Marshawn Lynch, OAK
# 88 Robert Woods, LAR
# 89 Jamison Crowder, WSH
# 90 Ted Ginn Jr., NO
# 91 Randall Cobb, GB
# 92 Amari Cooper, OAK
# 93 Kyle Rudolph, MIN
# 94 Jay Cutler, FA
# 95 Latavius Murray, MIN
# 96 Rishard Matthews, TEN
# 97 Theo Riddick, DET
# 98 Giovani Bernard, CIN
# 99 Chris Thompson, WSH
# 100 Mike Wallace, PHI
# 101 Paul Richardson, WSH
# 102 Tarik Cohen, CHI
# 103 Marqise Lee, JAX
# 104 Jason Witten, DAL
# 105 Sammy Watkins, KC
# 106 Bilal Powell, NYJ
# 107 Sterling Shepard, NYG
# 108 Isaiah Crowell, NYJ
# 109 Cameron Brate, TB
# 110 Jamaal Williams, GB
# 111 Kenyan Drake, MIA
# 112 Joe Mixon, CIN
# 113 Danny Amendola, MIA
# 114 DeSean Jackson, TB
# 115 Tyrell Williams, LAC
# 116 Orleans Darkwa, NYG
# 117 Benjamin Watson, NO
# 118 Jordy Nelson, OAK
# 119 Kelvin Benjamin, BUF
# 120 Jay Ajayi, PHI
# 121 Derrick Henry, TEN
# 122 Mitchell Trubisky, CHI
# 123 James White, NE
# 124 Jared Cook, OAK
# 125 Keelan Cole, JAX
# 126 Martavis Bryant, OAK
# 127 Eric Ebron, IND
# 128 Travis Benjamin, LAC
# 129 DeVante Parker, MIA
# 130 Rex Burkhead, NE
# 131 Aaron Rodgers, GB
# 132 Adam Humphries, TB
# 133 Hunter Henry*, LAC
# 134 Kendall Wright, MIN
# 135 Ryan Grant, IND
# 136 Trevor Siemian, MIN
# 137 Brandon LaFell, CIN
# 138 Brett Hundley, GB
# 139 Ameer Abdullah, DET
# 140 Tyler Kroft, CIN
# 141 Tyler Lockett, SEA
# 142 Vernon Davis, WSH
# 143 Matt Forte, NYJ
# 144 Josh Doctson, WSH
# 145 Austin Hooper, ATL
# 146 Jonathan Stewart, NYG
# 147 Charles Clay, BUF
# 148 Eric Decker, FA
# 149 Albert Wilson, MIA
# 150 Emmanuel Sanders, DEN
# 151 Will Fuller V, HOU
# 152 Terrance Williams, DAL
# 153 Chris Hogan, NE
# 154 Samaje Perine, WSH
# 155 LeGarrette Blount, DET
# 156 Austin Ekeler, LAC
# 157 George Kittle, SF
# 158 Deonte Thompson, DAL
# 159 Wayne Gallman, NYG
# 160 Matt Breida, SF
# 161 Marlon Mack, IND
# 162 Jaron Brown, SEA
# 163 Carson Palmer, ARI
# 164 Jeremy Maclin, FA
# 165 Austin Seferian-Jenkins, JAX
# 166 O.J. Howard, TB
# 167 Allen Hurns, DAL
# 168 Jesse James, PIT
# 169 Julius Thomas, MIA
# 170 J.D. McKissic, SEA
# 171 Trent Taylor, SF
# 172 David Njoku, CLE
# 173 Kenny Golladay, DET
# 174 J.J. Nelson, ARI
# 175 Chris Godwin, TB
# 176 Rod Smith, DAL
# 177 Corey Clement, PHI
# 178 Ty Montgomery, GB
# 179 Cole Beasley, DAL
# 180 Devontae Booker, DEN
# 181 Torrey Smith, CAR
# 182 Seth Roberts, OAK
# 183 Pierre Garcon, SF
# 184 Roger Lewis, NYG
# 185 C.J. Beathard, SF
# 186 Jimmy Garoppolo, SF
# 187 Marcedes Lewis, GB
# 188 T.J. Yeldon, JAX
# 189 Andre Ellington, HOU
# 190 Jalen Richard, OAK
# 191 Cordarrelle Patterson, NE
# 192 Peyton Barber, TB
# 193 DeAndre Washington, OAK
# 194 Chris Ivory, BUF
# 195 TJ Jones, DET
# 196 Shane Vereen, FA
# 197 Bennie Fowler III, CHI
# 198 Taylor Gabriel, CHI
# 199 Aaron Jones, GB
# 200 Trey Burton, CHI
# 201 Ed Dickson, SEA
# 202 Antonio Gates, LAC
# 203 Adrian Peterson, FA
# 204 Garrett Celek, SF
# 205 Jermaine Gresham, ARI
# 206 Donte Moncrief, JAX
# 207 Seth DeValve, CLE
# 208 Elijah McGuire, NYJ
# 209 Doug Martin, OAK
# 210 Bruce Ellington, HOU
# 211 Odell Beckham Jr., NYG
# 212 Ryan Fitzpatrick, TB
# 213 Charles Sims, TB
# 214 Brandon Coleman, NO
# 215 Charcandrick West, KC
# 216 Alfred Morris, DAL
# 217 Zay Jones, BUF
# 218 John Brown, BAL
# 219 Kyle Juszczyk, SF
# 220 Corey Davis, TEN
# 221 Mike Gillislee, NE
# 222 Rashard Higgins, CLE
# 223 Joshua Bellamy, CHI
# 224 Brock Osweiler, MIA
# 225 Kerwynn Williams, KC
# 226 Jamaal Charles, FA
# 227 Dede Westbrook, JAX
# 228 Chris Moore, BAL
# 229 Corey Coleman, CLE
# 230 Dalvin Cook, MIN
# 231 Dontrelle Inman, CHI
# 232 Stephen Anderson, HOU
# 233 Brice Butler, ARI
# 234 Nick O'Leary, BUF
# 235 Brian Hoyer, NE
# 236 Coby Fleener, NO
# 237 Ricardo Louis, CLE
# 238 Cody Latimer, NYG
# 239 Blaine Gabbert, TEN
# 240 Tyler Higbee, LAR
# 241 Tavarres King, MIN
# 242 Jordan Reed, WSH
# 243 Justin Hardy, ATL
# 244 Damien Williams, KC
# 245 Rhett Ellison, NYG
# 246 Martellus Bennett, NE
# 247 Danny Woodhead, BAL
# 248 Chester Rogers, IND
# 249 Kenny Britt, NE
# 250 Josh Gordon, CLE
# 251 Jordan Matthews, NE
# 252 Aldrick Robinson, SF
# 253 D'Onta Foreman, HOU
# 254 Benny Cunningham, CHI
# 255 Tyler Boyd, CIN
# 256 Zach Miller*, CHI
# 257 A.J. Derby, MIA
# 258 Luke Willson, DET
# 259 Darren Fells, CLE
# 260 Michael Campanaro, TEN
# 261 Mike Davis, SEA
# 262 Gerald Everett, LAR
# 263 Malcolm Brown, LAR
# 264 Tom Savage, NO
# 265 Mike Tolbert, BUF
# 266 Drew Stanton, CLE
# 267 Nick Boyle, BAL
# 268 Ricky Seals-Jones, ARI
# 269 Terrelle Pryor Sr., NYJ
# 270 Jarius Wright, CAR
# 271 Taywan Taylor, TEN
# 272 Jacquizz Rodgers, TB
# 273 Wendell Smallwood, PHI
# 274 Demetrius Harris, KC
# 275 Geronimo Allison, GB
# 276 Jeremy Kerley, BUF
# 372 Jerell Adams, NYG
# 373 Michael Hoomanawanui, NO
# 374 Clive Walford, NYJ
# 375 C.J. Prosise, SEA
# 376 ArDarius Stewart, NYJ
# 377 Branden Oliver, LAC
# 378 Stevan Ridley, PIT
# 379 Cameron Artis-Payne, CAR
# 380 Maurice Harris, WSH
# 381 Darrius Heyward-Bey, PIT
# 382 Lee Smith, OAK
# 383 Terron Ward, ATL
# 384 Willie Snead, BAL
# 385 Derek Carrier, OAK
# 386 Amara Darboh, SEA
# 387 Paxton Lynch, DEN
# 388 Andy Janovich, DEN
# 389 Freddie Martino, TB
# 390 Ross Travis, IND
# 391 Ryan Switzer, OAK
# 392 Roosevelt Nix, PIT
# 393 James Conner, PIT
# 394 Michael Thomas, LAR
# 395 Neal Sterling, NYJ
# 396 Xavier Grimble, PIT
# 397 EJ Manuel, OAK
# 398 Marvin Hall, ATL
# 399 Phillip Supernaw, TEN
# 400 Leonte Carroo, MIA
# 401 Brian Quick, WSH
# 402 Chris Thompson, HOU
# 403 Trevor Davis, GB
# 404 Aaron Ripkowski, GB
# 405 Luke Stocker, TEN
# 406 Bobby Rainey Jr., BAL
# 407 David Johnson, ARI
# 408 Sammie Coates, HOU
# 409 Tyler Ervin, HOU
# 410 De'Angelo Henderson, DEN
# 411 Jaelen Strong, JAX
# 412 Byron Marshall, WSH
# 413 Justin Hunter, PIT
# 414 Tanner McEvoy, SEA
# 415 Lance Dunbar, LAR
# 416 Brittan Golden, ARI
# 417 Zach Line, NO
# 418 Bryce Treggs, PHI
# 419 Ben Koyack, JAX
# 420 Alan Cross, TB
# 421 Trey Edmunds, NO
# 422 Austin Traylor, DEN
# 423 Nathan Peterman, BUF
# 424 Patrick Mahomes, KC
# 425 Ryan Mallett, FA
# 426 James Develin, NE
# 427 Geno Smith, LAC
# 428 Patrick DiMarco, BUF
# 429 Akeem Hunt*, KC
# 430 Chad Williams, ARI
# 431 Jeremy Sprinkle, WSH
# 432 Brian Hill, CIN
# 433 Jacob Hollister, NE
# 434 Sean McGrath, LAC
# 435 Tyler Eifert, CIN
# 436 Michael Roberts, DET
# 437 Zach Zenner, DET
# 438 Landry Jones, PIT
# 439 Tre Madden, SEA
# 440 Brandon Bolden, NE
# 441 Matthew Dayes, CLE
# 442 Markus Wheaton, PHI
# 443 Michael Clark, GB
# 444 Derek Watt, LAC
# 445 Will Tye, NE
# 446 Dwayne Washington, DET
# 447 Keith Smith, OAK
# 448 Nate Sudfeld, PHI
# 449 Marcus Johnson, SEA
# 450 Jared Abbrederis, DET
# 451 Orson Charles, KC
# 452 Noah Brown, DAL
# 453 Jay Prosch, HOU
# 454 Blake Bell, MIN
# 455 Quan Bray, BUF
# 456 Marcus Murphy, BUF
# 457 Randall Telfer, CLE
# 458 Tanner Gentry, CHI
# 459 Jalston Fowler, SEA
# 460 Griff Whalen, OAK
# 461 Vince Mayle, BAL
# 462 Nick Williams, TEN
# 463 Bernard Reedy, TB
# 464 Ifeanyi Momah, ARI
# 465 Darrell Daniels, IND
# 466 Chris Matthews, BAL
# 467 Fitzgerald Toussaint, PIT
# 468 Sean Mannion, LAR
# 469 Josh Ferguson, IND
# 470 Mack Brown, MIN
# 471 Danny Vitale, CLE
# 472 Joe Webb, HOU
# 473 Derrick Coleman, ARI
# 474 Geoff Swaim, DAL
# 475 Antony Auclair, TB
# 476 JoJo Natson, NYJ
# 477 Senorise Perry, MIA
# 478 Ryan Hewitt, CIN
# 479 Jehu Chesson, KC
# 480 Michael Burton, CHI
# 481 Chris Manhertz, CAR
# 482 Jordan Leslie, DEN
# 483 Cole Hikutini, SF
# 484 MarQueis Gray, MIA
# 485 DeAndrew White, HOU
# 486 Isaiah McKenzie, DEN
# 487 Darius Powe, NYG
# 488 Jeff Janis, CLE
# 489 Shelton Gibson, PHI
# 490 Cody Kessler, JAX
# 491 Allen Robinson, CHI
# 492 AJ McCarron, BUF
# 493 Kevin White, CHI
# 494 Andre Williams, LAC
# 495 Matt Cassel, DET
# 496 Arrelious Benn, JAX
# 497 Jeff Cumberland, LAC
# 498 Taiwan Jones, BUF
# 499 David Fluellen, TEN
# 500 Harry Douglas, TEN
# 501 Cobi Hamilton, ARI
# 502 Eric Weems, TEN
# 503 Matt Jones, PHI
# 504 LeShun Daniels Jr., WSH
# 505 Max McCaffrey, SF
# 506 Cooper Rush, DAL
# 507 Scott Tolzien, FA
# 508 Charone Peake, NYJ
# 509 Matt Hazel, CLE
# 510 Devante Mays, GB
# 511 Raheem Mostert, SF
# 512 Terrell Watson, NYG
# 513 Taylor Heinicke, CAR
# 514 Derek Anderson, FA
# 515 Joe Callahan, PHI
# 516 Andre Roberts, NYJ
# 517 John Kuhn, NO
# 518 Kalif Raymond, NYG
# 519 Justin Davis, LAR
# 520 Shaun Hill, MIN
# 521 Anquan Boldin, BUF
# 522 Matt Schaub, ATL
# 523 DeAngelo Williams, PIT
# 524 Devin Hester, SEA
# 525 Charlie Whitehurst, CLE
# 526 Calvin Johnson, DET
# 527 Eddie Royal, CHI
# 528 Gary Barnidge, CLE
# 529 Jerome Felton, BUF
# 530 Tim Hightower, SF
# 531 Matthew Slater, NE
# 532 Kellen Davis, NYJ
# 533 Josh Johnson, OAK
# 534 Justin Forsett, DEN
# 535 Matthew Mulligan, DET
# 536 Marcel Reece, SEA
# 537 Josh Freeman, IND
# 538 Mark Sanchez, FA
# 539 Rashad Jennings, NYG
# 540 David Johnson, PIT
# 541 Cedric Peerman, CIN
# 542 Chase Coffman, IND
# 543 John Phillips, NO
# 544 Percy Harvin*, BUF
# 545 Jordan Norwood, DEN
# 546 Julian Edelman, NE
# 547 Brandon Myers, TB
# 548 Antone Smith, TB
# 549 Colt McCoy, WSH
# 550 C.J. Spiller, KC
# 551 Ryan Mathews, PHI
# 552 Dexter McCluster, LAC
# 553 James Starks, GB
# 554 Dennis Pitta*, BAL
# 555 Jim Dray, ARI
# 556 Clay Harbor, NO
# 557 Marc Mariani, TEN
# 558 Andrew Quarless, DET
# 559 Joique Bell, DET
# 560 Victor Cruz, CHI
# 561 Marlon Moore*, CLE
# 562 Bryan Walters, JAX
# 752 Rodney Adams, MIN
# 753 Joshua Dobbs, PIT
# 754 Jordan Leggett, NYJ
# 755 Jake Butt, DEN
# 756 Mason Schreck, CIN
# 757 Alex Armah, CAR
# 758 David Moore, SEA
# 759 T.J. Logan, ARI
# 760 Carlos Henderson, DEN
# 761 Robert Davis, WSH
# 762 Bucky Hodges, NYJ
# 763 Sam Rogers, LAR
# 764 Isaiah Ford, MIA
# 765 Eric Saubert, ATL
# 766 Joe Williams, SF
# 767 Stacy Coley, MIN
# 768 Khalfani Muhammad, TEN
# 769 Jeremy McNichols, SF
# 770 DeAngelo Yancey, GB
# 771 Davis Webb, NYG
# 772 Freddie Stevenson, CHI
# 773 Jace Billingsley, DET
# 774 Ishmael Zamora, OAK
# 775 Austin Carr, NO
# 776 Hakeem Valles, DET
# 777 Rashawn Scott, MIA
# 778 Rannell Hall, CLE
# 779 Algernon Brown, NYJ
# 780 Jahad Thomas, NYJ
# 781 Damore'ea Stringfellow, SEA
# 782 Taquan Mizzell, CHI
# 783 Taysom Hill, NO
# 784 Victor Bolden Jr., SF
# 785 Sean Culkin, LAC
# 786 Cethan Carter, CIN
# 787 Evan Baylis, CAR
# 788 Shane Smith, NYG
# 789 Krishawn Hogan, IND
# 790 Henry Krieger-Coble, LAR
# 791 Ed Eagan, NYG
# 792 Carlton Agudosi, ARI
# 793 Isaac Whitney, OAK
# 794 Austin Davis, SEA
# 795 Darren McFadden, DAL
# 796 Chase Daniel, CHI
# 797 Chad Henne, KC
# 798 John Ross, CIN
# 799 Jake Rudock, DET
# 800 Kellen Clemens, LAC
# 801 Tyler Bray, CHI
# 802 Teddy Bridgewater, NYJ
# 803 Baker Mayfield, CLE
# 804 Sam Darnold, NYJ
# 805 Saquon Barkley, NYG
# 806 Josh Allen, BUF
# 807 Josh Rosen, ARI
# 808 D.J. Moore, CAR
# 809 Hayden Hurst, BAL
# 810 Calvin Ridley, ATL
# 811 Rashaad Penny, SEA
# 812 Sony Michel, NE
# 813 Lamar Jackson, BAL
# 814 Nick Chubb, CLE
# 815 Ronald Jones II, TB
# 816 Courtland Sutton, DEN
# 817 Mike Gesicki, MIA
# 818 Kerryon Johnson, DET
# 819 Dante Pettis, SF
# 820 Christian Kirk, ARI
# 821 Dallas Goedert, PHI
# 822 Anthony Miller, CHI
# 823 Derrius Guice, WSH
# 824 James Washington, PIT
# 825 D.J. Chark, JAX
# 826 Royce Freeman, DEN
# 827 Mason Rudolph, PIT
# 828 Michael Gallup, DAL
# 829 Mark Andrews, BAL
# 830 Tre'Quan Smith, NO
# 831 Jordan Akins, HOU
# 832 Ian Thomas, CAR
# 833 Keke Coutee, HOU
# 834 Nyheim Hines, IND
# 835 Antonio Callaway, CLE
# 836 Chris Herndon IV, NYJ
# 837 Kyle Lauletta, NYG
# 838 Mark Walton, CIN
# 839 DaeSean Hamilton, DEN
# 840 Will Dissly, SEA
# 841 Durham Smythe, MIA
# 842 Ito Smith, ATL
# 843 Kalen Ballage, MIA
# 844 Jaleel Scott, BAL
# 845 J'Mon Moore, GB
# 846 Chase Edmonds, ARI
# 847 Dalton Schultz, DAL
# 848 Justin Watson, TB
# 849 Troy Fumagalli, DEN
# 850 Tyler Conklin, MIN
# 851 Daurice Fountain, IND
# 852 Jordan Lasley, BAL
# 853 Jaylen Samuels, PIT
# 854 Jordan Wilkins, IND
# 855 Mike White, DAL
# 856 Marquez Valdes-Scantling, GB
# 857 Damion Ratley, CLE
# 858 John Kelly, LAR
# 859 Deon Cain, IND
# 860 Ray-Ray McCloud, BUF
# 861 Dylan Cantrell, LAC
# 862 Russell Gage, ATL
# 863 Luke Falk, TEN
# 864 Boston Scott, NO
# 865 Tanner Lee, JAX
# 866 Trenton Cannon, NYJ
# 867 Equanimeous St. Brown, GB
# 868 Cedrick Wilson, DAL
# 869 Braxton Berrios, NE
# 870 Jordan Thomas, HOU
# 871 Danny Etling, NE
# 872 Alex McGough, SEA
# 873 Javon Wims, CHI
# 874 David Williams, DEN
# 875 Marcell Ateman, OAK
# 876 Bo Scarbrough, DAL
# 877 Nick Bawden, DET
# 878 Richie James, SF
# 879 Logan Woodside, CIN
# 880 Ryan Izzo, NE
# 881 Justin Jackson, LAC
# 882 Auden Tate, CIN
# 883 Austin Proehl, BUF
# 884 Trey Quinn, WSH
# 885 Josh Adams, PHI
# 886 Akrum Wadley, TEN
# 887 Blake Jarwin, DAL
# 888 Byron Pringle, KC
# 889 Allen Lazard, JAX

# %% [markdown]
# 7.We'll create a list called positions that contains just the player positions. We'll do this by splitting the phrase by spaces and saving the very last item in each phrase. In a few cases, if the name ends in something other than position (like 'Q' for questionable of 'SSPD' for suspended), we'll take the second to last item:

# %%
positions = []
for player in df['player'].values:
    position = player.split()[-1]
    if position not in ['QB', 'RB', 'WR', 'TE']:
        position = player.split()[-2]
    print(position)
    positions.append(player.split()[-1])
# Out:
# RB
# QB
# RB
# RB
# WR
# WR
# QB
# QB
# RB
# QB
# RB
# WR
# QB
# RB
# QB
# QB
# QB
# RB
# QB
# WR
# QB
# QB
# WR
# WR
# QB
# WR
# QB
# WR
# WR
# QB
# RB
# TE
# RB
# RB
# QB
# TE
# WR
# WR
# WR
# WR
# QB
# WR
# WR
# RB
# QB
# QB
# QB
# QB
# WR
# QB
# RB
# WR
# RB
# TE
# QB
# RB
# WR
# RB
# WR
# WR
# WR
# WR
# RB
# WR
# QB
# WR
# QB
# RB
# WR
# WR
# QB
# WR
# RB
# WR
# TE
# WR
# RB
# TE
# WR
# RB
# TE
# RB
# TE
# QB
# WR
# RB
# RB
# RB
# WR
# WR
# WR
# WR
# WR
# TE
# QB
# RB
# WR
# RB
# RB
# RB
# WR
# WR
# RB
# WR
# TE
# WR
# RB
# WR
# RB
# TE
# RB
# RB
# RB
# WR
# WR
# WR
# RB
# TE
# WR
# WR
# RB
# RB
# QB
# RB
# TE
# WR
# WR
# TE
# WR
# WR
# RB
# QB
# WR
# TE
# WR
# WR
# QB
# WR
# QB
# RB
# TE
# WR
# TE
# RB
# WR
# TE
# RB
# TE
# WR
# WR
# WR
# WR
# WR
# WR
# RB
# RB
# RB
# 1  Russell Wilson, SEA        QB       347.9
# 2    Le'Veon Bell, PIT        RB       341.6
# 3     Alvin Kamara, NO        RB       320.4
# 4   Antonio Brown, PIT        WR       310.3

# %% [markdown]
# 9.Now go to this website to see what ESPN projected the player rankings to be BEFORE the season had started:
#
# http://www.espn.com/fantasy/football/story/_/page/17RanksPreseason200PPR/2017-fantasy-football-ppr-rankings-top-200
#
# We have also stored this locally as "fftprojections.htm". Use pd.read_html to read this data in.

# %% [markdown]
# 10.Save just the Player/Position/Team column to a dataframe called "df2". Rename the column "player".

# %%
table2 = pd.read_html('fftprojections.htm')
#table2 = pd.read_html('http://www.espn.com/fantasy/football/story/_/page/17RanksPreseason200PPR/2017-fantasy-football-ppr-rankings-top-200')
df2=table2[1]

# %%
df2 = df2[['Player/Position/Team']]
df2 = df2.rename(index=str, columns={'Player/Position/Team': 'player'})
df2.head()
# Out:
#                           player
# 0      1. David Johnson, RB, ARI
# 1       2. Le'Veon Bell, RB, PIT
# 2      3. Antonio Brown, WR, PIT
# 3    4. Ezekiel Elliott, RB, DAL
# 4  5. Odell Beckham Jr., WR, NYG

# %% [markdown]
# 11.We want to merge these two data frames. In order to do this, we need the player names to match up exactly. Update the "df2" data frame above to include only the player names and teams.

# %%
df2['player'] = [' '.join(player.split()[1:-2])+' '+player.split()[-1] for player in df2['player'] ]
df2.head()
# Out:
#                    player
# 0      David Johnson, ARI
# 1       Le'Veon Bell, PIT
# 2      Antonio Brown, PIT
# 3    Ezekiel Elliott, DAL
# 4  Odell Beckham Jr., NYG

# %% [markdown]
# 12.We'll want to create another column for what ESPN projected their ranking to be. Luckily, since they are in order, an index of 0 correponds to a ranking of 1, an index of 1 corresponds to a ranking of 2, etc. We can use the index and a list comprehension to create a ranking column:

# %%
df2['ranking'] = [int(x)+1 for x in df2.index]
df2.head()
# Out:
#                    player  ranking
# 0      David Johnson, ARI        1
# 1       Le'Veon Bell, PIT        2
# 2      Antonio Brown, PIT        3
# 3    Ezekiel Elliott, DAL        4
# 4  Odell Beckham Jr., NYG        5

# %% [markdown]
# 13.Okay, we are ready to merge these two dataframes. We'll use "inner" to denote that we only want to consider players that are in BOTH dataframes and we'll use "on=player" to denote that we want to merge the dataframes based on the player column.

# %%
results = pd.merge(df1, df2, how='inner', on = ['player'])
results.head()
# Out:
#                  player positions 2017 points  ranking
# 0   Russell Wilson, SEA        QB       347.9       79
# 1     Le'Veon Bell, PIT        RB       341.6        2
# 2      Alvin Kamara, NO        RB       320.4      152
# 3    Antonio Brown, PIT        WR       310.3        3
# 4  DeAndre Hopkins, HOU         Q       309.8       28

# %% [markdown]
# 14.Drop any rows that have any missing values. There might not be, but perform this operation just in case.

# %%
results = results.dropna(how = 'any')

# %% [markdown]
# 15.View all of the column data types using one command.

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121 entries, 0 to 120
# Data columns (total 4 columns):
# player         121 non-null object
# positions      121 non-null object
# 2017 points    121 non-null float64
# ranking        121 non-null int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.7+ KB

# %% [markdown]
# 16.Change the data type of 2017 points to a float.

# %%
results['2017 points'] = results['2017 points'].astype(float)

# %% [markdown]
# 17.Plot ESPN ranking on the x-axis versus 2017 points scored on the y-axis. Label your axes.

# %%
plt.plot(results['ranking'], results['2017 points'], '.')
plt.xlabel('espn ranking')
plt.ylabel('fantasy points')

# %% [markdown]
# 18.Is there a downward trend? Why does this make sense?

# %%
#because a ranking of 1 corresponds to the most projected points

# %% [markdown]
# 19.We can create a line of best fit:

# %%
import numpy as np

x = results['ranking']
y = results['2017 points']
fit = np.polyfit(x, y,1)
fit_fn = np.poly1d(fit) 
plt.plot(x, y,'.', x, fit_fn(x))
# Out:
# [<matplotlib.lines.Line2D at 0x10ce4f4a8>,
#  <matplotlib.lines.Line2D at 0x10ce4f7f0>]

# %% [markdown]
# 20.Print the slope and intercept of the line.

# %%
m, b = np.polyfit(x,y,1)
print(m,b)
# Out:
# -0.5734477697425076 213.67259031171207

# %% [markdown]
# 21.Create another column in the results dataframe called "predicted points" that lists the predicted points from the line of best fit for each player. Note: you can do this in one line. Don't use a loop.

# %%
results['predicted points'] = fit_fn(results['ranking'])

# %% [markdown]
# 22.Create another column called "residual" that lists the difference between the actual 2017 points and the predicted ESPN points.

# %%
results['residual'] = results['2017 points'] - results['predicted points']

# %% [markdown]
# 23.Sort the dataframe by predicted points from lowest to highest to see the most overrated players.

# %%
results.sort_values(by = 'residual', ascending = True).head()
# Out:
#                  player positions  2017 points  ranking  predicted points  \
# 114  David Johnson, ARI        RB         13.0        1        213.099143
# 118    Andrew Luck, IND         Q          0.0      116        147.152649
# 117    Kevin White, CHI        WR          2.6      117        146.579201
# 116   Tyler Eifert, CIN         Q          8.6      108        151.740231
# 109  Terrance West, BAL        RB         28.1       76        170.090560
#
#        residual
# 114 -200.099143
# 118 -147.152649
# 117 -143.979201
# 116 -143.140231
# 109 -141.990560

# %% [markdown]
# 24.R-squared is a measure of how well your model fits your data. Use the function below to calculate R-squared.

# %%
def rsquared(x, y, y_predicted):                   
    ybar = np.sum(y)/len(y)          
    ssreg = np.sum((y_predicted-ybar)**2)  
    sstot = np.sum((y - ybar)**2)  
    return ssreg / sstot

rsquared(results['ranking'], 
         results['2017 points'], 
         results['predicted points'])
# Out:
# 0.15948049574772416

# %% [markdown]
# 25.That R-Squared was pretty low. Let's try to do better.
#
# Up until now, you've only been able to create predictive models with numerical variables (e.g. rankings, points, etc.) However, we can also create regression models using categorical variables (such as football position!) Very exciting.
#
# In addition, up until now, you have probably only calculated a linear regression line when you have a single input variable. Today, we'll use multiple linear regression (where the input will be a matrix instead of a single vector).
#
# Our goal will be to use ESPN rankings (numerical) AND player position (categorical) to predict their fantasy points.
#
# Step 1: Create a new dataframe from the results dataframe called onehot that includes just the positions and ranking columns. (I'll explain why it's called onehot in a minute).

# %%
onehot = results[['ranking','positions']]
onehot.head()
# Out:
#    ranking positions
# 0       79        QB
# 1        2        RB
# 2      152        RB
# 3        3        WR
# 4       28         Q

# %% [markdown]
# 26.Now, a major step towards performing regression when there are categorical variables involved is first creating a matrix (called a one-hot matrix) where each position corresponds to a different column in the matrix. For example, if a player is a QB, he'll have a 1 in the QB column and a 0 in all of the others.
#
# We can do this using a built-in pandas function called get_dummies.
#
# Run the following code.

# %%
positions = pd.get_dummies(results['positions'])
onehot = onehot.drop('positions', axis = 1)
onehot = onehot.join(positions)
onehot.head()
# Out:
#    ranking  Q  QB  RB  SSPD  TE  WR
# 0       79  0   1   0     0   0   0
# 1        2  0   0   1     0   0   0
# 2      152  0   0   1     0   0   0
# 3        3  0   0   0     0   0   1
# 4       28  1   0   0     0   0   0

# %% [markdown]
# 27.Okay. Our input is going to be this matrix and our output is going to be the 2017 points. We'll need to have the scikit-learn package in order to use the the multiple linear regression model. scikit-learn is the most popular package for maching learning algorithms using Python. So exciting!!!
#
# Try running the cell below. If it doesn't work, try downloading the scikit-learn package by typing into your terminal this:
#
# pip install -U scikit-learn
#
# or this:
#
# conda install -c anaconda scikit-learn

# %%
from sklearn.linear_model import LinearRegression

X = onehot
y = results['2017 points']

clf = LinearRegression()
clf.fit(X, y)
clf.predict(X)
print('R-squared', clf.score(X,y))
# Out:
# R-squared 0.32797578096044677
# /Users/shareshianl/anaconda/lib/python3.6/site-packages/scipy/linalg/basic.py:1018: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)

# %% [markdown]
# 28.Wow! Our R-squared doubled when we incorporated the player position into our input. Let's visualize what is going on with this multiple linear regression by creating the following plot below:

# %%
#Let's break things down by position:
quarterbacks = results[results['positions'] == 'QB']
runningbacks = results[results['positions'] == 'RB']
receivers = results[results['positions'] == 'WR']
tightends = results[results['positions'] == 'TE']

fig, ax = plt.subplots(figsize=(7,7))

ax.scatter(quarterbacks.ranking, quarterbacks['2017 points'],  color='blue', label='qb')
ax.scatter(runningbacks.ranking, runningbacks['2017 points'],  color='red', label='rb')
ax.scatter(receivers.ranking, receivers['2017 points'],  color='yellow', label = 'wr')
ax.scatter(tightends.ranking, tightends['2017 points'],  color='green', label = 'te')

ax.plot(X.ranking, clf.predict(X), 'k.', label = 'predictions')
ax.set_xlabel('ESPN projected pre-season player ranking 2017')
ax.set_ylabel('Total ESPN Fantasy Points that player scored in 2017')
ax.set_title('Position matters!')
ax.legend(loc='best')

# %% [markdown]
# 29.Explain in your own words why your multiple linear regression model is plotting the black dots in the manner that you see above.

# %%
#different linear lines for different positions

# %% [markdown]
# Note: You've just explored the very beginnings of using Python to perform machine learning! Machine learning is a pretty ill defined term, but according to Wikipedia, "Machine learning explores the construction and study of algorithms that can learn from and make predictions on data."
#
# You have just learned the multiple linear regression sci-kit learn method. There are many MUCH better methods (RidgeCV, GradientBoostingRegressor, etc.)
#
# There are also better measures for how well a model does. (The adjusted R-squared measure is MUCH better than the R-squared measure.)
#
# In addition, we just committed the cardinal sin of data science in the above example, which is to use our entire dataset to train our model. In practice, we should have used just a subset of the player data to train our model (i.e., to calculate the line of best fit) and then we should have calculated how well our model did at predicting the test set values (the players that we didn't include in our training model).
#
# To learn more, this is a great first tutorial on how to use sci-kit learn for machine learning:
#
# https://www.datacamp.com/community/tutorials/machine-learning-python
#
# More docs are here:
#
# http://scikit-learn.org/stable/tutorial/basic/tutorial.html
#
# And Andrew Ng's online Machine Learning course is famous:
#
# https://www.coursera.org/learn/machine-learning
